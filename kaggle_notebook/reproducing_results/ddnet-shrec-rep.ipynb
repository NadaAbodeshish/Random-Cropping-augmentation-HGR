# %%
! pip install -q keras

# %%
import numpy as np
import math
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
from tqdm import tqdm
import pickle
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt
from scipy.spatial.distance import cdist

from keras.optimizers import *
from keras.models import Model
from keras.layers import *
# from keras.layers.core import *
# from tensorflow.keras.callbacks import *
# from keras.layers.convolutional import *
from keras import backend as K
import keras
import tensorflow as tf

# import google.colab.files

# %% [markdown]
# 1. Define configurations

# %%
random.seed(1234)

class Config():
    def __init__(self):
        self.frame_l = 32 # the length of frames
        self.joint_n = 12 # the number of joints
        self.joint_n = 22 # the number of joints
        self.joint_d = 3 # the dimension of joints
        self.clc_coarse = 14 # the number of coarse class
        self.clc_fine = 28 # the number of fine-grained class
        self.feat_d = 231
        self.filters = 64
C = Config()

# %% [markdown]
# 2. Define data processing functions

# %%
# Temple resizing function
import numpy as np
import os
import pandas as pd
import random
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

###################################################################################


#Rescale to be 64 frames
def zoom(p,target_l=64,joints_num=25,joints_dim=3):
    l = p.shape[0]
    p_new = np.empty([target_l,joints_num,joints_dim])
    for m in range(joints_num):
        for n in range(joints_dim):
            p[:,m,n] = medfilt(p[:,m,n],3)
            p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
    return p_new

def sampling_frame(p,C):
    full_l = p.shape[0] # full length
    if random.uniform(0,1)<0.5: # aligment sampling
        valid_l = np.round(np.random.uniform(0.9,1)*full_l)
        s = random.randint(0, full_l-int(valid_l))
        e = s+valid_l # sample end point
        p = p[int(s):int(e),:,:]
    else: # without aligment sampling
        valid_l = np.round(np.random.uniform(0.9,1)*full_l)
        index = np.sort(np.random.choice(range(0,full_l),int(valid_l),replace=False))
        p = p[index,:,:]
    p = zoom(p,C.frame_l,C.joint_n,C.joint_d)
    return p

from scipy.spatial.distance import cdist
def get_CG(p,C):
    M = []
    iu = np.triu_indices(C.joint_n,1,C.joint_n)
    for f in range(C.frame_l):
        #distance max
        d_m = cdist(p[f],np.concatenate([p[f],np.zeros([1,C.joint_d])]),'euclidean')
        d_m = d_m[iu]
        M.append(d_m)
    M = np.stack(M)
    return M

def normlize_range(p):
    # normolize to start point, use the center for hand case
    p[:,:,0] = p[:,:,0]-np.mean(p[:,:,0])
    p[:,:,1] = p[:,:,1]-np.mean(p[:,:,1])
    p[:,:,2] = p[:,:,2]-np.mean(p[:,:,2])
    return p

def cm_analysis(y_true, y_pred, filename, labels, ymap=None, figsize=(8,8)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args:
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                #annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
                annot[i, j] = '%.1f' % (p)
            elif c == 0:
                annot[i, j] = ''
            else:
                #annot[i, j] = '%.1f%%\n%d' % (p, c)
                annot[i, j] = '%.1f' % (p)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax, cbar=False, cmap="YlGnBu")
    plt.savefig(filename)

# %% [markdown]
# 3. Define network

# %%
def poses_diff(x):
    H, W = x.get_shape()[1],x.get_shape()[2]
    x = tf.subtract(x[:,1:,...],x[:,:-1,...])
    x = tf.image.resize(x,size=[H,W])
    return x

def pose_motion(P,frame_l):
    P_diff_slow = Lambda(lambda x: poses_diff(x))(P)
    P_diff_slow = Reshape((frame_l,-1))(P_diff_slow)
    P_fast = Lambda(lambda x: x[:,::2,...])(P)
    P_diff_fast = Lambda(lambda x: poses_diff(x))(P_fast)
    P_diff_fast = Reshape((int(frame_l/2),-1))(P_diff_fast)
    return P_diff_slow,P_diff_fast

def c1D(x,filters,kernel):
    x = Conv1D(filters, kernel_size=kernel,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def block(x,filters):
    x = c1D(x,filters,3)
    x = c1D(x,filters,3)
    return x

def d1D(x,filters):
    x = Dense(filters,use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def build_FM(frame_l=32,joint_n=22,joint_d=2,feat_d=231,filters=16):
    M = Input(shape=(frame_l,feat_d))
    P = Input(shape=(frame_l,joint_n,joint_d))

    diff_slow,diff_fast = pose_motion(P,frame_l)

    x = c1D(M,filters*2,1)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,3)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,1)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x_d_slow = c1D(diff_slow,filters*2,1)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,3)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,1)
    x_d_slow = MaxPool1D(2)(x_d_slow)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)

    x_d_fast = c1D(diff_fast,filters*2,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,3)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)

    x = concatenate([x,x_d_slow,x_d_fast])
    x = block(x,filters*2)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*4)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*8)
    x = SpatialDropout1D(0.1)(x)

    return Model(inputs=[M,P],outputs=x)


def build_DD_Net(frame_l=32,joint_n=22,joint_d=3,feat_d=231,clc_num=14,filters=16):
    M = Input(name='M', shape=(frame_l,feat_d))
    P = Input(name='P', shape=(frame_l,joint_n,joint_d))

    FM = build_FM(frame_l,joint_n,joint_d,feat_d,filters)

    x = FM([M,P])

    x = GlobalMaxPool1D()(x)

    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = Dense(clc_num, activation='softmax')(x)

    ######################Self-supervised part
    model = Model(inputs=[M,P],outputs=x)
    return model

# %%
DD_Net = build_DD_Net(C.frame_l,C.joint_n,C.joint_d,C.feat_d,C.clc_coarse,C.filters)
DD_Net.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ M (InputLayer)      │ (None, 32, 231)   │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ P (InputLayer)      │ (None, 32, 22, 3) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_1        │ (None, 4, 512)    │  1,740,160 │ M[0][0], P[0][0]  │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ functional_1[0][… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     65,536 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 128)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ leaky_re_lu_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     16,384 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 128)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ leaky_re_lu_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 14)        │      1,806 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,824,910 (6.96 MB)
#  Trainable params: 1,819,278 (6.94 MB)
#  Non-trainable params: 5,632 (22.00 KB)

# %% [markdown]
# 4. Load dataset (download GT_train_1.pkl and  GT_test_1.pkl from github )

# %%
# !wget https://github.com/fandulu/DD-Net/archive/master.zip
# !unzip master.zip
# !rm master.zip
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# --2024-12-13 21:26:39--  https://github.com/fandulu/DD-Net/archive/master.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master [following]
# --2024-12-13 21:26:40--  https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: 'master.zip'
#
# master.zip              [             <=>    ]  79.09M  14.1MB/s    in 5.6s
#
# 2024-12-13 21:26:45 (14.1 MB/s) - 'master.zip' saved [82934337]
#
# Archive:  master.zip
# f26a9994b0bafc41096fa269eab89c2757d71499
#    creating: DD-Net-master/
#   inflating: DD-Net-master/.gitignore
#    creating: DD-Net-master/JHMDB/
#   inflating: DD-Net-master/JHMDB/README.md
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_heavy.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_lite.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_middle.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_data_preprocessing.ipynb
#   inflating: DD-Net-master/JHMDB/utils.py
#    creating: DD-Net-master/JHMDB/weights/
#  extracting: DD-Net-master/JHMDB/weights/__init__.py
#   inflating: DD-Net-master/LICENSE
#   inflating: DD-Net-master/README.md
#    creating: DD-Net-master/SHREC/
#   inflating: DD-Net-master/SHREC/README.md
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_lite.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_data_preprocessing.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_lite.ipynb
#    creating: DD-Net-master/SHREC/images/
#   inflating: DD-Net-master/SHREC/images/SHREC_14.png
#   inflating: DD-Net-master/SHREC/images/SHREC_28.png
#   inflating: DD-Net-master/SHREC/utils.py
#    creating: DD-Net-master/SHREC/weights/
#  extracting: DD-Net-master/SHREC/weights/.gitkeep
#  extracting: DD-Net-master/SHREC/weights/__init__.py
#    creating: DD-Net-master/data/
#    creating: DD-Net-master/data/JHMDB/
#   inflating: DD-Net-master/data/JHMDB/GT_test_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_3.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_3.pkl
#   inflating: DD-Net-master/data/JHMDB/joint_positions.zip
#   inflating: DD-Net-master/data/JHMDB/splits.zip
#    creating: DD-Net-master/data/SHREC/
#  extracting: DD-Net-master/data/SHREC/__init__.py
#   inflating: DD-Net-master/data/SHREC/test.pickle
#   inflating: DD-Net-master/data/SHREC/test.pkl
#   inflating: DD-Net-master/data/SHREC/train.pickle
#   inflating: DD-Net-master/data/SHREC/train.pkl
#    creating: DD-Net-master/mics/
#  extracting: DD-Net-master/mics/__init__.py
#   inflating: DD-Net-master/mics/demo.png
#   inflating: DD-Net-master/mics/look.gif
#   inflating: DD-Net-master/mics/paper.png

# %% [markdown]
# 5. Running codes

# %%
Train = pickle.load(open("/kaggle/working/DD-Net-master/data/SHREC/train.pkl", "rb"))
Test = pickle.load(open("/kaggle/working/DD-Net-master/data/SHREC/test.pkl", "rb"))

X_0 = []
X_1 = []
Y = []
for i in tqdm(range(len(Train['pose']))):
    p = np.copy(Train['pose'][i]).reshape([-1,22,3])
    p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)
    p = normlize_range(p)

    label = np.zeros(C.clc_coarse)
    label[Train['coarse_label'][i]-1] = 1

    M = get_CG(p,C)

    X_0.append(M)
    X_1.append(p)
    Y.append(label)

X_0 = np.stack(X_0)
X_1 = np.stack(X_1)
Y = np.stack(Y)
# Out:
#   0%|          | 0/1960 [00:00<?, ?it/s]/tmp/ipykernel_23/208528541.py:23: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 1960/1960 [00:19<00:00, 100.41it/s]

# %%
X_test_0 = []
X_test_1 = []
Y_test = []
for i in tqdm(range(len(Test['pose']))):
    p = np.copy(Test['pose'][i]).reshape([-1,22,3])
    p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)
    p = normlize_range(p)

    label = np.zeros(C.clc_coarse)
    label[Test['coarse_label'][i]-1] = 1

    M = get_CG(p,C)

    X_test_0.append(M)
    X_test_1.append(p)
    Y_test.append(label)

X_test_0 = np.stack(X_test_0)
X_test_1 = np.stack(X_test_1)
Y_test = np.stack(Y_test)
# Out:
#   0%|          | 0/840 [00:00<?, ?it/s]/tmp/ipykernel_23/208528541.py:23: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 840/840 [00:08<00:00, 97.50it/s]

# %%
# it may takes several times to reach the reported performance
lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
            batch_size=len(Y),
            epochs=400,
            verbose=True,
            shuffle=True,
            callbacks=[lrScheduler],
            validation_data=([X_test_0,X_test_1],Y_test)
            )

lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
            batch_size=len(Y),
            epochs=500,
            verbose=True,
            shuffle=True,
            callbacks=[lrScheduler],
            validation_data=([X_test_0,X_test_1],Y_test)
            )
# Out:
# Epoch 1/400
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734125255.318036     103 service.cc:145] XLA service 0x7a8c7c2333b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734125255.318098     103 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1734125255.318104     103 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 2024-12-13 21:27:50.157113: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[1960,64,1,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1960,128,1,32]{3,2,1,0}, f32[64,128,1,3]{3,2,1,0}), window={size=1x3 pad=0_0x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-12-13 21:27:50.189015: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.032020733s
# Trying algorithm eng3{k11=2} for conv (f32[1960,64,1,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1960,128,1,32]{3,2,1,0}, f32[64,128,1,3]{3,2,1,0}), window={size=1x3 pad=0_0x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47s/step - accuracy: 0.0673 - loss: 3.4682
# I0000 00:00:1734125294.157724     103 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step - accuracy: 0.0673 - loss: 3.4682 - val_accuracy: 0.0679 - val_loss: 2.6388 - learning_rate: 1.0000e-04
# Epoch 2/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.0760 - loss: 3.3030 - val_accuracy: 0.0798 - val_loss: 2.6386 - learning_rate: 1.0000e-04
# Epoch 3/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.0847 - loss: 3.2301 - val_accuracy: 0.1107 - val_loss: 2.6386 - learning_rate: 1.0000e-04
# Epoch 4/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.0969 - loss: 3.1416 - val_accuracy: 0.0869 - val_loss: 2.6386 - learning_rate: 1.0000e-04
# Epoch 5/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.0944 - loss: 3.0521 - val_accuracy: 0.0726 - val_loss: 2.6386 - learning_rate: 1.0000e-04
# Epoch 6/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.1051 - loss: 3.0022 - val_accuracy: 0.0845 - val_loss: 2.6386 - learning_rate: 1.0000e-04
# Epoch 7/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.1173 - loss: 2.9578 - val_accuracy: 0.0810 - val_loss: 2.6387 - learning_rate: 1.0000e-04
# Epoch 8/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.1194 - loss: 2.9283 - val_accuracy: 0.0810 - val_loss: 2.6388 - learning_rate: 1.0000e-04
# Epoch 9/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.1327 - loss: 2.8806 - val_accuracy: 0.0810 - val_loss: 2.6390 - learning_rate: 1.0000e-04
# Epoch 10/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.1393 - loss: 2.8200 - val_accuracy: 0.0810 - val_loss: 2.6392 - learning_rate: 1.0000e-04
# Epoch 11/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.1561 - loss: 2.7501 - val_accuracy: 0.0810 - val_loss: 2.6395 - learning_rate: 1.0000e-04
# Epoch 12/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.1607 - loss: 2.7096 - val_accuracy: 0.0810 - val_loss: 2.6398 - learning_rate: 1.0000e-04
# Epoch 13/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.1668 - loss: 2.6825 - val_accuracy: 0.0810 - val_loss: 2.6402 - learning_rate: 1.0000e-04
# Epoch 14/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.1510 - loss: 2.6628 - val_accuracy: 0.0810 - val_loss: 2.6407 - learning_rate: 1.0000e-04
# Epoch 15/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.1781 - loss: 2.6019 - val_accuracy: 0.0810 - val_loss: 2.6413 - learning_rate: 1.0000e-04
# Epoch 16/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.1842 - loss: 2.5879 - val_accuracy: 0.0810 - val_loss: 2.6420 - learning_rate: 1.0000e-04
# Epoch 17/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.2015 - loss: 2.5198 - val_accuracy: 0.0810 - val_loss: 2.6428 - learning_rate: 1.0000e-04
# Epoch 18/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.1974 - loss: 2.5216 - val_accuracy: 0.0810 - val_loss: 2.6437 - learning_rate: 1.0000e-04
# Epoch 19/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.2041 - loss: 2.5435 - val_accuracy: 0.0810 - val_loss: 2.6446 - learning_rate: 1.0000e-04
# Epoch 20/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.2153 - loss: 2.4397 - val_accuracy: 0.0810 - val_loss: 2.6457 - learning_rate: 1.0000e-04
# Epoch 21/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.2281 - loss: 2.4137 - val_accuracy: 0.0810 - val_loss: 2.6468 - learning_rate: 1.0000e-04
# Epoch 22/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.2342 - loss: 2.3700 - val_accuracy: 0.0810 - val_loss: 2.6479 - learning_rate: 1.0000e-04
# Epoch 23/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.2378 - loss: 2.3651 - val_accuracy: 0.0810 - val_loss: 2.6491 - learning_rate: 1.0000e-04
# Epoch 24/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.2485 - loss: 2.3693 - val_accuracy: 0.0810 - val_loss: 2.6503 - learning_rate: 1.0000e-04
# Epoch 25/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.2546 - loss: 2.2803 - val_accuracy: 0.0810 - val_loss: 2.6516 - learning_rate: 1.0000e-04
# Epoch 26/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.2714 - loss: 2.3140 - val_accuracy: 0.0810 - val_loss: 2.6530 - learning_rate: 1.0000e-04
# Epoch 27/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.2556 - loss: 2.2527 - val_accuracy: 0.0810 - val_loss: 2.6545 - learning_rate: 1.0000e-04
# Epoch 28/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.2832 - loss: 2.1936 - val_accuracy: 0.0810 - val_loss: 2.6560 - learning_rate: 1.0000e-04
# Epoch 29/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.2862 - loss: 2.1998 - val_accuracy: 0.0821 - val_loss: 2.6575 - learning_rate: 1.0000e-04
# Epoch 30/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.3046 - loss: 2.1731 - val_accuracy: 0.0976 - val_loss: 2.6591 - learning_rate: 1.0000e-04
# Epoch 31/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.3097 - loss: 2.1554 - val_accuracy: 0.1048 - val_loss: 2.6607 - learning_rate: 1.0000e-04
# Epoch 32/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.3189 - loss: 2.1219 - val_accuracy: 0.0643 - val_loss: 2.6623 - learning_rate: 1.0000e-04
# Epoch 33/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.3301 - loss: 2.0940 - val_accuracy: 0.0607 - val_loss: 2.6640 - learning_rate: 1.0000e-04
# Epoch 34/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.3306 - loss: 2.0432 - val_accuracy: 0.0607 - val_loss: 2.6658 - learning_rate: 1.0000e-04
# Epoch 35/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.3500 - loss: 2.0364 - val_accuracy: 0.0607 - val_loss: 2.6676 - learning_rate: 1.0000e-04
# Epoch 36/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.3566 - loss: 2.0067 - val_accuracy: 0.0607 - val_loss: 2.6694 - learning_rate: 1.0000e-04
# Epoch 37/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.3398 - loss: 1.9900 - val_accuracy: 0.0607 - val_loss: 2.6713 - learning_rate: 1.0000e-04
# Epoch 38/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.3679 - loss: 1.9733 - val_accuracy: 0.0607 - val_loss: 2.6733 - learning_rate: 1.0000e-04
# Epoch 39/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.3628 - loss: 1.9312 - val_accuracy: 0.0607 - val_loss: 2.6752 - learning_rate: 1.0000e-04
# Epoch 40/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.4005 - loss: 1.8594 - val_accuracy: 0.0607 - val_loss: 2.6772 - learning_rate: 1.0000e-04
# Epoch 41/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.3801 - loss: 1.8903 - val_accuracy: 0.0607 - val_loss: 2.6793 - learning_rate: 1.0000e-04
# Epoch 42/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.4168 - loss: 1.8230 - val_accuracy: 0.0607 - val_loss: 2.6814 - learning_rate: 1.0000e-04
# Epoch 43/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.4071 - loss: 1.8275 - val_accuracy: 0.0607 - val_loss: 2.6835 - learning_rate: 1.0000e-04
# Epoch 44/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.4163 - loss: 1.8027 - val_accuracy: 0.0607 - val_loss: 2.6856 - learning_rate: 1.0000e-04
# Epoch 45/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.4255 - loss: 1.7966 - val_accuracy: 0.0607 - val_loss: 2.6878 - learning_rate: 1.0000e-04
# Epoch 46/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.4454 - loss: 1.7342 - val_accuracy: 0.0607 - val_loss: 2.6900 - learning_rate: 1.0000e-04
# Epoch 47/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.4423 - loss: 1.7459 - val_accuracy: 0.0607 - val_loss: 2.6924 - learning_rate: 1.0000e-04
# Epoch 48/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.4551 - loss: 1.7100 - val_accuracy: 0.0607 - val_loss: 2.6949 - learning_rate: 1.0000e-04
# Epoch 49/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.4663 - loss: 1.6762 - val_accuracy: 0.0607 - val_loss: 2.6975 - learning_rate: 1.0000e-04
# Epoch 50/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.4597 - loss: 1.6761 - val_accuracy: 0.0607 - val_loss: 2.7003 - learning_rate: 1.0000e-04
# Epoch 51/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.4760 - loss: 1.6734 - val_accuracy: 0.0607 - val_loss: 2.7031 - learning_rate: 1.0000e-04
# Epoch 52/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.4949 - loss: 1.6238 - val_accuracy: 0.0607 - val_loss: 2.7060 - learning_rate: 1.0000e-04
# Epoch 53/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.4985 - loss: 1.5974 - val_accuracy: 0.0607 - val_loss: 2.7089 - learning_rate: 1.0000e-04
# Epoch 54/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.5209 - loss: 1.5675 - val_accuracy: 0.0607 - val_loss: 2.7119 - learning_rate: 1.0000e-04
# Epoch 55/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.5077 - loss: 1.5672 - val_accuracy: 0.0607 - val_loss: 2.7150 - learning_rate: 1.0000e-04
# Epoch 56/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.5230 - loss: 1.5232 - val_accuracy: 0.0607 - val_loss: 2.7181 - learning_rate: 1.0000e-04
# Epoch 57/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.5051 - loss: 1.5540 - val_accuracy: 0.0607 - val_loss: 2.7215 - learning_rate: 1.0000e-04
# Epoch 58/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.5444 - loss: 1.4636 - val_accuracy: 0.0607 - val_loss: 2.7249 - learning_rate: 1.0000e-04
# Epoch 59/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.5327 - loss: 1.4795 - val_accuracy: 0.0607 - val_loss: 2.7284 - learning_rate: 1.0000e-04
# Epoch 60/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.5485 - loss: 1.4635 - val_accuracy: 0.0607 - val_loss: 2.7319 - learning_rate: 1.0000e-04
# Epoch 61/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.5679 - loss: 1.4119 - val_accuracy: 0.0607 - val_loss: 2.7355 - learning_rate: 1.0000e-04
# Epoch 62/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.5740 - loss: 1.4178 - val_accuracy: 0.0607 - val_loss: 2.7392 - learning_rate: 1.0000e-04
# Epoch 63/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.5811 - loss: 1.3927 - val_accuracy: 0.0607 - val_loss: 2.7429 - learning_rate: 1.0000e-04
# Epoch 64/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.5954 - loss: 1.3570 - val_accuracy: 0.0607 - val_loss: 2.7465 - learning_rate: 1.0000e-04
# Epoch 65/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.5913 - loss: 1.3266 - val_accuracy: 0.0619 - val_loss: 2.7504 - learning_rate: 1.0000e-04
# Epoch 66/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.5852 - loss: 1.3528 - val_accuracy: 0.0679 - val_loss: 2.7543 - learning_rate: 1.0000e-04
# Epoch 67/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.5934 - loss: 1.3492 - val_accuracy: 0.0714 - val_loss: 2.7581 - learning_rate: 1.0000e-04
# Epoch 68/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.5954 - loss: 1.3058 - val_accuracy: 0.0810 - val_loss: 2.7621 - learning_rate: 1.0000e-04
# Epoch 69/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.6158 - loss: 1.2786 - val_accuracy: 0.0881 - val_loss: 2.7661 - learning_rate: 1.0000e-04
# Epoch 70/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.6332 - loss: 1.2403 - val_accuracy: 0.0940 - val_loss: 2.7704 - learning_rate: 1.0000e-04
# Epoch 71/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6219 - loss: 1.2568 - val_accuracy: 0.1000 - val_loss: 2.7747 - learning_rate: 1.0000e-04
# Epoch 72/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.6291 - loss: 1.2616 - val_accuracy: 0.1071 - val_loss: 2.7789 - learning_rate: 1.0000e-04
# Epoch 73/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6515 - loss: 1.2172 - val_accuracy: 0.1095 - val_loss: 2.7832 - learning_rate: 1.0000e-04
# Epoch 74/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6311 - loss: 1.2609 - val_accuracy: 0.1119 - val_loss: 2.7876 - learning_rate: 1.0000e-04
# Epoch 75/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.6429 - loss: 1.2109 - val_accuracy: 0.1143 - val_loss: 2.7920 - learning_rate: 1.0000e-04
# Epoch 76/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.6444 - loss: 1.2038 - val_accuracy: 0.1143 - val_loss: 2.7962 - learning_rate: 1.0000e-04
# Epoch 77/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6602 - loss: 1.1655 - val_accuracy: 0.1167 - val_loss: 2.8006 - learning_rate: 1.0000e-04
# Epoch 78/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.6490 - loss: 1.1755 - val_accuracy: 0.1190 - val_loss: 2.8053 - learning_rate: 1.0000e-04
# Epoch 79/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6735 - loss: 1.1317 - val_accuracy: 0.1202 - val_loss: 2.8101 - learning_rate: 1.0000e-04
# Epoch 80/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.6704 - loss: 1.1158 - val_accuracy: 0.1214 - val_loss: 2.8154 - learning_rate: 1.0000e-04
# Epoch 81/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6837 - loss: 1.1113 - val_accuracy: 0.1214 - val_loss: 2.8208 - learning_rate: 1.0000e-04
# Epoch 82/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6791 - loss: 1.1220 - val_accuracy: 0.1214 - val_loss: 2.8264 - learning_rate: 1.0000e-04
# Epoch 83/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6801 - loss: 1.0825 - val_accuracy: 0.1214 - val_loss: 2.8323 - learning_rate: 1.0000e-04
# Epoch 84/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.6867 - loss: 1.0927 - val_accuracy: 0.1214 - val_loss: 2.8380 - learning_rate: 1.0000e-04
# Epoch 85/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6944 - loss: 1.0576 - val_accuracy: 0.1226 - val_loss: 2.8437 - learning_rate: 1.0000e-04
# Epoch 86/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.7097 - loss: 1.0560 - val_accuracy: 0.1238 - val_loss: 2.8492 - learning_rate: 1.0000e-04
# Epoch 87/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.7128 - loss: 1.0124 - val_accuracy: 0.1238 - val_loss: 2.8548 - learning_rate: 1.0000e-04
# Epoch 88/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.7041 - loss: 1.0474 - val_accuracy: 0.1226 - val_loss: 2.8602 - learning_rate: 1.0000e-04
# Epoch 89/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7240 - loss: 0.9972 - val_accuracy: 0.1226 - val_loss: 2.8659 - learning_rate: 1.0000e-04
# Epoch 90/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7311 - loss: 1.0018 - val_accuracy: 0.1214 - val_loss: 2.8717 - learning_rate: 1.0000e-04
# Epoch 91/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.7240 - loss: 0.9895 - val_accuracy: 0.1214 - val_loss: 2.8772 - learning_rate: 1.0000e-04
# Epoch 92/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7357 - loss: 0.9737 - val_accuracy: 0.1214 - val_loss: 2.8829 - learning_rate: 1.0000e-04
# Epoch 93/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7423 - loss: 0.9363 - val_accuracy: 0.1214 - val_loss: 2.8890 - learning_rate: 1.0000e-04
# Epoch 94/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7393 - loss: 0.9442 - val_accuracy: 0.1214 - val_loss: 2.8950 - learning_rate: 1.0000e-04
# Epoch 95/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7408 - loss: 0.9378 - val_accuracy: 0.1226 - val_loss: 2.9011 - learning_rate: 1.0000e-04
# Epoch 96/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7413 - loss: 0.9434 - val_accuracy: 0.1238 - val_loss: 2.9074 - learning_rate: 1.0000e-04
# Epoch 97/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.7454 - loss: 0.9462 - val_accuracy: 0.1238 - val_loss: 2.9136 - learning_rate: 1.0000e-04
# Epoch 98/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7459 - loss: 0.9264 - val_accuracy: 0.1226 - val_loss: 2.9199 - learning_rate: 1.0000e-04
# Epoch 99/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7526 - loss: 0.9139 - val_accuracy: 0.1226 - val_loss: 2.9264 - learning_rate: 1.0000e-04
# Epoch 100/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.7551 - loss: 0.9148 - val_accuracy: 0.1226 - val_loss: 2.9330 - learning_rate: 1.0000e-04
# Epoch 101/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7459 - loss: 0.9102 - val_accuracy: 0.1238 - val_loss: 2.9395 - learning_rate: 1.0000e-04
# Epoch 102/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7485 - loss: 0.8949 - val_accuracy: 0.1238 - val_loss: 2.9457 - learning_rate: 1.0000e-04
# Epoch 103/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.7648 - loss: 0.8875 - val_accuracy: 0.1238 - val_loss: 2.9517 - learning_rate: 1.0000e-04
# Epoch 104/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7765 - loss: 0.8592 - val_accuracy: 0.1238 - val_loss: 2.9577 - learning_rate: 1.0000e-04
# Epoch 105/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7781 - loss: 0.8673 - val_accuracy: 0.1238 - val_loss: 2.9636 - learning_rate: 1.0000e-04
# Epoch 106/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.7735 - loss: 0.8538 - val_accuracy: 0.1238 - val_loss: 2.9691 - learning_rate: 1.0000e-04
# Epoch 107/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7709 - loss: 0.8403 - val_accuracy: 0.1238 - val_loss: 2.9743 - learning_rate: 1.0000e-04
# Epoch 108/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7709 - loss: 0.8330 - val_accuracy: 0.1238 - val_loss: 2.9802 - learning_rate: 1.0000e-04
# Epoch 109/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7898 - loss: 0.8183 - val_accuracy: 0.1238 - val_loss: 2.9860 - learning_rate: 1.0000e-04
# Epoch 110/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7929 - loss: 0.8044 - val_accuracy: 0.1238 - val_loss: 2.9917 - learning_rate: 1.0000e-04
# Epoch 111/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7786 - loss: 0.8228 - val_accuracy: 0.1238 - val_loss: 2.9982 - learning_rate: 1.0000e-04
# Epoch 112/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.7791 - loss: 0.8191 - val_accuracy: 0.1238 - val_loss: 3.0049 - learning_rate: 1.0000e-04
# Epoch 113/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.7806 - loss: 0.8039 - val_accuracy: 0.1238 - val_loss: 3.0112 - learning_rate: 1.0000e-04
# Epoch 114/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.8138 - loss: 0.7602 - val_accuracy: 0.1238 - val_loss: 3.0173 - learning_rate: 1.0000e-04
# Epoch 115/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.7929 - loss: 0.7982 - val_accuracy: 0.1238 - val_loss: 3.0234 - learning_rate: 1.0000e-04
# Epoch 116/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7964 - loss: 0.7857 - val_accuracy: 0.1238 - val_loss: 3.0293 - learning_rate: 1.0000e-04
# Epoch 117/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8117 - loss: 0.7660 - val_accuracy: 0.1238 - val_loss: 3.0352 - learning_rate: 1.0000e-04
# Epoch 118/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8061 - loss: 0.7509 - val_accuracy: 0.1238 - val_loss: 3.0409 - learning_rate: 1.0000e-04
# Epoch 119/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8071 - loss: 0.7413 - val_accuracy: 0.1238 - val_loss: 3.0466 - learning_rate: 1.0000e-04
# Epoch 120/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8082 - loss: 0.7553 - val_accuracy: 0.1238 - val_loss: 3.0523 - learning_rate: 1.0000e-04
# Epoch 121/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7954 - loss: 0.7702 - val_accuracy: 0.1238 - val_loss: 3.0580 - learning_rate: 1.0000e-04
# Epoch 122/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8153 - loss: 0.7373 - val_accuracy: 0.1238 - val_loss: 3.0638 - learning_rate: 1.0000e-04
# Epoch 123/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8184 - loss: 0.7212 - val_accuracy: 0.1238 - val_loss: 3.0692 - learning_rate: 1.0000e-04
# Epoch 124/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.8219 - loss: 0.7199 - val_accuracy: 0.1238 - val_loss: 3.0741 - learning_rate: 1.0000e-04
# Epoch 125/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8265 - loss: 0.7190 - val_accuracy: 0.1238 - val_loss: 3.0790 - learning_rate: 1.0000e-04
# Epoch 126/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8260 - loss: 0.7163 - val_accuracy: 0.1238 - val_loss: 3.0845 - learning_rate: 1.0000e-04
# Epoch 127/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8352 - loss: 0.7054 - val_accuracy: 0.1238 - val_loss: 3.0897 - learning_rate: 1.0000e-04
# Epoch 128/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8133 - loss: 0.7286 - val_accuracy: 0.1238 - val_loss: 3.0948 - learning_rate: 1.0000e-04
# Epoch 129/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8281 - loss: 0.6890 - val_accuracy: 0.1238 - val_loss: 3.0994 - learning_rate: 1.0000e-04
# Epoch 130/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8327 - loss: 0.6875 - val_accuracy: 0.1238 - val_loss: 3.1038 - learning_rate: 1.0000e-04
# Epoch 131/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8342 - loss: 0.6865 - val_accuracy: 0.1238 - val_loss: 3.1085 - learning_rate: 1.0000e-04
# Epoch 132/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8158 - loss: 0.7195 - val_accuracy: 0.1238 - val_loss: 3.1131 - learning_rate: 1.0000e-04
# Epoch 133/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8352 - loss: 0.6764 - val_accuracy: 0.1238 - val_loss: 3.1175 - learning_rate: 1.0000e-04
# Epoch 134/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8230 - loss: 0.6815 - val_accuracy: 0.1238 - val_loss: 3.1213 - learning_rate: 1.0000e-04
# Epoch 135/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8408 - loss: 0.6621 - val_accuracy: 0.1238 - val_loss: 3.1239 - learning_rate: 1.0000e-04
# Epoch 136/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8464 - loss: 0.6375 - val_accuracy: 0.1238 - val_loss: 3.1270 - learning_rate: 1.0000e-04
# Epoch 137/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8449 - loss: 0.6558 - val_accuracy: 0.1238 - val_loss: 3.1290 - learning_rate: 1.0000e-04
# Epoch 138/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8393 - loss: 0.6469 - val_accuracy: 0.1238 - val_loss: 3.1310 - learning_rate: 1.0000e-04
# Epoch 139/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8429 - loss: 0.6346 - val_accuracy: 0.1238 - val_loss: 3.1336 - learning_rate: 1.0000e-04
# Epoch 140/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8423 - loss: 0.6525 - val_accuracy: 0.1238 - val_loss: 3.1367 - learning_rate: 1.0000e-04
# Epoch 141/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.8500 - loss: 0.6279 - val_accuracy: 0.1238 - val_loss: 3.1401 - learning_rate: 1.0000e-04
# Epoch 142/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8612 - loss: 0.6016 - val_accuracy: 0.1238 - val_loss: 3.1435 - learning_rate: 1.0000e-04
# Epoch 143/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8520 - loss: 0.6172 - val_accuracy: 0.1238 - val_loss: 3.1479 - learning_rate: 1.0000e-04
# Epoch 144/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8531 - loss: 0.6015 - val_accuracy: 0.1238 - val_loss: 3.1520 - learning_rate: 1.0000e-04
# Epoch 145/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8423 - loss: 0.6181 - val_accuracy: 0.1238 - val_loss: 3.1570 - learning_rate: 1.0000e-04
# Epoch 146/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8546 - loss: 0.5971 - val_accuracy: 0.1238 - val_loss: 3.1618 - learning_rate: 1.0000e-04
# Epoch 147/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8633 - loss: 0.5925 - val_accuracy: 0.1250 - val_loss: 3.1665 - learning_rate: 1.0000e-04
# Epoch 148/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8638 - loss: 0.5882 - val_accuracy: 0.1250 - val_loss: 3.1713 - learning_rate: 1.0000e-04
# Epoch 149/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8694 - loss: 0.5795 - val_accuracy: 0.1250 - val_loss: 3.1767 - learning_rate: 1.0000e-04
# Epoch 150/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8663 - loss: 0.5641 - val_accuracy: 0.1250 - val_loss: 3.1806 - learning_rate: 1.0000e-04
# Epoch 151/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8653 - loss: 0.5899 - val_accuracy: 0.1250 - val_loss: 3.1852 - learning_rate: 1.0000e-04
# Epoch 152/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.8730 - loss: 0.5725 - val_accuracy: 0.1250 - val_loss: 3.1895 - learning_rate: 1.0000e-04
# Epoch 153/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8745 - loss: 0.5639 - val_accuracy: 0.1250 - val_loss: 3.1946 - learning_rate: 1.0000e-04
# Epoch 154/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8673 - loss: 0.5581 - val_accuracy: 0.1250 - val_loss: 3.2001 - learning_rate: 1.0000e-04
# Epoch 155/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.8730 - loss: 0.5659 - val_accuracy: 0.1250 - val_loss: 3.2052 - learning_rate: 1.0000e-04
# Epoch 156/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8663 - loss: 0.5610 - val_accuracy: 0.1250 - val_loss: 3.2106 - learning_rate: 1.0000e-04
# Epoch 157/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8714 - loss: 0.5747 - val_accuracy: 0.1250 - val_loss: 3.2152 - learning_rate: 1.0000e-04
# Epoch 158/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8724 - loss: 0.5603 - val_accuracy: 0.1250 - val_loss: 3.2197 - learning_rate: 1.0000e-04
# Epoch 159/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8796 - loss: 0.5390 - val_accuracy: 0.1250 - val_loss: 3.2234 - learning_rate: 1.0000e-04
# Epoch 160/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8760 - loss: 0.5516 - val_accuracy: 0.1250 - val_loss: 3.2279 - learning_rate: 1.0000e-04
# Epoch 161/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8765 - loss: 0.5512 - val_accuracy: 0.1250 - val_loss: 3.2319 - learning_rate: 1.0000e-04
# Epoch 162/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8745 - loss: 0.5439 - val_accuracy: 0.1250 - val_loss: 3.2363 - learning_rate: 1.0000e-04
# Epoch 163/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.8724 - loss: 0.5473 - val_accuracy: 0.1250 - val_loss: 3.2407 - learning_rate: 1.0000e-04
# Epoch 164/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8821 - loss: 0.5270 - val_accuracy: 0.1250 - val_loss: 3.2449 - learning_rate: 1.0000e-04
# Epoch 165/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8781 - loss: 0.5234 - val_accuracy: 0.1250 - val_loss: 3.2490 - learning_rate: 1.0000e-04
# Epoch 166/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8913 - loss: 0.5082 - val_accuracy: 0.1250 - val_loss: 3.2533 - learning_rate: 1.0000e-04
# Epoch 167/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8842 - loss: 0.5069 - val_accuracy: 0.1250 - val_loss: 3.2572 - learning_rate: 1.0000e-04
# Epoch 168/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8796 - loss: 0.5149 - val_accuracy: 0.1250 - val_loss: 3.2612 - learning_rate: 1.0000e-04
# Epoch 169/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8862 - loss: 0.5197 - val_accuracy: 0.1250 - val_loss: 3.2658 - learning_rate: 1.0000e-04
# Epoch 170/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.8872 - loss: 0.5213 - val_accuracy: 0.1250 - val_loss: 3.2703 - learning_rate: 1.0000e-04
# Epoch 171/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8990 - loss: 0.4819 - val_accuracy: 0.1250 - val_loss: 3.2744 - learning_rate: 1.0000e-04
# Epoch 172/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8949 - loss: 0.4833 - val_accuracy: 0.1250 - val_loss: 3.2776 - learning_rate: 1.0000e-04
# Epoch 173/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8883 - loss: 0.4965 - val_accuracy: 0.1250 - val_loss: 3.2795 - learning_rate: 1.0000e-04
# Epoch 174/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8995 - loss: 0.4814 - val_accuracy: 0.1250 - val_loss: 3.2821 - learning_rate: 1.0000e-04
# Epoch 175/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8969 - loss: 0.4858 - val_accuracy: 0.1250 - val_loss: 3.2846 - learning_rate: 1.0000e-04
# Epoch 176/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8923 - loss: 0.4908 - val_accuracy: 0.1250 - val_loss: 3.2858 - learning_rate: 1.0000e-04
# Epoch 177/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8842 - loss: 0.5045 - val_accuracy: 0.1250 - val_loss: 3.2870 - learning_rate: 1.0000e-04
# Epoch 178/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8939 - loss: 0.4819 - val_accuracy: 0.1250 - val_loss: 3.2883 - learning_rate: 1.0000e-04
# Epoch 179/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9000 - loss: 0.4485 - val_accuracy: 0.1250 - val_loss: 3.2886 - learning_rate: 1.0000e-04
# Epoch 180/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8980 - loss: 0.4654 - val_accuracy: 0.1250 - val_loss: 3.2886 - learning_rate: 1.0000e-04
# Epoch 181/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9066 - loss: 0.4615 - val_accuracy: 0.1250 - val_loss: 3.2889 - learning_rate: 1.0000e-04
# Epoch 182/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9051 - loss: 0.4646 - val_accuracy: 0.1250 - val_loss: 3.2871 - learning_rate: 1.0000e-04
# Epoch 183/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9071 - loss: 0.4518 - val_accuracy: 0.1250 - val_loss: 3.2866 - learning_rate: 1.0000e-04
# Epoch 184/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9000 - loss: 0.4678 - val_accuracy: 0.1250 - val_loss: 3.2865 - learning_rate: 1.0000e-04
# Epoch 185/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9077 - loss: 0.4416 - val_accuracy: 0.1250 - val_loss: 3.2854 - learning_rate: 5.0000e-05
# Epoch 186/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8980 - loss: 0.4693 - val_accuracy: 0.1250 - val_loss: 3.2843 - learning_rate: 5.0000e-05
# Epoch 187/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9015 - loss: 0.4554 - val_accuracy: 0.1250 - val_loss: 3.2835 - learning_rate: 5.0000e-05
# Epoch 188/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8944 - loss: 0.4632 - val_accuracy: 0.1250 - val_loss: 3.2829 - learning_rate: 5.0000e-05
# Epoch 189/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9077 - loss: 0.4494 - val_accuracy: 0.1250 - val_loss: 3.2827 - learning_rate: 5.0000e-05
# Epoch 190/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9087 - loss: 0.4442 - val_accuracy: 0.1250 - val_loss: 3.2819 - learning_rate: 5.0000e-05
# Epoch 191/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9133 - loss: 0.4392 - val_accuracy: 0.1250 - val_loss: 3.2803 - learning_rate: 5.0000e-05
# Epoch 192/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9046 - loss: 0.4604 - val_accuracy: 0.1250 - val_loss: 3.2789 - learning_rate: 5.0000e-05
# Epoch 193/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9000 - loss: 0.4563 - val_accuracy: 0.1250 - val_loss: 3.2772 - learning_rate: 5.0000e-05
# Epoch 194/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9036 - loss: 0.4374 - val_accuracy: 0.1250 - val_loss: 3.2755 - learning_rate: 5.0000e-05
# Epoch 195/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9143 - loss: 0.4290 - val_accuracy: 0.1250 - val_loss: 3.2738 - learning_rate: 5.0000e-05
# Epoch 196/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9061 - loss: 0.4381 - val_accuracy: 0.1250 - val_loss: 3.2726 - learning_rate: 5.0000e-05
# Epoch 197/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9031 - loss: 0.4474 - val_accuracy: 0.1250 - val_loss: 3.2715 - learning_rate: 5.0000e-05
# Epoch 198/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9077 - loss: 0.4312 - val_accuracy: 0.1250 - val_loss: 3.2711 - learning_rate: 5.0000e-05
# Epoch 199/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9158 - loss: 0.4417 - val_accuracy: 0.1250 - val_loss: 3.2703 - learning_rate: 5.0000e-05
# Epoch 200/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8985 - loss: 0.4432 - val_accuracy: 0.1250 - val_loss: 3.2691 - learning_rate: 5.0000e-05
# Epoch 201/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9112 - loss: 0.4277 - val_accuracy: 0.1250 - val_loss: 3.2679 - learning_rate: 2.5000e-05
# Epoch 202/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8980 - loss: 0.4319 - val_accuracy: 0.1250 - val_loss: 3.2659 - learning_rate: 2.5000e-05
# Epoch 203/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9077 - loss: 0.4421 - val_accuracy: 0.1250 - val_loss: 3.2643 - learning_rate: 2.5000e-05
# Epoch 204/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9087 - loss: 0.4347 - val_accuracy: 0.1250 - val_loss: 3.2626 - learning_rate: 2.5000e-05
# Epoch 205/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9071 - loss: 0.4289 - val_accuracy: 0.1250 - val_loss: 3.2608 - learning_rate: 2.5000e-05
# Epoch 206/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9097 - loss: 0.4305 - val_accuracy: 0.1250 - val_loss: 3.2594 - learning_rate: 2.5000e-05
# Epoch 207/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9061 - loss: 0.4384 - val_accuracy: 0.1250 - val_loss: 3.2574 - learning_rate: 2.5000e-05
# Epoch 208/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9179 - loss: 0.4239 - val_accuracy: 0.1250 - val_loss: 3.2558 - learning_rate: 2.5000e-05
# Epoch 209/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9163 - loss: 0.4196 - val_accuracy: 0.1250 - val_loss: 3.2541 - learning_rate: 2.5000e-05
# Epoch 210/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9071 - loss: 0.4381 - val_accuracy: 0.1250 - val_loss: 3.2523 - learning_rate: 2.5000e-05
# Epoch 211/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9102 - loss: 0.4339 - val_accuracy: 0.1250 - val_loss: 3.2511 - learning_rate: 2.5000e-05
# Epoch 212/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9158 - loss: 0.4227 - val_accuracy: 0.1250 - val_loss: 3.2498 - learning_rate: 2.5000e-05
# Epoch 213/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9010 - loss: 0.4582 - val_accuracy: 0.1250 - val_loss: 3.2483 - learning_rate: 2.5000e-05
# Epoch 214/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9112 - loss: 0.4362 - val_accuracy: 0.1250 - val_loss: 3.2470 - learning_rate: 2.5000e-05
# Epoch 215/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9148 - loss: 0.4227 - val_accuracy: 0.1250 - val_loss: 3.2448 - learning_rate: 1.2500e-05
# Epoch 216/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9122 - loss: 0.4257 - val_accuracy: 0.1250 - val_loss: 3.2421 - learning_rate: 1.2500e-05
# Epoch 217/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9209 - loss: 0.4098 - val_accuracy: 0.1250 - val_loss: 3.2395 - learning_rate: 1.2500e-05
# Epoch 218/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9087 - loss: 0.4171 - val_accuracy: 0.1250 - val_loss: 3.2364 - learning_rate: 1.2500e-05
# Epoch 219/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9122 - loss: 0.4251 - val_accuracy: 0.1250 - val_loss: 3.2333 - learning_rate: 1.2500e-05
# Epoch 220/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9087 - loss: 0.4104 - val_accuracy: 0.1250 - val_loss: 3.2306 - learning_rate: 1.2500e-05
# Epoch 221/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9061 - loss: 0.4432 - val_accuracy: 0.1250 - val_loss: 3.2278 - learning_rate: 1.2500e-05
# Epoch 222/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9199 - loss: 0.4234 - val_accuracy: 0.1250 - val_loss: 3.2245 - learning_rate: 1.2500e-05
# Epoch 223/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9148 - loss: 0.4197 - val_accuracy: 0.1250 - val_loss: 3.2212 - learning_rate: 1.2500e-05
# Epoch 224/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9163 - loss: 0.4190 - val_accuracy: 0.1250 - val_loss: 3.2181 - learning_rate: 6.2500e-06
# Epoch 225/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9056 - loss: 0.4376 - val_accuracy: 0.1250 - val_loss: 3.2147 - learning_rate: 6.2500e-06
# Epoch 226/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9112 - loss: 0.4190 - val_accuracy: 0.1250 - val_loss: 3.2114 - learning_rate: 6.2500e-06
# Epoch 227/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9143 - loss: 0.4283 - val_accuracy: 0.1250 - val_loss: 3.2078 - learning_rate: 6.2500e-06
# Epoch 228/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9265 - loss: 0.4041 - val_accuracy: 0.1250 - val_loss: 3.2042 - learning_rate: 6.2500e-06
# Epoch 229/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9128 - loss: 0.4267 - val_accuracy: 0.1250 - val_loss: 3.2007 - learning_rate: 6.2500e-06
# Epoch 230/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9133 - loss: 0.4224 - val_accuracy: 0.1250 - val_loss: 3.1973 - learning_rate: 6.2500e-06
# Epoch 231/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9153 - loss: 0.4015 - val_accuracy: 0.1250 - val_loss: 3.1937 - learning_rate: 6.2500e-06
# Epoch 232/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9219 - loss: 0.3894 - val_accuracy: 0.1250 - val_loss: 3.1902 - learning_rate: 6.2500e-06
# Epoch 233/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9107 - loss: 0.4256 - val_accuracy: 0.1250 - val_loss: 3.1868 - learning_rate: 6.2500e-06
# Epoch 234/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9153 - loss: 0.4225 - val_accuracy: 0.1250 - val_loss: 3.1831 - learning_rate: 6.2500e-06
# Epoch 235/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9153 - loss: 0.4209 - val_accuracy: 0.1250 - val_loss: 3.1794 - learning_rate: 6.2500e-06
# Epoch 236/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9179 - loss: 0.4106 - val_accuracy: 0.1250 - val_loss: 3.1755 - learning_rate: 6.2500e-06
# Epoch 237/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9092 - loss: 0.4333 - val_accuracy: 0.1250 - val_loss: 3.1715 - learning_rate: 6.2500e-06
# Epoch 238/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9128 - loss: 0.4107 - val_accuracy: 0.1250 - val_loss: 3.1673 - learning_rate: 5.0000e-06
# Epoch 239/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9281 - loss: 0.3878 - val_accuracy: 0.1250 - val_loss: 3.1633 - learning_rate: 5.0000e-06
# Epoch 240/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9138 - loss: 0.4159 - val_accuracy: 0.1250 - val_loss: 3.1593 - learning_rate: 5.0000e-06
# Epoch 241/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9158 - loss: 0.4104 - val_accuracy: 0.1250 - val_loss: 3.1556 - learning_rate: 5.0000e-06
# Epoch 242/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9194 - loss: 0.4082 - val_accuracy: 0.1250 - val_loss: 3.1512 - learning_rate: 5.0000e-06
# Epoch 243/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9112 - loss: 0.4238 - val_accuracy: 0.1250 - val_loss: 3.1473 - learning_rate: 5.0000e-06
# Epoch 244/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9230 - loss: 0.3988 - val_accuracy: 0.1250 - val_loss: 3.1432 - learning_rate: 5.0000e-06
# Epoch 245/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9199 - loss: 0.4037 - val_accuracy: 0.1250 - val_loss: 3.1388 - learning_rate: 5.0000e-06
# Epoch 246/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9194 - loss: 0.4056 - val_accuracy: 0.1250 - val_loss: 3.1343 - learning_rate: 5.0000e-06
# Epoch 247/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9148 - loss: 0.4176 - val_accuracy: 0.1250 - val_loss: 3.1298 - learning_rate: 5.0000e-06
# Epoch 248/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9087 - loss: 0.4206 - val_accuracy: 0.1250 - val_loss: 3.1251 - learning_rate: 5.0000e-06
# Epoch 249/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9189 - loss: 0.4200 - val_accuracy: 0.1250 - val_loss: 3.1205 - learning_rate: 5.0000e-06
# Epoch 250/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9138 - loss: 0.4160 - val_accuracy: 0.1262 - val_loss: 3.1159 - learning_rate: 5.0000e-06
# Epoch 251/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9056 - loss: 0.4292 - val_accuracy: 0.1262 - val_loss: 3.1114 - learning_rate: 5.0000e-06
# Epoch 252/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9184 - loss: 0.3987 - val_accuracy: 0.1262 - val_loss: 3.1068 - learning_rate: 5.0000e-06
# Epoch 253/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9179 - loss: 0.4156 - val_accuracy: 0.1262 - val_loss: 3.1018 - learning_rate: 5.0000e-06
# Epoch 254/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9240 - loss: 0.4072 - val_accuracy: 0.1262 - val_loss: 3.0969 - learning_rate: 5.0000e-06
# Epoch 255/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9107 - loss: 0.4208 - val_accuracy: 0.1262 - val_loss: 3.0920 - learning_rate: 5.0000e-06
# Epoch 256/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9158 - loss: 0.4061 - val_accuracy: 0.1262 - val_loss: 3.0870 - learning_rate: 5.0000e-06
# Epoch 257/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9143 - loss: 0.4110 - val_accuracy: 0.1262 - val_loss: 3.0817 - learning_rate: 5.0000e-06
# Epoch 258/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9179 - loss: 0.4050 - val_accuracy: 0.1262 - val_loss: 3.0768 - learning_rate: 5.0000e-06
# Epoch 259/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9189 - loss: 0.4177 - val_accuracy: 0.1262 - val_loss: 3.0716 - learning_rate: 5.0000e-06
# Epoch 260/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9168 - loss: 0.4107 - val_accuracy: 0.1262 - val_loss: 3.0662 - learning_rate: 5.0000e-06
# Epoch 261/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9168 - loss: 0.4107 - val_accuracy: 0.1262 - val_loss: 3.0609 - learning_rate: 5.0000e-06
# Epoch 262/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9204 - loss: 0.4160 - val_accuracy: 0.1262 - val_loss: 3.0554 - learning_rate: 5.0000e-06
# Epoch 263/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9250 - loss: 0.4016 - val_accuracy: 0.1262 - val_loss: 3.0498 - learning_rate: 5.0000e-06
# Epoch 264/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9204 - loss: 0.4045 - val_accuracy: 0.1262 - val_loss: 3.0442 - learning_rate: 5.0000e-06
# Epoch 265/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9199 - loss: 0.4110 - val_accuracy: 0.1262 - val_loss: 3.0383 - learning_rate: 5.0000e-06
# Epoch 266/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9184 - loss: 0.4112 - val_accuracy: 0.1274 - val_loss: 3.0324 - learning_rate: 5.0000e-06
# Epoch 267/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9204 - loss: 0.4071 - val_accuracy: 0.1274 - val_loss: 3.0268 - learning_rate: 5.0000e-06
# Epoch 268/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9143 - loss: 0.4096 - val_accuracy: 0.1274 - val_loss: 3.0209 - learning_rate: 5.0000e-06
# Epoch 269/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9199 - loss: 0.4015 - val_accuracy: 0.1286 - val_loss: 3.0150 - learning_rate: 5.0000e-06
# Epoch 270/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9133 - loss: 0.4243 - val_accuracy: 0.1286 - val_loss: 3.0092 - learning_rate: 5.0000e-06
# Epoch 271/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9153 - loss: 0.4179 - val_accuracy: 0.1286 - val_loss: 3.0030 - learning_rate: 5.0000e-06
# Epoch 272/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9184 - loss: 0.4131 - val_accuracy: 0.1286 - val_loss: 2.9970 - learning_rate: 5.0000e-06
# Epoch 273/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9163 - loss: 0.4196 - val_accuracy: 0.1286 - val_loss: 2.9904 - learning_rate: 5.0000e-06
# Epoch 274/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9194 - loss: 0.4031 - val_accuracy: 0.1286 - val_loss: 2.9842 - learning_rate: 5.0000e-06
# Epoch 275/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9179 - loss: 0.3980 - val_accuracy: 0.1298 - val_loss: 2.9775 - learning_rate: 5.0000e-06
# Epoch 276/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9224 - loss: 0.4157 - val_accuracy: 0.1298 - val_loss: 2.9713 - learning_rate: 5.0000e-06
# Epoch 277/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9163 - loss: 0.3998 - val_accuracy: 0.1310 - val_loss: 2.9652 - learning_rate: 5.0000e-06
# Epoch 278/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9153 - loss: 0.3977 - val_accuracy: 0.1333 - val_loss: 2.9586 - learning_rate: 5.0000e-06
# Epoch 279/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9168 - loss: 0.4024 - val_accuracy: 0.1333 - val_loss: 2.9520 - learning_rate: 5.0000e-06
# Epoch 280/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9204 - loss: 0.4112 - val_accuracy: 0.1333 - val_loss: 2.9454 - learning_rate: 5.0000e-06
# Epoch 281/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9087 - loss: 0.4250 - val_accuracy: 0.1333 - val_loss: 2.9387 - learning_rate: 5.0000e-06
# Epoch 282/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9204 - loss: 0.4058 - val_accuracy: 0.1345 - val_loss: 2.9318 - learning_rate: 5.0000e-06
# Epoch 283/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9092 - loss: 0.4186 - val_accuracy: 0.1345 - val_loss: 2.9250 - learning_rate: 5.0000e-06
# Epoch 284/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9194 - loss: 0.4086 - val_accuracy: 0.1357 - val_loss: 2.9180 - learning_rate: 5.0000e-06
# Epoch 285/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9066 - loss: 0.4199 - val_accuracy: 0.1369 - val_loss: 2.9110 - learning_rate: 5.0000e-06
# Epoch 286/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9158 - loss: 0.4003 - val_accuracy: 0.1369 - val_loss: 2.9037 - learning_rate: 5.0000e-06
# Epoch 287/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9199 - loss: 0.3995 - val_accuracy: 0.1417 - val_loss: 2.8967 - learning_rate: 5.0000e-06
# Epoch 288/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9158 - loss: 0.3982 - val_accuracy: 0.1429 - val_loss: 2.8898 - learning_rate: 5.0000e-06
# Epoch 289/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9240 - loss: 0.4026 - val_accuracy: 0.1452 - val_loss: 2.8828 - learning_rate: 5.0000e-06
# Epoch 290/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9204 - loss: 0.4054 - val_accuracy: 0.1476 - val_loss: 2.8757 - learning_rate: 5.0000e-06
# Epoch 291/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9173 - loss: 0.4069 - val_accuracy: 0.1476 - val_loss: 2.8683 - learning_rate: 5.0000e-06
# Epoch 292/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.9061 - loss: 0.4430 - val_accuracy: 0.1476 - val_loss: 2.8612 - learning_rate: 5.0000e-06
# Epoch 293/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9184 - loss: 0.4076 - val_accuracy: 0.1476 - val_loss: 2.8541 - learning_rate: 5.0000e-06
# Epoch 294/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9133 - loss: 0.4060 - val_accuracy: 0.1476 - val_loss: 2.8468 - learning_rate: 5.0000e-06
# Epoch 295/400
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9750 - loss: 0.1656 - val_accuracy: 0.9452 - val_loss: 0.1843 - learning_rate: 5.0000e-06
# Epoch 400/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9827 - loss: 0.1522 - val_accuracy: 0.9464 - val_loss: 0.1843 - learning_rate: 5.0000e-06
# Epoch 401/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9832 - loss: 0.1562 - val_accuracy: 0.9464 - val_loss: 0.1842 - learning_rate: 5.0000e-06
# Epoch 402/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9827 - loss: 0.1510 - val_accuracy: 0.9476 - val_loss: 0.1841 - learning_rate: 5.0000e-06
# Epoch 403/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9847 - loss: 0.1561 - val_accuracy: 0.9476 - val_loss: 0.1841 - learning_rate: 5.0000e-06
# Epoch 404/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9791 - loss: 0.1571 - val_accuracy: 0.9476 - val_loss: 0.1840 - learning_rate: 5.0000e-06
# Epoch 405/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9816 - loss: 0.1604 - val_accuracy: 0.9476 - val_loss: 0.1839 - learning_rate: 5.0000e-06
# Epoch 406/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9786 - loss: 0.1582 - val_accuracy: 0.9476 - val_loss: 0.1839 - learning_rate: 5.0000e-06
# Epoch 407/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9796 - loss: 0.1595 - val_accuracy: 0.9476 - val_loss: 0.1838 - learning_rate: 5.0000e-06
# Epoch 408/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9796 - loss: 0.1555 - val_accuracy: 0.9476 - val_loss: 0.1837 - learning_rate: 5.0000e-06
# Epoch 409/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9755 - loss: 0.1644 - val_accuracy: 0.9476 - val_loss: 0.1836 - learning_rate: 5.0000e-06
# Epoch 410/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9796 - loss: 0.1621 - val_accuracy: 0.9476 - val_loss: 0.1836 - learning_rate: 5.0000e-06
# Epoch 411/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9791 - loss: 0.1491 - val_accuracy: 0.9476 - val_loss: 0.1835 - learning_rate: 5.0000e-06
# Epoch 412/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9816 - loss: 0.1562 - val_accuracy: 0.9488 - val_loss: 0.1834 - learning_rate: 5.0000e-06
# Epoch 413/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9770 - loss: 0.1675 - val_accuracy: 0.9488 - val_loss: 0.1833 - learning_rate: 5.0000e-06
# Epoch 414/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9745 - loss: 0.1740 - val_accuracy: 0.9476 - val_loss: 0.1832 - learning_rate: 5.0000e-06
# Epoch 415/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9796 - loss: 0.1568 - val_accuracy: 0.9476 - val_loss: 0.1831 - learning_rate: 5.0000e-06
# Epoch 416/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9791 - loss: 0.1546 - val_accuracy: 0.9476 - val_loss: 0.1830 - learning_rate: 5.0000e-06
# Epoch 417/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9735 - loss: 0.1659 - val_accuracy: 0.9476 - val_loss: 0.1829 - learning_rate: 5.0000e-06
# Epoch 418/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9750 - loss: 0.1648 - val_accuracy: 0.9476 - val_loss: 0.1828 - learning_rate: 5.0000e-06
# Epoch 419/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9806 - loss: 0.1572 - val_accuracy: 0.9476 - val_loss: 0.1827 - learning_rate: 5.0000e-06
# Epoch 420/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9801 - loss: 0.1487 - val_accuracy: 0.9488 - val_loss: 0.1826 - learning_rate: 5.0000e-06
# Epoch 421/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9781 - loss: 0.1640 - val_accuracy: 0.9464 - val_loss: 0.1825 - learning_rate: 5.0000e-06
# Epoch 422/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.9816 - loss: 0.1614 - val_accuracy: 0.9464 - val_loss: 0.1824 - learning_rate: 5.0000e-06
# Epoch 423/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9755 - loss: 0.1626 - val_accuracy: 0.9464 - val_loss: 0.1824 - learning_rate: 5.0000e-06
# Epoch 424/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9801 - loss: 0.1531 - val_accuracy: 0.9464 - val_loss: 0.1823 - learning_rate: 5.0000e-06
# Epoch 425/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9781 - loss: 0.1669 - val_accuracy: 0.9464 - val_loss: 0.1822 - learning_rate: 5.0000e-06
# Epoch 426/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9735 - loss: 0.1634 - val_accuracy: 0.9464 - val_loss: 0.1822 - learning_rate: 5.0000e-06
# Epoch 427/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9776 - loss: 0.1567 - val_accuracy: 0.9464 - val_loss: 0.1821 - learning_rate: 5.0000e-06
# Epoch 428/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9786 - loss: 0.1578 - val_accuracy: 0.9464 - val_loss: 0.1821 - learning_rate: 5.0000e-06
# Epoch 429/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9821 - loss: 0.1507 - val_accuracy: 0.9464 - val_loss: 0.1820 - learning_rate: 5.0000e-06
# Epoch 430/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9791 - loss: 0.1528 - val_accuracy: 0.9464 - val_loss: 0.1820 - learning_rate: 5.0000e-06
# Epoch 431/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9821 - loss: 0.1541 - val_accuracy: 0.9464 - val_loss: 0.1819 - learning_rate: 5.0000e-06
# Epoch 432/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9816 - loss: 0.1577 - val_accuracy: 0.9464 - val_loss: 0.1818 - learning_rate: 5.0000e-06
# Epoch 433/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9867 - loss: 0.1476 - val_accuracy: 0.9464 - val_loss: 0.1817 - learning_rate: 5.0000e-06
# Epoch 434/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9781 - loss: 0.1599 - val_accuracy: 0.9464 - val_loss: 0.1816 - learning_rate: 5.0000e-06
# Epoch 435/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9827 - loss: 0.1506 - val_accuracy: 0.9464 - val_loss: 0.1816 - learning_rate: 5.0000e-06
# Epoch 436/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9765 - loss: 0.1588 - val_accuracy: 0.9464 - val_loss: 0.1815 - learning_rate: 5.0000e-06
# Epoch 437/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9827 - loss: 0.1545 - val_accuracy: 0.9464 - val_loss: 0.1814 - learning_rate: 5.0000e-06
# Epoch 438/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9796 - loss: 0.1676 - val_accuracy: 0.9464 - val_loss: 0.1813 - learning_rate: 5.0000e-06
# Epoch 439/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9811 - loss: 0.1483 - val_accuracy: 0.9464 - val_loss: 0.1813 - learning_rate: 5.0000e-06
# Epoch 440/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9776 - loss: 0.1647 - val_accuracy: 0.9464 - val_loss: 0.1811 - learning_rate: 5.0000e-06
# Epoch 441/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9811 - loss: 0.1578 - val_accuracy: 0.9464 - val_loss: 0.1811 - learning_rate: 5.0000e-06
# Epoch 442/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.9888 - loss: 0.1462 - val_accuracy: 0.9464 - val_loss: 0.1810 - learning_rate: 5.0000e-06
# Epoch 443/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9750 - loss: 0.1658 - val_accuracy: 0.9464 - val_loss: 0.1809 - learning_rate: 5.0000e-06
# Epoch 444/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9765 - loss: 0.1589 - val_accuracy: 0.9452 - val_loss: 0.1808 - learning_rate: 5.0000e-06
# Epoch 445/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9770 - loss: 0.1599 - val_accuracy: 0.9452 - val_loss: 0.1807 - learning_rate: 5.0000e-06
# Epoch 446/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9821 - loss: 0.1594 - val_accuracy: 0.9464 - val_loss: 0.1807 - learning_rate: 5.0000e-06
# Epoch 447/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9791 - loss: 0.1611 - val_accuracy: 0.9476 - val_loss: 0.1806 - learning_rate: 5.0000e-06
# Epoch 448/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9770 - loss: 0.1577 - val_accuracy: 0.9476 - val_loss: 0.1806 - learning_rate: 5.0000e-06
# Epoch 449/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9791 - loss: 0.1546 - val_accuracy: 0.9464 - val_loss: 0.1806 - learning_rate: 5.0000e-06
# Epoch 450/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9811 - loss: 0.1670 - val_accuracy: 0.9464 - val_loss: 0.1806 - learning_rate: 5.0000e-06
# Epoch 451/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9801 - loss: 0.1647 - val_accuracy: 0.9476 - val_loss: 0.1806 - learning_rate: 5.0000e-06
# Epoch 452/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9821 - loss: 0.1531 - val_accuracy: 0.9476 - val_loss: 0.1806 - learning_rate: 5.0000e-06
# Epoch 453/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9847 - loss: 0.1615 - val_accuracy: 0.9476 - val_loss: 0.1806 - learning_rate: 5.0000e-06
# Epoch 454/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9760 - loss: 0.1712 - val_accuracy: 0.9476 - val_loss: 0.1806 - learning_rate: 5.0000e-06
# Epoch 455/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9760 - loss: 0.1650 - val_accuracy: 0.9476 - val_loss: 0.1805 - learning_rate: 5.0000e-06
# Epoch 456/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9719 - loss: 0.1708 - val_accuracy: 0.9476 - val_loss: 0.1805 - learning_rate: 5.0000e-06
# Epoch 457/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9765 - loss: 0.1720 - val_accuracy: 0.9476 - val_loss: 0.1804 - learning_rate: 5.0000e-06
# Epoch 458/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9837 - loss: 0.1489 - val_accuracy: 0.9476 - val_loss: 0.1803 - learning_rate: 5.0000e-06
# Epoch 459/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9796 - loss: 0.1585 - val_accuracy: 0.9476 - val_loss: 0.1803 - learning_rate: 5.0000e-06
# Epoch 460/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9801 - loss: 0.1592 - val_accuracy: 0.9476 - val_loss: 0.1802 - learning_rate: 5.0000e-06
# Epoch 461/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9760 - loss: 0.1574 - val_accuracy: 0.9476 - val_loss: 0.1802 - learning_rate: 5.0000e-06
# Epoch 462/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9776 - loss: 0.1599 - val_accuracy: 0.9488 - val_loss: 0.1802 - learning_rate: 5.0000e-06
# Epoch 463/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9796 - loss: 0.1446 - val_accuracy: 0.9488 - val_loss: 0.1802 - learning_rate: 5.0000e-06
# Epoch 464/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9862 - loss: 0.1534 - val_accuracy: 0.9488 - val_loss: 0.1802 - learning_rate: 5.0000e-06
# Epoch 465/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9786 - loss: 0.1592 - val_accuracy: 0.9488 - val_loss: 0.1801 - learning_rate: 5.0000e-06
# Epoch 466/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9750 - loss: 0.1634 - val_accuracy: 0.9488 - val_loss: 0.1801 - learning_rate: 5.0000e-06
# Epoch 467/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9801 - loss: 0.1595 - val_accuracy: 0.9488 - val_loss: 0.1800 - learning_rate: 5.0000e-06
# Epoch 468/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9770 - loss: 0.1556 - val_accuracy: 0.9488 - val_loss: 0.1800 - learning_rate: 5.0000e-06
# Epoch 469/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9832 - loss: 0.1609 - val_accuracy: 0.9488 - val_loss: 0.1799 - learning_rate: 5.0000e-06
# Epoch 470/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9745 - loss: 0.1602 - val_accuracy: 0.9488 - val_loss: 0.1799 - learning_rate: 5.0000e-06
# Epoch 471/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9827 - loss: 0.1523 - val_accuracy: 0.9488 - val_loss: 0.1799 - learning_rate: 5.0000e-06
# Epoch 472/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9821 - loss: 0.1551 - val_accuracy: 0.9488 - val_loss: 0.1798 - learning_rate: 5.0000e-06
# Epoch 473/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9796 - loss: 0.1596 - val_accuracy: 0.9488 - val_loss: 0.1798 - learning_rate: 5.0000e-06
# Epoch 474/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9796 - loss: 0.1479 - val_accuracy: 0.9488 - val_loss: 0.1797 - learning_rate: 5.0000e-06
# Epoch 475/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9801 - loss: 0.1513 - val_accuracy: 0.9488 - val_loss: 0.1796 - learning_rate: 5.0000e-06
# Epoch 476/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9811 - loss: 0.1517 - val_accuracy: 0.9476 - val_loss: 0.1796 - learning_rate: 5.0000e-06
# Epoch 477/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.9827 - loss: 0.1490 - val_accuracy: 0.9476 - val_loss: 0.1796 - learning_rate: 5.0000e-06
# Epoch 478/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9786 - loss: 0.1599 - val_accuracy: 0.9476 - val_loss: 0.1795 - learning_rate: 5.0000e-06
# Epoch 479/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9796 - loss: 0.1559 - val_accuracy: 0.9476 - val_loss: 0.1795 - learning_rate: 5.0000e-06
# Epoch 480/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9842 - loss: 0.1598 - val_accuracy: 0.9476 - val_loss: 0.1795 - learning_rate: 5.0000e-06
# Epoch 481/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9816 - loss: 0.1479 - val_accuracy: 0.9476 - val_loss: 0.1794 - learning_rate: 5.0000e-06
# Epoch 482/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.9827 - loss: 0.1528 - val_accuracy: 0.9476 - val_loss: 0.1794 - learning_rate: 5.0000e-06
# Epoch 483/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9806 - loss: 0.1479 - val_accuracy: 0.9476 - val_loss: 0.1793 - learning_rate: 5.0000e-06
# Epoch 484/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9765 - loss: 0.1543 - val_accuracy: 0.9476 - val_loss: 0.1793 - learning_rate: 5.0000e-06
# Epoch 485/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9816 - loss: 0.1466 - val_accuracy: 0.9476 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 486/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9770 - loss: 0.1639 - val_accuracy: 0.9476 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 487/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9832 - loss: 0.1403 - val_accuracy: 0.9476 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 488/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9755 - loss: 0.1645 - val_accuracy: 0.9476 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 489/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9760 - loss: 0.1681 - val_accuracy: 0.9476 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 490/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9811 - loss: 0.1616 - val_accuracy: 0.9476 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 491/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9832 - loss: 0.1475 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 492/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9816 - loss: 0.1533 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 493/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9776 - loss: 0.1539 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 494/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9847 - loss: 0.1429 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 495/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9857 - loss: 0.1476 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 496/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9806 - loss: 0.1607 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 497/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9796 - loss: 0.1579 - val_accuracy: 0.9488 - val_loss: 0.1793 - learning_rate: 5.0000e-06
# Epoch 498/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9781 - loss: 0.1555 - val_accuracy: 0.9476 - val_loss: 0.1793 - learning_rate: 5.0000e-06
# Epoch 499/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9821 - loss: 0.1541 - val_accuracy: 0.9476 - val_loss: 0.1794 - learning_rate: 5.0000e-06
# Epoch 500/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9806 - loss: 0.1616 - val_accuracy: 0.9476 - val_loss: 0.1794 - learning_rate: 5.0000e-06

# %% [markdown]
# 6.Plotting results

# %%
# Plot training & validation accuracy values
# plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Test'])
plt.show()

# %%
Y_pred = DD_Net.predict([X_test_0,X_test_1])
labels = ['Grab', 'Tap', 'Expand', 'Pinch', 'RC', 'RCC', 'SR', 'SL', 'SU', 'SD', 'SX', 'S+', 'SV', 'Shake']

y_true = []
for i in np.argmax(Y_test,axis=1):
    y_true.append(labels[i])

y_pred = []
for i in np.argmax(Y_pred,axis=1):
    y_pred.append(labels[i])

cm_analysis(y_true,y_pred, 'SHREC_14.png', labels, ymap=None, figsize=(8,8))
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step
