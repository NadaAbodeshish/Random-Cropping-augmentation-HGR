# %%
! pip install -q keras

# %%
import numpy as np
import math
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
from tqdm import tqdm
import pickle
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt
from scipy.spatial.distance import cdist

from keras.optimizers import *
from keras.models import Model
from keras.layers import *
# from keras.layers.core import *
# from tensorflow.keras.callbacks import *
# from keras.layers.convolutional import *
from keras import backend as K
import keras
import tensorflow as tf

# import google.colab.files

# %% [markdown]
# 1. Define configurations

# %%
random.seed(1234)

class Config():
    def __init__(self):
        self.frame_l = 32 # the length of frames
        self.joint_n = 12 # the number of joints
        self.joint_n = 22 # the number of joints
        self.joint_d = 3 # the dimension of joints
        self.clc_coarse = 14 # the number of coarse class
        self.clc_fine = 28 # the number of fine-grained class
        self.feat_d = 231
        self.filters = 64
C = Config()

# %% [markdown]
# 2. Define data processing functions

# %%
# Temple resizing function
import numpy as np
import os
import pandas as pd
import random
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

###################################################################################


#Rescale to be 64 frames
def zoom(p,target_l=64,joints_num=25,joints_dim=3):
    l = p.shape[0]
    p_new = np.empty([target_l,joints_num,joints_dim])
    for m in range(joints_num):
        for n in range(joints_dim):
            p[:,m,n] = medfilt(p[:,m,n],3)
            p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
    return p_new

def sampling_frame(p,C):
    full_l = p.shape[0] # full length
    if random.uniform(0,1)<0.5: # aligment sampling
        valid_l = np.round(np.random.uniform(0.9,1)*full_l)
        s = random.randint(0, full_l-int(valid_l))
        e = s+valid_l # sample end point
        p = p[int(s):int(e),:,:]
    else: # without aligment sampling
        valid_l = np.round(np.random.uniform(0.9,1)*full_l)
        index = np.sort(np.random.choice(range(0,full_l),int(valid_l),replace=False))
        p = p[index,:,:]
    p = zoom(p,C.frame_l,C.joint_n,C.joint_d)
    return p

from scipy.spatial.distance import cdist
def get_CG(p,C):
    M = []
    iu = np.triu_indices(C.joint_n,1,C.joint_n)
    for f in range(C.frame_l):
        #distance max
        d_m = cdist(p[f],np.concatenate([p[f],np.zeros([1,C.joint_d])]),'euclidean')
        d_m = d_m[iu]
        M.append(d_m)
    M = np.stack(M)
    return M

def normlize_range(p):
    # normolize to start point, use the center for hand case
    p[:,:,0] = p[:,:,0]-np.mean(p[:,:,0])
    p[:,:,1] = p[:,:,1]-np.mean(p[:,:,1])
    p[:,:,2] = p[:,:,2]-np.mean(p[:,:,2])
    return p

def cm_analysis(y_true, y_pred, filename, labels, ymap=None, figsize=(8,8)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args:
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                #annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
                annot[i, j] = '%.1f' % (p)
            elif c == 0:
                annot[i, j] = ''
            else:
                #annot[i, j] = '%.1f%%\n%d' % (p, c)
                annot[i, j] = '%.1f' % (p)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax, cbar=False, cmap="YlGnBu")
    plt.savefig(filename)

# %% [markdown]
# 3. Define network

# %%
def poses_diff(x):
    H, W = x.get_shape()[1],x.get_shape()[2]
    x = tf.subtract(x[:,1:,...],x[:,:-1,...])
    x = tf.image.resize(x,size=[H,W])
    return x

def pose_motion(P,frame_l):
    P_diff_slow = Lambda(lambda x: poses_diff(x))(P)
    P_diff_slow = Reshape((frame_l,-1))(P_diff_slow)
    P_fast = Lambda(lambda x: x[:,::2,...])(P)
    P_diff_fast = Lambda(lambda x: poses_diff(x))(P_fast)
    P_diff_fast = Reshape((int(frame_l/2),-1))(P_diff_fast)
    return P_diff_slow,P_diff_fast

def c1D(x,filters,kernel):
    x = Conv1D(filters, kernel_size=kernel,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def block(x,filters):
    x = c1D(x,filters,3)
    x = c1D(x,filters,3)
    return x

def d1D(x,filters):
    x = Dense(filters,use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def build_FM(frame_l=32,joint_n=22,joint_d=2,feat_d=231,filters=16):
    M = Input(shape=(frame_l,feat_d))
    P = Input(shape=(frame_l,joint_n,joint_d))

    diff_slow,diff_fast = pose_motion(P,frame_l)

    x = c1D(M,filters*2,1)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,3)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,1)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x_d_slow = c1D(diff_slow,filters*2,1)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,3)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,1)
    x_d_slow = MaxPool1D(2)(x_d_slow)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)

    x_d_fast = c1D(diff_fast,filters*2,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,3)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)

    x = concatenate([x,x_d_slow,x_d_fast])
    x = block(x,filters*2)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*4)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*8)
    x = SpatialDropout1D(0.1)(x)

    return Model(inputs=[M,P],outputs=x)


def build_DD_Net(frame_l=32,joint_n=22,joint_d=3,feat_d=231,clc_num=14,filters=16):
    M = Input(name='M', shape=(frame_l,feat_d))
    P = Input(name='P', shape=(frame_l,joint_n,joint_d))

    FM = build_FM(frame_l,joint_n,joint_d,feat_d,filters)

    x = FM([M,P])

    x = GlobalMaxPool1D()(x)

    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = Dense(clc_num, activation='softmax')(x)

    ######################Self-supervised part
    model = Model(inputs=[M,P],outputs=x)
    return model

# %%
DD_Net = build_DD_Net(C.frame_l,C.joint_n,C.joint_d,C.feat_d,C.clc_coarse,C.filters)
DD_Net.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ M (InputLayer)      │ (None, 32, 231)   │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ P (InputLayer)      │ (None, 32, 22, 3) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_1        │ (None, 4, 512)    │  1,740,160 │ M[0][0], P[0][0]  │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ functional_1[0][… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     65,536 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 128)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ leaky_re_lu_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     16,384 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 128)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ leaky_re_lu_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 14)        │      1,806 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,824,910 (6.96 MB)
#  Trainable params: 1,819,278 (6.94 MB)
#  Non-trainable params: 5,632 (22.00 KB)

# %% [markdown]
# 4. Load dataset (download GT_train_1.pkl and  GT_test_1.pkl from github )

# %%
# !wget https://github.com/fandulu/DD-Net/archive/master.zip
# !unzip master.zip
# !rm master.zip
# Out:
# --2024-12-16 15:51:42--  https://github.com/fandulu/DD-Net/archive/master.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master [following]
# --2024-12-16 15:51:42--  https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: 'master.zip'
#
# master.zip              [            <=>     ]  79.09M  14.1MB/s    in 5.6s
#
# 2024-12-16 15:51:48 (14.1 MB/s) - 'master.zip' saved [82934337]
#
# Archive:  master.zip
# f26a9994b0bafc41096fa269eab89c2757d71499
#    creating: DD-Net-master/
#   inflating: DD-Net-master/.gitignore
#    creating: DD-Net-master/JHMDB/
#   inflating: DD-Net-master/JHMDB/README.md
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_heavy.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_lite.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_middle.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_data_preprocessing.ipynb
#   inflating: DD-Net-master/JHMDB/utils.py
#    creating: DD-Net-master/JHMDB/weights/
#  extracting: DD-Net-master/JHMDB/weights/__init__.py
#   inflating: DD-Net-master/LICENSE
#   inflating: DD-Net-master/README.md
#    creating: DD-Net-master/SHREC/
#   inflating: DD-Net-master/SHREC/README.md
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_lite.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_data_preprocessing.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_lite.ipynb
#    creating: DD-Net-master/SHREC/images/
#   inflating: DD-Net-master/SHREC/images/SHREC_14.png
#   inflating: DD-Net-master/SHREC/images/SHREC_28.png
#   inflating: DD-Net-master/SHREC/utils.py
#    creating: DD-Net-master/SHREC/weights/
#  extracting: DD-Net-master/SHREC/weights/.gitkeep
#  extracting: DD-Net-master/SHREC/weights/__init__.py
#    creating: DD-Net-master/data/
#    creating: DD-Net-master/data/JHMDB/
#   inflating: DD-Net-master/data/JHMDB/GT_test_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_3.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_3.pkl
#   inflating: DD-Net-master/data/JHMDB/joint_positions.zip
#   inflating: DD-Net-master/data/JHMDB/splits.zip
#    creating: DD-Net-master/data/SHREC/
#  extracting: DD-Net-master/data/SHREC/__init__.py
#   inflating: DD-Net-master/data/SHREC/test.pickle
#   inflating: DD-Net-master/data/SHREC/test.pkl
#   inflating: DD-Net-master/data/SHREC/train.pickle
#   inflating: DD-Net-master/data/SHREC/train.pkl
#    creating: DD-Net-master/mics/
#  extracting: DD-Net-master/mics/__init__.py
#   inflating: DD-Net-master/mics/demo.png
#   inflating: DD-Net-master/mics/look.gif
#   inflating: DD-Net-master/mics/paper.png

# %% [markdown]
# 5. Running codes

# %%
Train = pickle.load(open("/kaggle/working/DD-Net-master/data/SHREC/train.pkl", "rb"))
Test = pickle.load(open("/kaggle/working/DD-Net-master/data/SHREC/test.pkl", "rb"))

X_0 = []
X_1 = []
Y = []
for i in tqdm(range(len(Train['pose']))):
    p = np.copy(Train['pose'][i]).reshape([-1,22,3])
    p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)
    p = normlize_range(p)

    label = np.zeros(C.clc_coarse)
    label[Train['coarse_label'][i]-1] = 1

    M = get_CG(p,C)

    X_0.append(M)
    X_1.append(p)
    Y.append(label)

X_0 = np.stack(X_0)
X_1 = np.stack(X_1)
Y = np.stack(Y)
# Out:
#   0%|          | 0/1960 [00:00<?, ?it/s]/tmp/ipykernel_24/208528541.py:23: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 1960/1960 [00:24<00:00, 79.71it/s]

# %%
X_test_0 = []
X_test_1 = []
Y_test = []
for i in tqdm(range(len(Test['pose']))):
    p = np.copy(Test['pose'][i]).reshape([-1,22,3])
    p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)
    p = normlize_range(p)

    label = np.zeros(C.clc_coarse)
    label[Test['coarse_label'][i]-1] = 1

    M = get_CG(p,C)

    X_test_0.append(M)
    X_test_1.append(p)
    Y_test.append(label)

X_test_0 = np.stack(X_test_0)
X_test_1 = np.stack(X_test_1)
Y_test = np.stack(Y_test)
# Out:
#   0%|          | 0/840 [00:00<?, ?it/s]/tmp/ipykernel_24/208528541.py:23: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 840/840 [00:10<00:00, 81.40it/s]

# %%
# it may takes several times to reach the reported performance
lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
            batch_size=len(Y),
            epochs=400,
            verbose=True,
            shuffle=True,
            callbacks=[lrScheduler],
            validation_data=([X_test_0,X_test_1],Y_test)
            )

lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
            batch_size=len(Y),
            epochs=500,
            verbose=True,
            shuffle=True,
            callbacks=[lrScheduler],
            validation_data=([X_test_0,X_test_1],Y_test)
            )
# Out:
# Epoch 1/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step - accuracy: 0.0628 - loss: 3.4606 - val_accuracy: 0.0702 - val_loss: 2.6388 - learning_rate: 1.0000e-04
# Epoch 2/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.0694 - loss: 3.3571 - val_accuracy: 0.1036 - val_loss: 2.6386 - learning_rate: 1.0000e-04
# Epoch 3/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0929 - loss: 3.2174 - val_accuracy: 0.0857 - val_loss: 2.6385 - learning_rate: 1.0000e-04
# Epoch 4/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0934 - loss: 3.1548 - val_accuracy: 0.0750 - val_loss: 2.6385 - learning_rate: 1.0000e-04
# Epoch 5/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.0903 - loss: 3.0927 - val_accuracy: 0.0726 - val_loss: 2.6385 - learning_rate: 1.0000e-04
# Epoch 6/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1168 - loss: 2.9855 - val_accuracy: 0.0690 - val_loss: 2.6385 - learning_rate: 1.0000e-04
# Epoch 7/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1199 - loss: 2.9634 - val_accuracy: 0.0810 - val_loss: 2.6386 - learning_rate: 1.0000e-04
# Epoch 8/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1255 - loss: 2.9075 - val_accuracy: 0.0810 - val_loss: 2.6387 - learning_rate: 1.0000e-04
# Epoch 9/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.1393 - loss: 2.8158 - val_accuracy: 0.0810 - val_loss: 2.6388 - learning_rate: 1.0000e-04
# Epoch 10/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1490 - loss: 2.7756 - val_accuracy: 0.0810 - val_loss: 2.6390 - learning_rate: 1.0000e-04
# Epoch 11/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1551 - loss: 2.7708 - val_accuracy: 0.0810 - val_loss: 2.6393 - learning_rate: 1.0000e-04
# Epoch 12/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1724 - loss: 2.7323 - val_accuracy: 0.0810 - val_loss: 2.6396 - learning_rate: 1.0000e-04
# Epoch 13/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1633 - loss: 2.7090 - val_accuracy: 0.0810 - val_loss: 2.6400 - learning_rate: 1.0000e-04
# Epoch 14/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1806 - loss: 2.6467 - val_accuracy: 0.0810 - val_loss: 2.6405 - learning_rate: 1.0000e-04
# Epoch 15/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2005 - loss: 2.5838 - val_accuracy: 0.0810 - val_loss: 2.6410 - learning_rate: 1.0000e-04
# Epoch 16/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.1949 - loss: 2.5440 - val_accuracy: 0.0810 - val_loss: 2.6417 - learning_rate: 1.0000e-04
# Epoch 17/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.1770 - loss: 2.5807 - val_accuracy: 0.0810 - val_loss: 2.6424 - learning_rate: 1.0000e-04
# Epoch 18/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2153 - loss: 2.4674 - val_accuracy: 0.0810 - val_loss: 2.6432 - learning_rate: 1.0000e-04
# Epoch 19/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.2005 - loss: 2.4927 - val_accuracy: 0.0810 - val_loss: 2.6441 - learning_rate: 1.0000e-04
# Epoch 20/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2056 - loss: 2.4724 - val_accuracy: 0.0810 - val_loss: 2.6451 - learning_rate: 1.0000e-04
# Epoch 21/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2199 - loss: 2.4540 - val_accuracy: 0.0810 - val_loss: 2.6461 - learning_rate: 1.0000e-04
# Epoch 22/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2301 - loss: 2.3814 - val_accuracy: 0.0821 - val_loss: 2.6471 - learning_rate: 1.0000e-04
# Epoch 23/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.2388 - loss: 2.3884 - val_accuracy: 0.0726 - val_loss: 2.6482 - learning_rate: 1.0000e-04
# Epoch 24/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.2541 - loss: 2.3087 - val_accuracy: 0.0655 - val_loss: 2.6494 - learning_rate: 1.0000e-04
# Epoch 25/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2612 - loss: 2.3211 - val_accuracy: 0.0655 - val_loss: 2.6506 - learning_rate: 1.0000e-04
# Epoch 26/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2612 - loss: 2.2722 - val_accuracy: 0.0655 - val_loss: 2.6518 - learning_rate: 1.0000e-04
# Epoch 27/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2643 - loss: 2.2699 - val_accuracy: 0.0655 - val_loss: 2.6531 - learning_rate: 1.0000e-04
# Epoch 28/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.2918 - loss: 2.1999 - val_accuracy: 0.0655 - val_loss: 2.6545 - learning_rate: 1.0000e-04
# Epoch 29/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2679 - loss: 2.2195 - val_accuracy: 0.0655 - val_loss: 2.6559 - learning_rate: 1.0000e-04
# Epoch 30/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3066 - loss: 2.1365 - val_accuracy: 0.0655 - val_loss: 2.6574 - learning_rate: 1.0000e-04
# Epoch 31/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.3143 - loss: 2.1404 - val_accuracy: 0.0655 - val_loss: 2.6589 - learning_rate: 1.0000e-04
# Epoch 32/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3173 - loss: 2.1001 - val_accuracy: 0.0655 - val_loss: 2.6605 - learning_rate: 1.0000e-04
# Epoch 33/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3464 - loss: 2.0796 - val_accuracy: 0.0655 - val_loss: 2.6621 - learning_rate: 1.0000e-04
# Epoch 34/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3316 - loss: 2.0507 - val_accuracy: 0.0655 - val_loss: 2.6637 - learning_rate: 1.0000e-04
# Epoch 35/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3577 - loss: 1.9940 - val_accuracy: 0.0655 - val_loss: 2.6653 - learning_rate: 1.0000e-04
# Epoch 36/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3337 - loss: 2.0383 - val_accuracy: 0.0655 - val_loss: 2.6670 - learning_rate: 1.0000e-04
# Epoch 37/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3806 - loss: 1.9303 - val_accuracy: 0.0702 - val_loss: 2.6687 - learning_rate: 1.0000e-04
# Epoch 38/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.3770 - loss: 1.9707 - val_accuracy: 0.0810 - val_loss: 2.6705 - learning_rate: 1.0000e-04
# Epoch 39/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3740 - loss: 1.9246 - val_accuracy: 0.1024 - val_loss: 2.6723 - learning_rate: 1.0000e-04
# Epoch 40/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3755 - loss: 1.9271 - val_accuracy: 0.0821 - val_loss: 2.6742 - learning_rate: 1.0000e-04
# Epoch 41/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.4046 - loss: 1.8619 - val_accuracy: 0.0643 - val_loss: 2.6761 - learning_rate: 1.0000e-04
# Epoch 42/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.4199 - loss: 1.8489 - val_accuracy: 0.0607 - val_loss: 2.6780 - learning_rate: 1.0000e-04
# Epoch 43/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.4168 - loss: 1.8010 - val_accuracy: 0.0607 - val_loss: 2.6801 - learning_rate: 1.0000e-04
# Epoch 44/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.4306 - loss: 1.7653 - val_accuracy: 0.0607 - val_loss: 2.6821 - learning_rate: 1.0000e-04
# Epoch 45/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.4439 - loss: 1.7488 - val_accuracy: 0.0607 - val_loss: 2.6843 - learning_rate: 1.0000e-04
# Epoch 46/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.4332 - loss: 1.7694 - val_accuracy: 0.0607 - val_loss: 2.6864 - learning_rate: 1.0000e-04
# Epoch 47/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.4638 - loss: 1.7320 - val_accuracy: 0.0607 - val_loss: 2.6887 - learning_rate: 1.0000e-04
# Epoch 48/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.4577 - loss: 1.6843 - val_accuracy: 0.0607 - val_loss: 2.6910 - learning_rate: 1.0000e-04
# Epoch 49/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.4684 - loss: 1.6855 - val_accuracy: 0.0607 - val_loss: 2.6934 - learning_rate: 1.0000e-04
# Epoch 50/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.4765 - loss: 1.6386 - val_accuracy: 0.0607 - val_loss: 2.6959 - learning_rate: 1.0000e-04
# Epoch 51/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.4903 - loss: 1.6268 - val_accuracy: 0.0607 - val_loss: 2.6984 - learning_rate: 1.0000e-04
# Epoch 52/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.4923 - loss: 1.6261 - val_accuracy: 0.0607 - val_loss: 2.7010 - learning_rate: 1.0000e-04
# Epoch 53/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5020 - loss: 1.5669 - val_accuracy: 0.0607 - val_loss: 2.7037 - learning_rate: 1.0000e-04
# Epoch 54/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.5061 - loss: 1.5555 - val_accuracy: 0.0607 - val_loss: 2.7064 - learning_rate: 1.0000e-04
# Epoch 55/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.5250 - loss: 1.5497 - val_accuracy: 0.0607 - val_loss: 2.7091 - learning_rate: 1.0000e-04
# Epoch 56/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5071 - loss: 1.5295 - val_accuracy: 0.0607 - val_loss: 2.7119 - learning_rate: 1.0000e-04
# Epoch 57/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5337 - loss: 1.4962 - val_accuracy: 0.0607 - val_loss: 2.7148 - learning_rate: 1.0000e-04
# Epoch 58/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5179 - loss: 1.5086 - val_accuracy: 0.0607 - val_loss: 2.7176 - learning_rate: 1.0000e-04
# Epoch 59/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.5612 - loss: 1.4480 - val_accuracy: 0.0607 - val_loss: 2.7207 - learning_rate: 1.0000e-04
# Epoch 60/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5566 - loss: 1.4416 - val_accuracy: 0.0607 - val_loss: 2.7238 - learning_rate: 1.0000e-04
# Epoch 61/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.5653 - loss: 1.4377 - val_accuracy: 0.0607 - val_loss: 2.7270 - learning_rate: 1.0000e-04
# Epoch 62/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5612 - loss: 1.4465 - val_accuracy: 0.0619 - val_loss: 2.7304 - learning_rate: 1.0000e-04
# Epoch 63/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5704 - loss: 1.4108 - val_accuracy: 0.0655 - val_loss: 2.7337 - learning_rate: 1.0000e-04
# Epoch 64/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5878 - loss: 1.3690 - val_accuracy: 0.0726 - val_loss: 2.7371 - learning_rate: 1.0000e-04
# Epoch 65/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6031 - loss: 1.3334 - val_accuracy: 0.0786 - val_loss: 2.7408 - learning_rate: 1.0000e-04
# Epoch 66/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.5959 - loss: 1.3554 - val_accuracy: 0.0917 - val_loss: 2.7444 - learning_rate: 1.0000e-04
# Epoch 67/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6051 - loss: 1.3027 - val_accuracy: 0.1012 - val_loss: 2.7481 - learning_rate: 1.0000e-04
# Epoch 68/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6097 - loss: 1.3050 - val_accuracy: 0.1083 - val_loss: 2.7520 - learning_rate: 1.0000e-04
# Epoch 69/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6301 - loss: 1.2727 - val_accuracy: 0.1119 - val_loss: 2.7559 - learning_rate: 1.0000e-04
# Epoch 70/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6143 - loss: 1.2738 - val_accuracy: 0.1202 - val_loss: 2.7598 - learning_rate: 1.0000e-04
# Epoch 71/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6250 - loss: 1.2435 - val_accuracy: 0.1202 - val_loss: 2.7638 - learning_rate: 1.0000e-04
# Epoch 72/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.6388 - loss: 1.2406 - val_accuracy: 0.1202 - val_loss: 2.7679 - learning_rate: 1.0000e-04
# Epoch 73/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.6362 - loss: 1.2279 - val_accuracy: 0.1214 - val_loss: 2.7720 - learning_rate: 1.0000e-04
# Epoch 74/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6510 - loss: 1.1816 - val_accuracy: 0.1226 - val_loss: 2.7760 - learning_rate: 1.0000e-04
# Epoch 75/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.6464 - loss: 1.1980 - val_accuracy: 0.1226 - val_loss: 2.7800 - learning_rate: 1.0000e-04
# Epoch 76/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6551 - loss: 1.1782 - val_accuracy: 0.1226 - val_loss: 2.7840 - learning_rate: 1.0000e-04
# Epoch 77/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6408 - loss: 1.1878 - val_accuracy: 0.1238 - val_loss: 2.7881 - learning_rate: 1.0000e-04
# Epoch 78/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6709 - loss: 1.1560 - val_accuracy: 0.1238 - val_loss: 2.7924 - learning_rate: 1.0000e-04
# Epoch 79/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6658 - loss: 1.1376 - val_accuracy: 0.1238 - val_loss: 2.7968 - learning_rate: 1.0000e-04
# Epoch 80/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.6770 - loss: 1.1342 - val_accuracy: 0.1250 - val_loss: 2.8012 - learning_rate: 1.0000e-04
# Epoch 81/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6847 - loss: 1.0934 - val_accuracy: 0.1250 - val_loss: 2.8056 - learning_rate: 1.0000e-04
# Epoch 82/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6857 - loss: 1.0968 - val_accuracy: 0.1250 - val_loss: 2.8098 - learning_rate: 1.0000e-04
# Epoch 83/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6801 - loss: 1.0896 - val_accuracy: 0.1238 - val_loss: 2.8141 - learning_rate: 1.0000e-04
# Epoch 84/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.6913 - loss: 1.0913 - val_accuracy: 0.1238 - val_loss: 2.8187 - learning_rate: 1.0000e-04
# Epoch 85/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7005 - loss: 1.0756 - val_accuracy: 0.1238 - val_loss: 2.8231 - learning_rate: 1.0000e-04
# Epoch 86/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7051 - loss: 1.0279 - val_accuracy: 0.1238 - val_loss: 2.8278 - learning_rate: 1.0000e-04
# Epoch 87/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.6862 - loss: 1.0642 - val_accuracy: 0.1238 - val_loss: 2.8327 - learning_rate: 1.0000e-04
# Epoch 88/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7082 - loss: 1.0304 - val_accuracy: 0.1250 - val_loss: 2.8377 - learning_rate: 1.0000e-04
# Epoch 89/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7148 - loss: 1.0223 - val_accuracy: 0.1226 - val_loss: 2.8428 - learning_rate: 1.0000e-04
# Epoch 90/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7112 - loss: 1.0075 - val_accuracy: 0.1226 - val_loss: 2.8474 - learning_rate: 1.0000e-04
# Epoch 91/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7071 - loss: 1.0208 - val_accuracy: 0.1226 - val_loss: 2.8521 - learning_rate: 1.0000e-04
# Epoch 92/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7332 - loss: 0.9770 - val_accuracy: 0.1226 - val_loss: 2.8571 - learning_rate: 1.0000e-04
# Epoch 93/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7281 - loss: 0.9890 - val_accuracy: 0.1226 - val_loss: 2.8624 - learning_rate: 1.0000e-04
# Epoch 94/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.7367 - loss: 0.9552 - val_accuracy: 0.1226 - val_loss: 2.8678 - learning_rate: 1.0000e-04
# Epoch 95/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.7281 - loss: 0.9546 - val_accuracy: 0.1226 - val_loss: 2.8734 - learning_rate: 1.0000e-04
# Epoch 96/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7444 - loss: 0.9424 - val_accuracy: 0.1214 - val_loss: 2.8790 - learning_rate: 1.0000e-04
# Epoch 97/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7536 - loss: 0.9321 - val_accuracy: 0.1226 - val_loss: 2.8848 - learning_rate: 1.0000e-04
# Epoch 98/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.7378 - loss: 0.9248 - val_accuracy: 0.1226 - val_loss: 2.8903 - learning_rate: 1.0000e-04
# Epoch 99/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7541 - loss: 0.9106 - val_accuracy: 0.1226 - val_loss: 2.8955 - learning_rate: 1.0000e-04
# Epoch 100/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.7561 - loss: 0.9161 - val_accuracy: 0.1226 - val_loss: 2.9012 - learning_rate: 1.0000e-04
# Epoch 101/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.7505 - loss: 0.9131 - val_accuracy: 0.1226 - val_loss: 2.9069 - learning_rate: 1.0000e-04
# Epoch 102/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.7556 - loss: 0.9101 - val_accuracy: 0.1226 - val_loss: 2.9122 - learning_rate: 1.0000e-04
# Epoch 103/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7668 - loss: 0.8684 - val_accuracy: 0.1226 - val_loss: 2.9177 - learning_rate: 1.0000e-04
# Epoch 104/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7638 - loss: 0.8974 - val_accuracy: 0.1226 - val_loss: 2.9233 - learning_rate: 1.0000e-04
# Epoch 105/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7622 - loss: 0.8520 - val_accuracy: 0.1226 - val_loss: 2.9292 - learning_rate: 1.0000e-04
# Epoch 106/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7750 - loss: 0.8711 - val_accuracy: 0.1226 - val_loss: 2.9354 - learning_rate: 1.0000e-04
# Epoch 107/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7689 - loss: 0.8542 - val_accuracy: 0.1226 - val_loss: 2.9411 - learning_rate: 1.0000e-04
# Epoch 108/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.7821 - loss: 0.8302 - val_accuracy: 0.1226 - val_loss: 2.9467 - learning_rate: 1.0000e-04
# Epoch 109/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.7811 - loss: 0.8313 - val_accuracy: 0.1226 - val_loss: 2.9525 - learning_rate: 1.0000e-04
# Epoch 110/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7796 - loss: 0.8148 - val_accuracy: 0.1226 - val_loss: 2.9591 - learning_rate: 1.0000e-04
# Epoch 111/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7878 - loss: 0.8065 - val_accuracy: 0.1226 - val_loss: 2.9659 - learning_rate: 1.0000e-04
# Epoch 112/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7903 - loss: 0.8104 - val_accuracy: 0.1238 - val_loss: 2.9733 - learning_rate: 1.0000e-04
# Epoch 113/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8041 - loss: 0.7965 - val_accuracy: 0.1226 - val_loss: 2.9799 - learning_rate: 1.0000e-04
# Epoch 114/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7949 - loss: 0.7970 - val_accuracy: 0.1226 - val_loss: 2.9869 - learning_rate: 1.0000e-04
# Epoch 115/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.8036 - loss: 0.7864 - val_accuracy: 0.1226 - val_loss: 2.9937 - learning_rate: 1.0000e-04
# Epoch 116/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7898 - loss: 0.8090 - val_accuracy: 0.1226 - val_loss: 2.9998 - learning_rate: 1.0000e-04
# Epoch 117/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7964 - loss: 0.7910 - val_accuracy: 0.1226 - val_loss: 3.0057 - learning_rate: 1.0000e-04
# Epoch 118/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8087 - loss: 0.7573 - val_accuracy: 0.1226 - val_loss: 3.0117 - learning_rate: 1.0000e-04
# Epoch 119/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8020 - loss: 0.7871 - val_accuracy: 0.1226 - val_loss: 3.0170 - learning_rate: 1.0000e-04
# Epoch 120/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8128 - loss: 0.7397 - val_accuracy: 0.1214 - val_loss: 3.0219 - learning_rate: 1.0000e-04
# Epoch 121/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8107 - loss: 0.7568 - val_accuracy: 0.1214 - val_loss: 3.0267 - learning_rate: 1.0000e-04
# Epoch 122/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8122 - loss: 0.7715 - val_accuracy: 0.1214 - val_loss: 3.0316 - learning_rate: 1.0000e-04
# Epoch 123/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8240 - loss: 0.7076 - val_accuracy: 0.1214 - val_loss: 3.0375 - learning_rate: 1.0000e-04
# Epoch 124/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8311 - loss: 0.7000 - val_accuracy: 0.1214 - val_loss: 3.0435 - learning_rate: 1.0000e-04
# Epoch 125/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8230 - loss: 0.7255 - val_accuracy: 0.1214 - val_loss: 3.0497 - learning_rate: 1.0000e-04
# Epoch 126/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8332 - loss: 0.7120 - val_accuracy: 0.1214 - val_loss: 3.0554 - learning_rate: 1.0000e-04
# Epoch 127/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8168 - loss: 0.7180 - val_accuracy: 0.1214 - val_loss: 3.0607 - learning_rate: 1.0000e-04
# Epoch 128/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8347 - loss: 0.6951 - val_accuracy: 0.1214 - val_loss: 3.0656 - learning_rate: 1.0000e-04
# Epoch 129/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8347 - loss: 0.7105 - val_accuracy: 0.1214 - val_loss: 3.0701 - learning_rate: 1.0000e-04
# Epoch 130/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8469 - loss: 0.6573 - val_accuracy: 0.1214 - val_loss: 3.0739 - learning_rate: 1.0000e-04
# Epoch 131/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8306 - loss: 0.6925 - val_accuracy: 0.1214 - val_loss: 3.0781 - learning_rate: 1.0000e-04
# Epoch 132/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8367 - loss: 0.6640 - val_accuracy: 0.1214 - val_loss: 3.0823 - learning_rate: 1.0000e-04
# Epoch 133/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8337 - loss: 0.6786 - val_accuracy: 0.1214 - val_loss: 3.0866 - learning_rate: 1.0000e-04
# Epoch 134/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8250 - loss: 0.6861 - val_accuracy: 0.1214 - val_loss: 3.0910 - learning_rate: 1.0000e-04
# Epoch 135/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8408 - loss: 0.6604 - val_accuracy: 0.1214 - val_loss: 3.0954 - learning_rate: 1.0000e-04
# Epoch 136/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8321 - loss: 0.6783 - val_accuracy: 0.1214 - val_loss: 3.0985 - learning_rate: 5.0000e-05
# Epoch 137/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8469 - loss: 0.6419 - val_accuracy: 0.1214 - val_loss: 3.1015 - learning_rate: 5.0000e-05
# Epoch 138/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8551 - loss: 0.6364 - val_accuracy: 0.1214 - val_loss: 3.1049 - learning_rate: 5.0000e-05
# Epoch 139/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8454 - loss: 0.6343 - val_accuracy: 0.1214 - val_loss: 3.1081 - learning_rate: 5.0000e-05
# Epoch 140/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8505 - loss: 0.6346 - val_accuracy: 0.1214 - val_loss: 3.1105 - learning_rate: 5.0000e-05
# Epoch 141/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8357 - loss: 0.6571 - val_accuracy: 0.1214 - val_loss: 3.1130 - learning_rate: 5.0000e-05
# Epoch 142/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8434 - loss: 0.6525 - val_accuracy: 0.1214 - val_loss: 3.1157 - learning_rate: 5.0000e-05
# Epoch 143/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8418 - loss: 0.6438 - val_accuracy: 0.1214 - val_loss: 3.1187 - learning_rate: 5.0000e-05
# Epoch 144/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8556 - loss: 0.6252 - val_accuracy: 0.1214 - val_loss: 3.1219 - learning_rate: 5.0000e-05
# Epoch 145/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8541 - loss: 0.6232 - val_accuracy: 0.1226 - val_loss: 3.1249 - learning_rate: 5.0000e-05
# Epoch 146/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8454 - loss: 0.6154 - val_accuracy: 0.1226 - val_loss: 3.1277 - learning_rate: 5.0000e-05
# Epoch 147/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8485 - loss: 0.6361 - val_accuracy: 0.1226 - val_loss: 3.1298 - learning_rate: 5.0000e-05
# Epoch 148/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8520 - loss: 0.6062 - val_accuracy: 0.1226 - val_loss: 3.1323 - learning_rate: 5.0000e-05
# Epoch 149/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8536 - loss: 0.6178 - val_accuracy: 0.1238 - val_loss: 3.1341 - learning_rate: 5.0000e-05
# Epoch 150/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8561 - loss: 0.6114 - val_accuracy: 0.1238 - val_loss: 3.1362 - learning_rate: 5.0000e-05
# Epoch 151/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8510 - loss: 0.6178 - val_accuracy: 0.1238 - val_loss: 3.1384 - learning_rate: 5.0000e-05
# Epoch 152/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8587 - loss: 0.6260 - val_accuracy: 0.1238 - val_loss: 3.1410 - learning_rate: 5.0000e-05
# Epoch 153/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8546 - loss: 0.5961 - val_accuracy: 0.1238 - val_loss: 3.1429 - learning_rate: 5.0000e-05
# Epoch 154/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8566 - loss: 0.6119 - val_accuracy: 0.1238 - val_loss: 3.1448 - learning_rate: 5.0000e-05
# Epoch 155/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8704 - loss: 0.5993 - val_accuracy: 0.1250 - val_loss: 3.1469 - learning_rate: 5.0000e-05
# Epoch 156/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8546 - loss: 0.6083 - val_accuracy: 0.1250 - val_loss: 3.1492 - learning_rate: 5.0000e-05
# Epoch 157/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8668 - loss: 0.5947 - val_accuracy: 0.1250 - val_loss: 3.1516 - learning_rate: 5.0000e-05
# Epoch 158/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8679 - loss: 0.5953 - val_accuracy: 0.1250 - val_loss: 3.1543 - learning_rate: 5.0000e-05
# Epoch 159/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8515 - loss: 0.6126 - val_accuracy: 0.1250 - val_loss: 3.1564 - learning_rate: 5.0000e-05
# Epoch 160/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8673 - loss: 0.5809 - val_accuracy: 0.1250 - val_loss: 3.1592 - learning_rate: 5.0000e-05
# Epoch 161/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8587 - loss: 0.6114 - val_accuracy: 0.1250 - val_loss: 3.1625 - learning_rate: 5.0000e-05
# Epoch 162/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8770 - loss: 0.5719 - val_accuracy: 0.1250 - val_loss: 3.1657 - learning_rate: 5.0000e-05
# Epoch 163/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8546 - loss: 0.5986 - val_accuracy: 0.1250 - val_loss: 3.1692 - learning_rate: 5.0000e-05
# Epoch 164/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8663 - loss: 0.5570 - val_accuracy: 0.1250 - val_loss: 3.1716 - learning_rate: 5.0000e-05
# Epoch 165/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8658 - loss: 0.5874 - val_accuracy: 0.1250 - val_loss: 3.1747 - learning_rate: 5.0000e-05
# Epoch 166/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8617 - loss: 0.5686 - val_accuracy: 0.1250 - val_loss: 3.1769 - learning_rate: 5.0000e-05
# Epoch 167/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8796 - loss: 0.5535 - val_accuracy: 0.1250 - val_loss: 3.1788 - learning_rate: 5.0000e-05
# Epoch 168/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8515 - loss: 0.5875 - val_accuracy: 0.1250 - val_loss: 3.1806 - learning_rate: 5.0000e-05
# Epoch 169/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8668 - loss: 0.5774 - val_accuracy: 0.1238 - val_loss: 3.1820 - learning_rate: 5.0000e-05
# Epoch 170/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8724 - loss: 0.5529 - val_accuracy: 0.1238 - val_loss: 3.1829 - learning_rate: 5.0000e-05
# Epoch 171/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8704 - loss: 0.5713 - val_accuracy: 0.1238 - val_loss: 3.1845 - learning_rate: 5.0000e-05
# Epoch 172/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8765 - loss: 0.5553 - val_accuracy: 0.1238 - val_loss: 3.1859 - learning_rate: 5.0000e-05
# Epoch 173/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8699 - loss: 0.5768 - val_accuracy: 0.1238 - val_loss: 3.1878 - learning_rate: 5.0000e-05
# Epoch 174/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8837 - loss: 0.5559 - val_accuracy: 0.1238 - val_loss: 3.1891 - learning_rate: 5.0000e-05
# Epoch 175/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8745 - loss: 0.5465 - val_accuracy: 0.1238 - val_loss: 3.1905 - learning_rate: 5.0000e-05
# Epoch 176/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8648 - loss: 0.5753 - val_accuracy: 0.1238 - val_loss: 3.1917 - learning_rate: 5.0000e-05
# Epoch 177/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8811 - loss: 0.5253 - val_accuracy: 0.1238 - val_loss: 3.1932 - learning_rate: 5.0000e-05
# Epoch 178/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8633 - loss: 0.5726 - val_accuracy: 0.1238 - val_loss: 3.1945 - learning_rate: 5.0000e-05
# Epoch 179/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8796 - loss: 0.5332 - val_accuracy: 0.1238 - val_loss: 3.1953 - learning_rate: 5.0000e-05
# Epoch 180/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8673 - loss: 0.5581 - val_accuracy: 0.1238 - val_loss: 3.1964 - learning_rate: 5.0000e-05
# Epoch 181/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8760 - loss: 0.5396 - val_accuracy: 0.1238 - val_loss: 3.1975 - learning_rate: 5.0000e-05
# Epoch 182/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8821 - loss: 0.5228 - val_accuracy: 0.1238 - val_loss: 3.1993 - learning_rate: 5.0000e-05
# Epoch 183/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8709 - loss: 0.5531 - val_accuracy: 0.1238 - val_loss: 3.2006 - learning_rate: 5.0000e-05
# Epoch 184/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8679 - loss: 0.5603 - val_accuracy: 0.1250 - val_loss: 3.2010 - learning_rate: 5.0000e-05
# Epoch 185/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8765 - loss: 0.5440 - val_accuracy: 0.1250 - val_loss: 3.2009 - learning_rate: 5.0000e-05
# Epoch 186/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8806 - loss: 0.5445 - val_accuracy: 0.1250 - val_loss: 3.2010 - learning_rate: 5.0000e-05
# Epoch 187/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8796 - loss: 0.5179 - val_accuracy: 0.1250 - val_loss: 3.2010 - learning_rate: 5.0000e-05
# Epoch 188/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8750 - loss: 0.5393 - val_accuracy: 0.1250 - val_loss: 3.2010 - learning_rate: 5.0000e-05
# Epoch 189/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8694 - loss: 0.5413 - val_accuracy: 0.1250 - val_loss: 3.2012 - learning_rate: 5.0000e-05
# Epoch 190/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8827 - loss: 0.5313 - val_accuracy: 0.1250 - val_loss: 3.2010 - learning_rate: 5.0000e-05
# Epoch 191/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8852 - loss: 0.5257 - val_accuracy: 0.1250 - val_loss: 3.2008 - learning_rate: 5.0000e-05
# Epoch 192/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8791 - loss: 0.5369 - val_accuracy: 0.1250 - val_loss: 3.2009 - learning_rate: 5.0000e-05
# Epoch 193/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8842 - loss: 0.5172 - val_accuracy: 0.1250 - val_loss: 3.2002 - learning_rate: 2.5000e-05
# Epoch 194/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8842 - loss: 0.5073 - val_accuracy: 0.1250 - val_loss: 3.2001 - learning_rate: 2.5000e-05
# Epoch 195/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8898 - loss: 0.5175 - val_accuracy: 0.1250 - val_loss: 3.2001 - learning_rate: 2.5000e-05
# Epoch 196/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8959 - loss: 0.4928 - val_accuracy: 0.1250 - val_loss: 3.2004 - learning_rate: 2.5000e-05
# Epoch 197/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8883 - loss: 0.5124 - val_accuracy: 0.1250 - val_loss: 3.1997 - learning_rate: 2.5000e-05
# Epoch 198/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8990 - loss: 0.4916 - val_accuracy: 0.1250 - val_loss: 3.1990 - learning_rate: 2.5000e-05
# Epoch 199/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8893 - loss: 0.5222 - val_accuracy: 0.1250 - val_loss: 3.1980 - learning_rate: 2.5000e-05
# Epoch 200/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8816 - loss: 0.5179 - val_accuracy: 0.1250 - val_loss: 3.1975 - learning_rate: 2.5000e-05
# Epoch 201/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.8781 - loss: 0.5187 - val_accuracy: 0.1250 - val_loss: 3.1965 - learning_rate: 2.5000e-05
# Epoch 202/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8872 - loss: 0.5235 - val_accuracy: 0.1250 - val_loss: 3.1956 - learning_rate: 2.5000e-05
# Epoch 203/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8867 - loss: 0.5065 - val_accuracy: 0.1250 - val_loss: 3.1949 - learning_rate: 2.5000e-05
# Epoch 204/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8883 - loss: 0.5029 - val_accuracy: 0.1250 - val_loss: 3.1941 - learning_rate: 1.2500e-05
# Epoch 205/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8980 - loss: 0.4982 - val_accuracy: 0.1250 - val_loss: 3.1933 - learning_rate: 1.2500e-05
# Epoch 206/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8765 - loss: 0.5193 - val_accuracy: 0.1250 - val_loss: 3.1924 - learning_rate: 1.2500e-05
# Epoch 207/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8893 - loss: 0.5000 - val_accuracy: 0.1250 - val_loss: 3.1915 - learning_rate: 1.2500e-05
# Epoch 208/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8929 - loss: 0.5091 - val_accuracy: 0.1250 - val_loss: 3.1905 - learning_rate: 1.2500e-05
# Epoch 209/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8913 - loss: 0.5036 - val_accuracy: 0.1250 - val_loss: 3.1896 - learning_rate: 1.2500e-05
# Epoch 210/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8959 - loss: 0.4889 - val_accuracy: 0.1250 - val_loss: 3.1884 - learning_rate: 1.2500e-05
# Epoch 211/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8842 - loss: 0.5235 - val_accuracy: 0.1250 - val_loss: 3.1869 - learning_rate: 1.2500e-05
# Epoch 212/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8862 - loss: 0.5135 - val_accuracy: 0.1250 - val_loss: 3.1857 - learning_rate: 1.2500e-05
# Epoch 213/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8903 - loss: 0.5000 - val_accuracy: 0.1250 - val_loss: 3.1841 - learning_rate: 1.2500e-05
# Epoch 214/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8923 - loss: 0.5240 - val_accuracy: 0.1250 - val_loss: 3.1827 - learning_rate: 1.2500e-05
# Epoch 215/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8949 - loss: 0.4930 - val_accuracy: 0.1250 - val_loss: 3.1811 - learning_rate: 1.2500e-05
# Epoch 216/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8857 - loss: 0.5179 - val_accuracy: 0.1250 - val_loss: 3.1793 - learning_rate: 6.2500e-06
# Epoch 217/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8893 - loss: 0.4968 - val_accuracy: 0.1250 - val_loss: 3.1776 - learning_rate: 6.2500e-06
# Epoch 218/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8898 - loss: 0.5212 - val_accuracy: 0.1250 - val_loss: 3.1756 - learning_rate: 6.2500e-06
# Epoch 219/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8832 - loss: 0.5254 - val_accuracy: 0.1250 - val_loss: 3.1735 - learning_rate: 6.2500e-06
# Epoch 220/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8842 - loss: 0.5160 - val_accuracy: 0.1250 - val_loss: 3.1715 - learning_rate: 6.2500e-06
# Epoch 221/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8929 - loss: 0.5115 - val_accuracy: 0.1250 - val_loss: 3.1694 - learning_rate: 6.2500e-06
# Epoch 222/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8867 - loss: 0.5107 - val_accuracy: 0.1250 - val_loss: 3.1673 - learning_rate: 6.2500e-06
# Epoch 223/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.8842 - loss: 0.5063 - val_accuracy: 0.1250 - val_loss: 3.1653 - learning_rate: 6.2500e-06
# Epoch 224/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8837 - loss: 0.5205 - val_accuracy: 0.1250 - val_loss: 3.1630 - learning_rate: 6.2500e-06
# Epoch 225/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9000 - loss: 0.4914 - val_accuracy: 0.1250 - val_loss: 3.1606 - learning_rate: 5.0000e-06
# Epoch 226/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8893 - loss: 0.5097 - val_accuracy: 0.1250 - val_loss: 3.1581 - learning_rate: 5.0000e-06
# Epoch 227/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8923 - loss: 0.4925 - val_accuracy: 0.1250 - val_loss: 3.1553 - learning_rate: 5.0000e-06
# Epoch 228/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9005 - loss: 0.4853 - val_accuracy: 0.1250 - val_loss: 3.1528 - learning_rate: 5.0000e-06
# Epoch 229/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8893 - loss: 0.5119 - val_accuracy: 0.1250 - val_loss: 3.1501 - learning_rate: 5.0000e-06
# Epoch 230/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8811 - loss: 0.5099 - val_accuracy: 0.1250 - val_loss: 3.1477 - learning_rate: 5.0000e-06
# Epoch 231/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8862 - loss: 0.5193 - val_accuracy: 0.1250 - val_loss: 3.1452 - learning_rate: 5.0000e-06
# Epoch 232/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8857 - loss: 0.5025 - val_accuracy: 0.1250 - val_loss: 3.1421 - learning_rate: 5.0000e-06
# Epoch 233/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8883 - loss: 0.4999 - val_accuracy: 0.1250 - val_loss: 3.1391 - learning_rate: 5.0000e-06
# Epoch 234/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8903 - loss: 0.5002 - val_accuracy: 0.1250 - val_loss: 3.1362 - learning_rate: 5.0000e-06
# Epoch 235/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9005 - loss: 0.4846 - val_accuracy: 0.1250 - val_loss: 3.1330 - learning_rate: 5.0000e-06
# Epoch 236/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8964 - loss: 0.5070 - val_accuracy: 0.1250 - val_loss: 3.1298 - learning_rate: 5.0000e-06
# Epoch 237/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8816 - loss: 0.5105 - val_accuracy: 0.1250 - val_loss: 3.1267 - learning_rate: 5.0000e-06
# Epoch 238/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9046 - loss: 0.4739 - val_accuracy: 0.1250 - val_loss: 3.1233 - learning_rate: 5.0000e-06
# Epoch 239/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8918 - loss: 0.4948 - val_accuracy: 0.1250 - val_loss: 3.1200 - learning_rate: 5.0000e-06
# Epoch 240/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8847 - loss: 0.5106 - val_accuracy: 0.1250 - val_loss: 3.1165 - learning_rate: 5.0000e-06
# Epoch 241/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8796 - loss: 0.5303 - val_accuracy: 0.1250 - val_loss: 3.1133 - learning_rate: 5.0000e-06
# Epoch 242/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8852 - loss: 0.5008 - val_accuracy: 0.1250 - val_loss: 3.1096 - learning_rate: 5.0000e-06
# Epoch 243/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8878 - loss: 0.5010 - val_accuracy: 0.1250 - val_loss: 3.1061 - learning_rate: 5.0000e-06
# Epoch 244/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.8842 - loss: 0.5133 - val_accuracy: 0.1250 - val_loss: 3.1024 - learning_rate: 5.0000e-06
# Epoch 245/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9010 - loss: 0.4927 - val_accuracy: 0.1250 - val_loss: 3.0985 - learning_rate: 5.0000e-06
# Epoch 246/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8867 - loss: 0.5167 - val_accuracy: 0.1250 - val_loss: 3.0947 - learning_rate: 5.0000e-06
# Epoch 247/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8959 - loss: 0.4962 - val_accuracy: 0.1250 - val_loss: 3.0909 - learning_rate: 5.0000e-06
# Epoch 248/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8913 - loss: 0.5028 - val_accuracy: 0.1250 - val_loss: 3.0873 - learning_rate: 5.0000e-06
# Epoch 249/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8847 - loss: 0.5001 - val_accuracy: 0.1250 - val_loss: 3.0834 - learning_rate: 5.0000e-06
# Epoch 250/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8842 - loss: 0.5144 - val_accuracy: 0.1250 - val_loss: 3.0795 - learning_rate: 5.0000e-06
# Epoch 251/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8934 - loss: 0.4951 - val_accuracy: 0.1250 - val_loss: 3.0755 - learning_rate: 5.0000e-06
# Epoch 252/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8888 - loss: 0.4954 - val_accuracy: 0.1250 - val_loss: 3.0714 - learning_rate: 5.0000e-06
# Epoch 253/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8949 - loss: 0.4928 - val_accuracy: 0.1250 - val_loss: 3.0673 - learning_rate: 5.0000e-06
# Epoch 254/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8801 - loss: 0.5193 - val_accuracy: 0.1250 - val_loss: 3.0634 - learning_rate: 5.0000e-06
# Epoch 255/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8903 - loss: 0.5080 - val_accuracy: 0.1250 - val_loss: 3.0595 - learning_rate: 5.0000e-06
# Epoch 256/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8939 - loss: 0.5016 - val_accuracy: 0.1250 - val_loss: 3.0553 - learning_rate: 5.0000e-06
# Epoch 257/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8883 - loss: 0.4964 - val_accuracy: 0.1250 - val_loss: 3.0511 - learning_rate: 5.0000e-06
# Epoch 258/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9000 - loss: 0.4748 - val_accuracy: 0.1250 - val_loss: 3.0466 - learning_rate: 5.0000e-06
# Epoch 259/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8954 - loss: 0.4806 - val_accuracy: 0.1250 - val_loss: 3.0424 - learning_rate: 5.0000e-06
# Epoch 260/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8929 - loss: 0.4984 - val_accuracy: 0.1250 - val_loss: 3.0377 - learning_rate: 5.0000e-06
# Epoch 261/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8842 - loss: 0.4952 - val_accuracy: 0.1250 - val_loss: 3.0333 - learning_rate: 5.0000e-06
# Epoch 262/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8898 - loss: 0.5073 - val_accuracy: 0.1250 - val_loss: 3.0289 - learning_rate: 5.0000e-06
# Epoch 263/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8898 - loss: 0.5178 - val_accuracy: 0.1250 - val_loss: 3.0241 - learning_rate: 5.0000e-06
# Epoch 264/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8949 - loss: 0.5021 - val_accuracy: 0.1250 - val_loss: 3.0195 - learning_rate: 5.0000e-06
# Epoch 265/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.8903 - loss: 0.4903 - val_accuracy: 0.1250 - val_loss: 3.0146 - learning_rate: 5.0000e-06
# Epoch 266/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8969 - loss: 0.4807 - val_accuracy: 0.1250 - val_loss: 3.0094 - learning_rate: 5.0000e-06
# Epoch 267/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8934 - loss: 0.4973 - val_accuracy: 0.1250 - val_loss: 3.0042 - learning_rate: 5.0000e-06
# Epoch 268/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8852 - loss: 0.5126 - val_accuracy: 0.1250 - val_loss: 2.9993 - learning_rate: 5.0000e-06
# Epoch 269/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8990 - loss: 0.4837 - val_accuracy: 0.1250 - val_loss: 2.9941 - learning_rate: 5.0000e-06
# Epoch 270/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8842 - loss: 0.5164 - val_accuracy: 0.1250 - val_loss: 2.9888 - learning_rate: 5.0000e-06
# Epoch 271/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9026 - loss: 0.4637 - val_accuracy: 0.1250 - val_loss: 2.9837 - learning_rate: 5.0000e-06
# Epoch 272/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8954 - loss: 0.5026 - val_accuracy: 0.1250 - val_loss: 2.9782 - learning_rate: 5.0000e-06
# Epoch 273/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8974 - loss: 0.4713 - val_accuracy: 0.1250 - val_loss: 2.9727 - learning_rate: 5.0000e-06
# Epoch 274/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8944 - loss: 0.5000 - val_accuracy: 0.1250 - val_loss: 2.9671 - learning_rate: 5.0000e-06
# Epoch 275/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8918 - loss: 0.4946 - val_accuracy: 0.1262 - val_loss: 2.9615 - learning_rate: 5.0000e-06
# Epoch 276/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8837 - loss: 0.4933 - val_accuracy: 0.1262 - val_loss: 2.9557 - learning_rate: 5.0000e-06
# Epoch 277/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9082 - loss: 0.4692 - val_accuracy: 0.1262 - val_loss: 2.9498 - learning_rate: 5.0000e-06
# Epoch 278/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9061 - loss: 0.4781 - val_accuracy: 0.1274 - val_loss: 2.9437 - learning_rate: 5.0000e-06
# Epoch 279/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8990 - loss: 0.4862 - val_accuracy: 0.1274 - val_loss: 2.9379 - learning_rate: 5.0000e-06
# Epoch 280/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8969 - loss: 0.4879 - val_accuracy: 0.1286 - val_loss: 2.9317 - learning_rate: 5.0000e-06
# Epoch 281/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8872 - loss: 0.5148 - val_accuracy: 0.1286 - val_loss: 2.9254 - learning_rate: 5.0000e-06
# Epoch 282/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8908 - loss: 0.4909 - val_accuracy: 0.1310 - val_loss: 2.9192 - learning_rate: 5.0000e-06
# Epoch 283/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8878 - loss: 0.5060 - val_accuracy: 0.1310 - val_loss: 2.9130 - learning_rate: 5.0000e-06
# Epoch 284/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9005 - loss: 0.4733 - val_accuracy: 0.1310 - val_loss: 2.9067 - learning_rate: 5.0000e-06
# Epoch 285/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8985 - loss: 0.4945 - val_accuracy: 0.1321 - val_loss: 2.9006 - learning_rate: 5.0000e-06
# Epoch 286/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8852 - loss: 0.5125 - val_accuracy: 0.1321 - val_loss: 2.8943 - learning_rate: 5.0000e-06
# Epoch 287/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8939 - loss: 0.4884 - val_accuracy: 0.1321 - val_loss: 2.8877 - learning_rate: 5.0000e-06
# Epoch 288/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8908 - loss: 0.4991 - val_accuracy: 0.1333 - val_loss: 2.8810 - learning_rate: 5.0000e-06
# Epoch 289/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9071 - loss: 0.4680 - val_accuracy: 0.1333 - val_loss: 2.8745 - learning_rate: 5.0000e-06
# Epoch 290/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8918 - loss: 0.5030 - val_accuracy: 0.1345 - val_loss: 2.8681 - learning_rate: 5.0000e-06
# Epoch 291/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8929 - loss: 0.4933 - val_accuracy: 0.1381 - val_loss: 2.8613 - learning_rate: 5.0000e-06
# Epoch 292/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8974 - loss: 0.4906 - val_accuracy: 0.1393 - val_loss: 2.8546 - learning_rate: 5.0000e-06
# Epoch 293/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8908 - loss: 0.4921 - val_accuracy: 0.1393 - val_loss: 2.8478 - learning_rate: 5.0000e-06
# Epoch 294/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8974 - loss: 0.4938 - val_accuracy: 0.1405 - val_loss: 2.8413 - learning_rate: 5.0000e-06
# Epoch 295/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8786 - loss: 0.5121 - val_accuracy: 0.1417 - val_loss: 2.8344 - learning_rate: 5.0000e-06
# Epoch 296/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.8898 - loss: 0.4954 - val_accuracy: 0.1464 - val_loss: 2.8276 - learning_rate: 5.0000e-06
# Epoch 297/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8954 - loss: 0.5042 - val_accuracy: 0.1476 - val_loss: 2.8211 - learning_rate: 5.0000e-06
# Epoch 298/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8918 - loss: 0.4953 - val_accuracy: 0.1476 - val_loss: 2.8143 - learning_rate: 5.0000e-06
# Epoch 299/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8883 - loss: 0.4986 - val_accuracy: 0.1476 - val_loss: 2.8074 - learning_rate: 5.0000e-06
# Epoch 300/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8954 - loss: 0.4920 - val_accuracy: 0.1476 - val_loss: 2.8000 - learning_rate: 5.0000e-06
# Epoch 301/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8847 - loss: 0.5090 - val_accuracy: 0.1476 - val_loss: 2.7932 - learning_rate: 5.0000e-06
# Epoch 302/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8944 - loss: 0.4880 - val_accuracy: 0.1488 - val_loss: 2.7857 - learning_rate: 5.0000e-06
# Epoch 303/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8883 - loss: 0.5088 - val_accuracy: 0.1488 - val_loss: 2.7785 - learning_rate: 5.0000e-06
# Epoch 304/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8990 - loss: 0.4926 - val_accuracy: 0.1512 - val_loss: 2.7711 - learning_rate: 5.0000e-06
# Epoch 305/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8827 - loss: 0.5098 - val_accuracy: 0.1536 - val_loss: 2.7635 - learning_rate: 5.0000e-06
# Epoch 306/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9020 - loss: 0.4694 - val_accuracy: 0.1536 - val_loss: 2.7557 - learning_rate: 5.0000e-06
# Epoch 307/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8990 - loss: 0.4814 - val_accuracy: 0.1560 - val_loss: 2.7481 - learning_rate: 5.0000e-06
# Epoch 308/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8990 - loss: 0.4953 - val_accuracy: 0.1560 - val_loss: 2.7407 - learning_rate: 5.0000e-06
# Epoch 309/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8969 - loss: 0.4787 - val_accuracy: 0.1583 - val_loss: 2.7332 - learning_rate: 5.0000e-06
# Epoch 310/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9026 - loss: 0.4717 - val_accuracy: 0.1607 - val_loss: 2.7253 - learning_rate: 5.0000e-06
# Epoch 311/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9005 - loss: 0.4861 - val_accuracy: 0.1607 - val_loss: 2.7174 - learning_rate: 5.0000e-06
# Epoch 312/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9000 - loss: 0.4803 - val_accuracy: 0.1619 - val_loss: 2.7097 - learning_rate: 5.0000e-06
# Epoch 313/400
# ...
# Epoch 398/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9791 - loss: 0.1497 - val_accuracy: 0.9476 - val_loss: 0.1824 - learning_rate: 5.0000e-06
# Epoch 399/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9755 - loss: 0.1542 - val_accuracy: 0.9476 - val_loss: 0.1823 - learning_rate: 5.0000e-06
# Epoch 400/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9816 - loss: 0.1562 - val_accuracy: 0.9476 - val_loss: 0.1822 - learning_rate: 5.0000e-06
# Epoch 401/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9760 - loss: 0.1589 - val_accuracy: 0.9476 - val_loss: 0.1822 - learning_rate: 5.0000e-06
# Epoch 402/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9791 - loss: 0.1549 - val_accuracy: 0.9476 - val_loss: 0.1821 - learning_rate: 5.0000e-06
# Epoch 403/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9827 - loss: 0.1522 - val_accuracy: 0.9476 - val_loss: 0.1821 - learning_rate: 5.0000e-06
# Epoch 404/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9801 - loss: 0.1608 - val_accuracy: 0.9476 - val_loss: 0.1820 - learning_rate: 5.0000e-06
# Epoch 405/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9852 - loss: 0.1562 - val_accuracy: 0.9476 - val_loss: 0.1820 - learning_rate: 5.0000e-06
# Epoch 406/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9760 - loss: 0.1590 - val_accuracy: 0.9476 - val_loss: 0.1819 - learning_rate: 5.0000e-06
# Epoch 407/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9755 - loss: 0.1577 - val_accuracy: 0.9476 - val_loss: 0.1818 - learning_rate: 5.0000e-06
# Epoch 408/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9821 - loss: 0.1525 - val_accuracy: 0.9476 - val_loss: 0.1817 - learning_rate: 5.0000e-06
# Epoch 409/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9842 - loss: 0.1480 - val_accuracy: 0.9476 - val_loss: 0.1817 - learning_rate: 5.0000e-06
# Epoch 410/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9781 - loss: 0.1592 - val_accuracy: 0.9476 - val_loss: 0.1816 - learning_rate: 5.0000e-06
# Epoch 411/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9801 - loss: 0.1544 - val_accuracy: 0.9476 - val_loss: 0.1815 - learning_rate: 5.0000e-06
# Epoch 412/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9796 - loss: 0.1597 - val_accuracy: 0.9476 - val_loss: 0.1815 - learning_rate: 5.0000e-06
# Epoch 413/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9760 - loss: 0.1635 - val_accuracy: 0.9476 - val_loss: 0.1814 - learning_rate: 5.0000e-06
# Epoch 414/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9781 - loss: 0.1612 - val_accuracy: 0.9476 - val_loss: 0.1813 - learning_rate: 5.0000e-06
# Epoch 415/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9811 - loss: 0.1545 - val_accuracy: 0.9476 - val_loss: 0.1812 - learning_rate: 5.0000e-06
# Epoch 416/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9781 - loss: 0.1521 - val_accuracy: 0.9476 - val_loss: 0.1811 - learning_rate: 5.0000e-06
# Epoch 417/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9811 - loss: 0.1557 - val_accuracy: 0.9488 - val_loss: 0.1810 - learning_rate: 5.0000e-06
# Epoch 418/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9786 - loss: 0.1558 - val_accuracy: 0.9488 - val_loss: 0.1809 - learning_rate: 5.0000e-06
# Epoch 419/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9806 - loss: 0.1627 - val_accuracy: 0.9488 - val_loss: 0.1808 - learning_rate: 5.0000e-06
# Epoch 420/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9770 - loss: 0.1638 - val_accuracy: 0.9488 - val_loss: 0.1808 - learning_rate: 5.0000e-06
# Epoch 421/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9827 - loss: 0.1476 - val_accuracy: 0.9488 - val_loss: 0.1807 - learning_rate: 5.0000e-06
# Epoch 422/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9837 - loss: 0.1450 - val_accuracy: 0.9488 - val_loss: 0.1806 - learning_rate: 5.0000e-06
# Epoch 423/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9791 - loss: 0.1605 - val_accuracy: 0.9476 - val_loss: 0.1805 - learning_rate: 5.0000e-06
# Epoch 424/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9832 - loss: 0.1525 - val_accuracy: 0.9476 - val_loss: 0.1804 - learning_rate: 5.0000e-06
# Epoch 425/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9852 - loss: 0.1514 - val_accuracy: 0.9476 - val_loss: 0.1804 - learning_rate: 5.0000e-06
# Epoch 426/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9791 - loss: 0.1526 - val_accuracy: 0.9476 - val_loss: 0.1803 - learning_rate: 5.0000e-06
# Epoch 427/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9827 - loss: 0.1544 - val_accuracy: 0.9476 - val_loss: 0.1803 - learning_rate: 5.0000e-06
# Epoch 428/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9821 - loss: 0.1484 - val_accuracy: 0.9476 - val_loss: 0.1802 - learning_rate: 5.0000e-06
# Epoch 429/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9770 - loss: 0.1569 - val_accuracy: 0.9476 - val_loss: 0.1802 - learning_rate: 5.0000e-06
# Epoch 430/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9770 - loss: 0.1514 - val_accuracy: 0.9476 - val_loss: 0.1801 - learning_rate: 5.0000e-06
# Epoch 431/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9765 - loss: 0.1566 - val_accuracy: 0.9476 - val_loss: 0.1800 - learning_rate: 5.0000e-06
# Epoch 432/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9816 - loss: 0.1525 - val_accuracy: 0.9476 - val_loss: 0.1800 - learning_rate: 5.0000e-06
# Epoch 433/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9811 - loss: 0.1570 - val_accuracy: 0.9476 - val_loss: 0.1799 - learning_rate: 5.0000e-06
# Epoch 434/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9821 - loss: 0.1530 - val_accuracy: 0.9476 - val_loss: 0.1798 - learning_rate: 5.0000e-06
# Epoch 435/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.9786 - loss: 0.1482 - val_accuracy: 0.9476 - val_loss: 0.1798 - learning_rate: 5.0000e-06
# Epoch 436/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9827 - loss: 0.1424 - val_accuracy: 0.9476 - val_loss: 0.1797 - learning_rate: 5.0000e-06
# Epoch 437/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9755 - loss: 0.1571 - val_accuracy: 0.9476 - val_loss: 0.1796 - learning_rate: 5.0000e-06
# Epoch 438/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9796 - loss: 0.1530 - val_accuracy: 0.9476 - val_loss: 0.1796 - learning_rate: 5.0000e-06
# Epoch 439/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9786 - loss: 0.1617 - val_accuracy: 0.9476 - val_loss: 0.1795 - learning_rate: 5.0000e-06
# Epoch 440/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9694 - loss: 0.1646 - val_accuracy: 0.9488 - val_loss: 0.1795 - learning_rate: 5.0000e-06
# Epoch 441/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9862 - loss: 0.1480 - val_accuracy: 0.9488 - val_loss: 0.1795 - learning_rate: 5.0000e-06
# Epoch 442/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9852 - loss: 0.1469 - val_accuracy: 0.9488 - val_loss: 0.1794 - learning_rate: 5.0000e-06
# Epoch 443/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9740 - loss: 0.1600 - val_accuracy: 0.9488 - val_loss: 0.1794 - learning_rate: 5.0000e-06
# Epoch 444/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9806 - loss: 0.1484 - val_accuracy: 0.9488 - val_loss: 0.1793 - learning_rate: 5.0000e-06
# Epoch 445/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9852 - loss: 0.1439 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 446/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9821 - loss: 0.1545 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 447/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9806 - loss: 0.1558 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 448/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9801 - loss: 0.1580 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 449/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9816 - loss: 0.1541 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 450/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9862 - loss: 0.1523 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 451/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9842 - loss: 0.1552 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 452/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9811 - loss: 0.1533 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 453/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9842 - loss: 0.1516 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 454/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9776 - loss: 0.1547 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 455/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9781 - loss: 0.1560 - val_accuracy: 0.9488 - val_loss: 0.1792 - learning_rate: 5.0000e-06
# Epoch 456/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9776 - loss: 0.1546 - val_accuracy: 0.9488 - val_loss: 0.1791 - learning_rate: 5.0000e-06
# Epoch 457/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9852 - loss: 0.1510 - val_accuracy: 0.9488 - val_loss: 0.1791 - learning_rate: 5.0000e-06
# Epoch 458/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9821 - loss: 0.1350 - val_accuracy: 0.9488 - val_loss: 0.1790 - learning_rate: 5.0000e-06
# Epoch 459/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9781 - loss: 0.1576 - val_accuracy: 0.9488 - val_loss: 0.1790 - learning_rate: 5.0000e-06
# Epoch 460/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9770 - loss: 0.1593 - val_accuracy: 0.9488 - val_loss: 0.1790 - learning_rate: 5.0000e-06
# Epoch 461/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9786 - loss: 0.1542 - val_accuracy: 0.9488 - val_loss: 0.1790 - learning_rate: 5.0000e-06
# Epoch 462/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9827 - loss: 0.1524 - val_accuracy: 0.9488 - val_loss: 0.1790 - learning_rate: 5.0000e-06
# Epoch 463/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9801 - loss: 0.1495 - val_accuracy: 0.9488 - val_loss: 0.1789 - learning_rate: 5.0000e-06
# Epoch 464/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9832 - loss: 0.1497 - val_accuracy: 0.9488 - val_loss: 0.1789 - learning_rate: 5.0000e-06
# Epoch 465/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9786 - loss: 0.1492 - val_accuracy: 0.9488 - val_loss: 0.1789 - learning_rate: 5.0000e-06
# Epoch 466/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9806 - loss: 0.1494 - val_accuracy: 0.9488 - val_loss: 0.1789 - learning_rate: 5.0000e-06
# Epoch 467/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9791 - loss: 0.1516 - val_accuracy: 0.9488 - val_loss: 0.1789 - learning_rate: 5.0000e-06
# Epoch 468/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9811 - loss: 0.1507 - val_accuracy: 0.9488 - val_loss: 0.1788 - learning_rate: 5.0000e-06
# Epoch 469/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9816 - loss: 0.1522 - val_accuracy: 0.9488 - val_loss: 0.1788 - learning_rate: 5.0000e-06
# Epoch 470/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9796 - loss: 0.1497 - val_accuracy: 0.9488 - val_loss: 0.1788 - learning_rate: 5.0000e-06
# Epoch 471/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9796 - loss: 0.1584 - val_accuracy: 0.9488 - val_loss: 0.1788 - learning_rate: 5.0000e-06
# Epoch 472/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9735 - loss: 0.1696 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 473/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9847 - loss: 0.1433 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 474/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9837 - loss: 0.1542 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 475/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9821 - loss: 0.1537 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 476/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9821 - loss: 0.1515 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 477/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9781 - loss: 0.1564 - val_accuracy: 0.9488 - val_loss: 0.1786 - learning_rate: 5.0000e-06
# Epoch 478/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9847 - loss: 0.1447 - val_accuracy: 0.9488 - val_loss: 0.1786 - learning_rate: 5.0000e-06
# Epoch 479/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9867 - loss: 0.1395 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 480/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9837 - loss: 0.1535 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 481/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9801 - loss: 0.1521 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 482/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9811 - loss: 0.1441 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 483/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9811 - loss: 0.1479 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 484/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9862 - loss: 0.1476 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 485/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9816 - loss: 0.1444 - val_accuracy: 0.9488 - val_loss: 0.1787 - learning_rate: 5.0000e-06
# Epoch 486/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9821 - loss: 0.1451 - val_accuracy: 0.9488 - val_loss: 0.1786 - learning_rate: 5.0000e-06
# Epoch 487/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9760 - loss: 0.1658 - val_accuracy: 0.9488 - val_loss: 0.1786 - learning_rate: 5.0000e-06
# Epoch 488/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9832 - loss: 0.1474 - val_accuracy: 0.9488 - val_loss: 0.1786 - learning_rate: 5.0000e-06
# Epoch 489/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9776 - loss: 0.1464 - val_accuracy: 0.9488 - val_loss: 0.1786 - learning_rate: 5.0000e-06
# Epoch 490/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9827 - loss: 0.1552 - val_accuracy: 0.9488 - val_loss: 0.1786 - learning_rate: 5.0000e-06
# Epoch 491/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9832 - loss: 0.1451 - val_accuracy: 0.9488 - val_loss: 0.1786 - learning_rate: 5.0000e-06
# Epoch 492/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9776 - loss: 0.1559 - val_accuracy: 0.9488 - val_loss: 0.1785 - learning_rate: 5.0000e-06
# Epoch 493/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9801 - loss: 0.1464 - val_accuracy: 0.9488 - val_loss: 0.1785 - learning_rate: 5.0000e-06
# Epoch 494/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9872 - loss: 0.1367 - val_accuracy: 0.9476 - val_loss: 0.1785 - learning_rate: 5.0000e-06
# Epoch 495/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9852 - loss: 0.1455 - val_accuracy: 0.9476 - val_loss: 0.1784 - learning_rate: 5.0000e-06
# Epoch 496/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9786 - loss: 0.1506 - val_accuracy: 0.9476 - val_loss: 0.1785 - learning_rate: 5.0000e-06
# Epoch 497/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9806 - loss: 0.1481 - val_accuracy: 0.9476 - val_loss: 0.1785 - learning_rate: 5.0000e-06
# Epoch 498/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9796 - loss: 0.1452 - val_accuracy: 0.9476 - val_loss: 0.1784 - learning_rate: 5.0000e-06
# Epoch 499/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9827 - loss: 0.1437 - val_accuracy: 0.9476 - val_loss: 0.1785 - learning_rate: 5.0000e-06
# Epoch 500/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9857 - loss: 0.1359 - val_accuracy: 0.9476 - val_loss: 0.1785 - learning_rate: 5.0000e-06

# %% [markdown]
# 6.Plotting results

# %%
# Plot training & validation accuracy values
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Test'])
plt.show()

# %%
Y_pred = DD_Net.predict([X_test_0,X_test_1])
labels = ['Grab', 'Tap', 'Expand', 'Pinch', 'RC', 'RCC', 'SR', 'SL', 'SU', 'SD', 'SX', 'S+', 'SV', 'Shake']

y_true = []
for i in np.argmax(Y_test,axis=1):
    y_true.append(labels[i])

y_pred = []
for i in np.argmax(Y_pred,axis=1):
    y_pred.append(labels[i])

cm_analysis(y_true,y_pred, 'SHREC_14.png', labels, ymap=None, figsize=(8,8))
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
