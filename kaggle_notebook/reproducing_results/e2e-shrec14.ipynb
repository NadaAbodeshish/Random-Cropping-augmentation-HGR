# %%
# !git clone https://github.com/NadaAbodeshish/Random-Cropping-augmentation-HGR.git
# Out:
# Cloning into 'Random-Cropping-augmentation-HGR'...
# remote: Enumerating objects: 843, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 843 (delta 111), reused 147 (delta 57), pack-reused 637 (from 1)
# Receiving objects: 100% (843/843), 166.94 MiB | 39.99 MiB/s, done.
# Resolving deltas: 100% (463/463), done.

# %%
# %cd Random-Cropping-augmentation-HGR/e2eET
# Out:
# /kaggle/working/Random-Cropping-augmentation-HGR/e2eET

# %%
# !ls /kaggle/input/shrec1714g
# Out:
# 'SHREC2017.mVOs-3d.14g-noisy(raw).960px-[allVOs].adaptive-mean'

# %%
# !cp -r /kaggle/input/shrec1714g/* /kaggle/working/Random-Cropping-augmentation-HGR/e2eET/images_d/

# %%
# %cd experiments.server
# Out:
# /kaggle/working/Random-Cropping-augmentation-HGR/e2eET/experiments.server

# %%
# !pip install pytorchcv
# !pip install matplotlib
# !pip install geffnet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.2/134.2 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.2/585.2 kB 15.4 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 2.4 MB/s eta 0:00:00
# ...

# %%
# !python mVO.e2eEnsembleTuning.py -IG 0 -nC 14 -mVOs top-down custom front-away -dsN SHREC2017 -IISE 0 -ISIS 0
# Out:
# Dataloader has been created successfully...
# The dataloader has 14 (14) classes: ['01-Grab', '02-Tap', '03-Expand', '04-Pinch', '05-RotationCW', '06-RotationCCW', '07-SwipeRight', '08-SwipeLeft', '09-SwipeUp', '10-SwipeDown', '11-SwipeX', '12-Swipe+', '13-SwipeV', '14-Shake']
# Training set [len=1960, img_sz=(960, 960)] loaded on device: cuda:0
# Validation set [len=840, img_sz=(960, 960)] loaded on device: cuda:0
# Previewing loaded data [1] and applied transforms [2]...
#
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...
