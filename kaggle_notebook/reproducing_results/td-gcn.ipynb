# %%
 # !git clone https://github.com/NadaAbodeshish/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion.git
# Out:
# Cloning into 'augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion'...
# remote: Enumerating objects: 670, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 670 (delta 17), reused 22 (delta 9), pack-reused 637 (from 1)
# Receiving objects: 100% (670/670), 166.59 MiB | 43.52 MiB/s, done.
# Resolving deltas: 100% (369/369), done.
# Updating files: 100% (187/187), done.

# %%
# %cd /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/TD/data/shrec
# Out:
# /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/TD/data/shrec

# %%
# !ls /kaggle/input/hand-gesture-sh/
# Out:
# HandGestureDataset_SHREC2017

# %%
# !python gen_traindataset.py

# %%
# !python gen_testdataset.py

# %%
# %cd /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/TD/
# Out:
# /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/TD

# %%
# !pip install torchpack

# %%
# !pip install -e torchlight
# !pip install torchpack==0.2.2
# Out:
# Obtaining file:///kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/TD/torchlight
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: torchlight
#     Found existing installation: torchlight 1.0
#     Uninstalling torchlight-1.0:
#       Successfully uninstalled torchlight-1.0
#   Running setup.py develop for torchlight
# ...
#   Using cached torchpack-0.2.2-py3-none-any.whl.metadata (3.6 kB)
# ...
# Using cached torchpack-0.2.2-py3-none-any.whl (18 kB)
# ...
#   Attempting uninstall: torchpack
#     Found existing installation: torchpack 0.3.1
#     Uninstalling torchpack-0.3.1:
#       Successfully uninstalled torchpack-0.3.1
# ...

# %%
# !sed -i 's/from collections import Iterable/from collections.abc import Iterable/' /opt/conda/lib/python3.10/site-packages/torchpack/config.py

# %%
# !sed -i 's/from torchvision.models.resnet import model_urls/from torchvision.models import get_model_weights/' /opt/conda/lib/python3.10/site-packages/torchpack/io.py

# %%
# !sed -i 's/model_urls\[\(.*\)\]/get_model_weights(\1)/' /opt/conda/lib/python3.10/site-packages/torchpack/io.py

# %%
# !python main.py --device 0 --config ./config/shrec17/shrec17.yaml
# Out:
# <class 'model.tdgcn.Model'>
# Model(
#   (data_bn): BatchNorm1d(66, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l1): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (convs): ModuleList(
#         (0-2): 3 x TDGC(
#           (conv1): Conv2d(3, 8, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv4): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1))
#           (tanh): Tanh()
#         )
#       )
#       (down): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU(inplace=True)
#     )
#     (tcn1): MultiScale_TemporalConv(
#       (branches): ModuleList(
#         (0): Sequential(
# ...

# %%
# !python main.py --device 0 --config /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/TD/config/shrec17/shrec17.yaml --phase test --weights /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/TD/work_dir/shrec17/28joint/runs-1-306.pt
# Out:
# <class 'model.tdgcn.Model'>
# Model(
#   (data_bn): BatchNorm1d(66, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l1): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (convs): ModuleList(
#         (0-2): 3 x TDGC(
#           (conv1): Conv2d(3, 8, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv4): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1))
#           (tanh): Tanh()
#         )
#       )
#       (down): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU(inplace=True)
#     )
#     (tcn1): MultiScale_TemporalConv(
#       (branches): ModuleList(
#         (0): Sequential(
# ...

# %%
# !python main.py --device 0 --config /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/TD/config/shrec17/shrec17.yaml --phase test --weights /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/TD/work_dir/shrec17/28joint/runs-2-612.pt
# Out:
# <class 'model.tdgcn.Model'>
# Model(
#   (data_bn): BatchNorm1d(66, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l1): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (convs): ModuleList(
#         (0-2): 3 x TDGC(
#           (conv1): Conv2d(3, 8, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv4): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1))
#           (tanh): Tanh()
#         )
#       )
#       (down): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU(inplace=True)
#     )
#     (tcn1): MultiScale_TemporalConv(
#       (branches): ModuleList(
#         (0): Sequential(
# ...
