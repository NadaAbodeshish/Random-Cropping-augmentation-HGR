# %%
! pip install -q keras
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()

# %%
import numpy as np
import math
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
from tqdm import tqdm
import pickle
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt
from scipy.spatial.distance import cdist

from keras.optimizers import *
from keras.models import Model
from keras.layers import *
from keras import backend as K
import keras
import tensorflow as tf

# %% [markdown]
# 1. Define configurations

# %%
random.seed(1234)

class Config():
    def __init__(self):
        self.frame_l = 32 # the length of frames
        self.joint_n = 15 # the number of joints
        self.joint_d = 2 # the dimension of joints
        self.clc_num = 21 # the number of class
        self.feat_d = 105
        self.filters = 64
C = Config()

# %% [markdown]
# 2. Define data processing functions

# %%
# Temple resizing function
def zoom(p,target_l=64,joints_num=25,joints_dim=3):
    l = p.shape[0]
    p_new = np.empty([target_l,joints_num,joints_dim])
    for m in range(joints_num):
        for n in range(joints_dim):
            p[:,m,n] = medfilt(p[:,m,n],3)
            p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
    return p_new



# Calculate JCD feature
def norm_scale(x):
    return (x-np.mean(x))/np.mean(x)

def get_CG(p,C):
    M = []
    iu = np.triu_indices(C.joint_n,1,C.joint_n)
    for f in range(C.frame_l):
        d_m = cdist(p[f],p[f],'euclidean')
        d_m = d_m[iu]
        M.append(d_m)
    M = np.stack(M)
    M = norm_scale(M)
    return M


# Genrate dataset
def data_generator(T,C,le):
    X_0 = []
    X_1 = []
    Y = []
    for i in tqdm(range(len(T['pose']))):
        p = np.copy(T['pose'][i])
        p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)

        label = np.zeros(C.clc_num)
        label[le.transform(T['label'])[i]-1] = 1

        M = get_CG(p,C)

        X_0.append(M)
        X_1.append(p)
        Y.append(label)

    X_0 = np.stack(X_0)
    X_1 = np.stack(X_1)
    Y = np.stack(Y)
    return X_0,X_1,Y

# %% [markdown]
# 3. Define network

# %%
def poses_diff(x):
    H, W = x.get_shape()[1],x.get_shape()[2]
    x = tf.subtract(x[:,1:,...],x[:,:-1,...])
    x = tf.image.resize(x,size=[H,W])
    return x

def pose_motion(P,frame_l):
    P_diff_slow = Lambda(lambda x: poses_diff(x))(P)
    P_diff_slow = Reshape((frame_l,-1))(P_diff_slow)
    P_fast = Lambda(lambda x: x[:,::2,...])(P)
    P_diff_fast = Lambda(lambda x: poses_diff(x))(P_fast)
    P_diff_fast = Reshape((int(frame_l/2),-1))(P_diff_fast)
    return P_diff_slow,P_diff_fast

def c1D(x,filters,kernel):
    x = Conv1D(filters, kernel_size=kernel,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def block(x,filters):
    x = c1D(x,filters,3)
    x = c1D(x,filters,3)
    return x

def d1D(x,filters):
    x = Dense(filters,use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def build_FM(frame_l=32,joint_n=22,joint_d=2,feat_d=231,filters=16):
    M = Input(shape=(frame_l,feat_d))
    P = Input(shape=(frame_l,joint_n,joint_d))

    diff_slow,diff_fast = pose_motion(P,frame_l)

    x = c1D(M,filters*2,1)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,3)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,1)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x_d_slow = c1D(diff_slow,filters*2,1)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,3)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,1)
    x_d_slow = MaxPool1D(2)(x_d_slow)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)

    x_d_fast = c1D(diff_fast,filters*2,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,3)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)

    x = concatenate([x,x_d_slow,x_d_fast])
    x = block(x,filters*2)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*4)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*8)
    x = SpatialDropout1D(0.1)(x)

    return Model(inputs=[M,P],outputs=x)


def build_DD_Net(C):
    M = Input(name='M', shape=(C.frame_l,C.feat_d))
    P = Input(name='P', shape=(C.frame_l,C.joint_n,C.joint_d))

    FM = build_FM(C.frame_l,C.joint_n,C.joint_d,C.feat_d,C.filters)

    x = FM([M,P])

    x = GlobalMaxPool1D()(x)

    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = Dense(C.clc_num, activation='softmax')(x)

    ######################Self-supervised part
    model = Model(inputs=[M,P],outputs=x)
    return model

# %%
DD_Net = build_DD_Net(C)
DD_Net.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ M (InputLayer)      │ (None, 32, 105)   │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ P (InputLayer)      │ (None, 32, 15, 2) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_1        │ (None, 4, 512)    │  1,714,816 │ M[0][0], P[0][0]  │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ functional_1[0][… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     65,536 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 128)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ leaky_re_lu_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     16,384 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 128)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ leaky_re_lu_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 21)        │      2,709 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,800,469 (6.87 MB)
#  Trainable params: 1,794,837 (6.85 MB)
#  Non-trainable params: 5,632 (22.00 KB)

# %% [markdown]
# 4. Load dataset (download GT_train_1.pkl and  GT_test_1.pkl from github )

# %%
# !wget https://github.com/fandulu/DD-Net/archive/master.zip
# !unzip master.zip
# !rm master.zip
# Out:
# --2024-12-11 23:33:57--  https://github.com/fandulu/DD-Net/archive/master.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master [following]
# --2024-12-11 23:33:58--  https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: 'master.zip'
#
# master.zip              [             <=>    ]  79.09M  14.3MB/s    in 5.5s
#
# 2024-12-11 23:34:03 (14.3 MB/s) - 'master.zip' saved [82934337]
#
# Archive:  master.zip
# f26a9994b0bafc41096fa269eab89c2757d71499
#    creating: DD-Net-master/
#   inflating: DD-Net-master/.gitignore
#    creating: DD-Net-master/JHMDB/
#   inflating: DD-Net-master/JHMDB/README.md
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_heavy.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_lite.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_middle.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_data_preprocessing.ipynb
#   inflating: DD-Net-master/JHMDB/utils.py
#    creating: DD-Net-master/JHMDB/weights/
#  extracting: DD-Net-master/JHMDB/weights/__init__.py
#   inflating: DD-Net-master/LICENSE
#   inflating: DD-Net-master/README.md
#    creating: DD-Net-master/SHREC/
#   inflating: DD-Net-master/SHREC/README.md
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_lite.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_data_preprocessing.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_lite.ipynb
#    creating: DD-Net-master/SHREC/images/
#   inflating: DD-Net-master/SHREC/images/SHREC_14.png
#   inflating: DD-Net-master/SHREC/images/SHREC_28.png
#   inflating: DD-Net-master/SHREC/utils.py
#    creating: DD-Net-master/SHREC/weights/
#  extracting: DD-Net-master/SHREC/weights/.gitkeep
#  extracting: DD-Net-master/SHREC/weights/__init__.py
#    creating: DD-Net-master/data/
#    creating: DD-Net-master/data/JHMDB/
#   inflating: DD-Net-master/data/JHMDB/GT_test_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_3.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_3.pkl
#   inflating: DD-Net-master/data/JHMDB/joint_positions.zip
#   inflating: DD-Net-master/data/JHMDB/splits.zip
#    creating: DD-Net-master/data/SHREC/
#  extracting: DD-Net-master/data/SHREC/__init__.py
#   inflating: DD-Net-master/data/SHREC/test.pickle
#   inflating: DD-Net-master/data/SHREC/test.pkl
#   inflating: DD-Net-master/data/SHREC/train.pickle
#   inflating: DD-Net-master/data/SHREC/train.pkl
#    creating: DD-Net-master/mics/
#  extracting: DD-Net-master/mics/__init__.py
#   inflating: DD-Net-master/mics/demo.png
#   inflating: DD-Net-master/mics/look.gif
#   inflating: DD-Net-master/mics/paper.png

# %% [markdown]
# # 新段落

# %%
Train = pickle.load(open("/kaggle/working/DD-Net-master/data/JHMDB/GT_train_1.pkl", "rb"))
Test = pickle.load(open("/kaggle/working/DD-Net-master/data/JHMDB/GT_test_1.pkl", "rb"))

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(Train['label'])

X_0,X_1,Y = data_generator(Train,C,le)
X_test_0,X_test_1,Y_test = data_generator(Test,C,le)
# Out:
#   0%|          | 0/433 [00:00<?, ?it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#   4%|▍         | 17/433 [00:00<00:02, 162.22it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#   8%|▊         | 34/433 [00:00<00:02, 158.33it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  12%|█▏        | 51/433 [00:00<00:02, 161.11it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  16%|█▌        | 68/433 [00:00<00:02, 162.58it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  20%|█▉        | 85/433 [00:00<00:02, 162.86it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  24%|██▎       | 102/433 [00:00<00:02, 163.01it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  27%|██▋       | 119/433 [00:00<00:01, 162.32it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  31%|███▏      | 136/433 [00:00<00:01, 163.64it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  35%|███▌      | 153/433 [00:00<00:01, 163.16it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  39%|███▉      | 170/433 [00:01<00:01, 163.53it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# ...
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  73%|███████▎  | 129/176 [00:00<00:00, 153.44it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  82%|████████▏ | 145/176 [00:00<00:00, 153.91it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  91%|█████████▏| 161/176 [00:01<00:00, 153.72it/s]/tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# /tmp/ipykernel_23/3198380831.py:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 176/176 [00:01<00:00, 152.69it/s]

# %% [markdown]
# 5. Start train on split 1

# %%
lr = 1e-3
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
                    batch_size=len(Y),
                    epochs=600,
                    verbose=True,
                    shuffle=True,
                    callbacks=[lrScheduler],
                    validation_data=([X_test_0,X_test_1],Y_test)
                    )
lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
                    batch_size=len(Y),
                    epochs=600,
                    verbose=True,
                    shuffle=True,
                    callbacks=[lrScheduler],
                    validation_data=([X_test_0,X_test_1],Y_test)
                    )
# Out:
# Epoch 1/600
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733960060.567559     105 service.cc:145] XLA service 0x78fa24072fb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733960060.567641     105 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1733960060.567646     105 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44s/step - accuracy: 0.0323 - loss: 3.6332
# I0000 00:00:1733960095.974954     105 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 47s 47s/step - accuracy: 0.0323 - loss: 3.6332 - val_accuracy: 0.0682 - val_loss: 3.0431 - learning_rate: 0.0010
# Epoch 2/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.0808 - loss: 3.2101 - val_accuracy: 0.0682 - val_loss: 3.0413 - learning_rate: 0.0010
# Epoch 3/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.1594 - loss: 2.9422 - val_accuracy: 0.0966 - val_loss: 3.0367 - learning_rate: 0.0010
# Epoch 4/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.2102 - loss: 2.6881 - val_accuracy: 0.2330 - val_loss: 3.0302 - learning_rate: 0.0010
# Epoch 5/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.2610 - loss: 2.5488 - val_accuracy: 0.2045 - val_loss: 3.0233 - learning_rate: 0.0010
# Epoch 6/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.3626 - loss: 2.3203 - val_accuracy: 0.1648 - val_loss: 3.0148 - learning_rate: 0.0010
# Epoch 7/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.3926 - loss: 2.1853 - val_accuracy: 0.0966 - val_loss: 3.0052 - learning_rate: 0.0010
# Epoch 8/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.3903 - loss: 2.0724 - val_accuracy: 0.0966 - val_loss: 2.9931 - learning_rate: 0.0010
# Epoch 9/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4226 - loss: 1.9231 - val_accuracy: 0.1193 - val_loss: 2.9783 - learning_rate: 0.0010
# Epoch 10/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4388 - loss: 1.8115 - val_accuracy: 0.1364 - val_loss: 2.9621 - learning_rate: 0.0010
# Epoch 11/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5173 - loss: 1.7150 - val_accuracy: 0.1705 - val_loss: 2.9444 - learning_rate: 0.0010
# Epoch 12/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5173 - loss: 1.6283 - val_accuracy: 0.1761 - val_loss: 2.9251 - learning_rate: 0.0010
# Epoch 13/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5589 - loss: 1.5158 - val_accuracy: 0.2045 - val_loss: 2.9052 - learning_rate: 0.0010
# Epoch 14/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6051 - loss: 1.4639 - val_accuracy: 0.2102 - val_loss: 2.8868 - learning_rate: 0.0010
# Epoch 15/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6351 - loss: 1.3523 - val_accuracy: 0.2102 - val_loss: 2.8694 - learning_rate: 0.0010
# Epoch 16/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6212 - loss: 1.3689 - val_accuracy: 0.2102 - val_loss: 2.8516 - learning_rate: 0.0010
# Epoch 17/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6628 - loss: 1.2165 - val_accuracy: 0.1875 - val_loss: 2.8332 - learning_rate: 0.0010
# Epoch 18/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6813 - loss: 1.1625 - val_accuracy: 0.1932 - val_loss: 2.8138 - learning_rate: 0.0010
# Epoch 19/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6628 - loss: 1.1531 - val_accuracy: 0.2045 - val_loss: 2.7940 - learning_rate: 0.0010
# Epoch 20/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7206 - loss: 1.0705 - val_accuracy: 0.2159 - val_loss: 2.7721 - learning_rate: 0.0010
# Epoch 21/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7413 - loss: 1.0324 - val_accuracy: 0.2159 - val_loss: 2.7497 - learning_rate: 0.0010
# Epoch 22/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7552 - loss: 0.9178 - val_accuracy: 0.2443 - val_loss: 2.7240 - learning_rate: 0.0010
# Epoch 23/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7275 - loss: 0.9462 - val_accuracy: 0.2500 - val_loss: 2.6998 - learning_rate: 0.0010
# Epoch 24/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7875 - loss: 0.8015 - val_accuracy: 0.2557 - val_loss: 2.6773 - learning_rate: 0.0010
# Epoch 25/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8037 - loss: 0.8046 - val_accuracy: 0.2500 - val_loss: 2.6545 - learning_rate: 0.0010
# Epoch 26/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8037 - loss: 0.7498 - val_accuracy: 0.2614 - val_loss: 2.6336 - learning_rate: 0.0010
# Epoch 27/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8129 - loss: 0.7598 - val_accuracy: 0.2727 - val_loss: 2.6147 - learning_rate: 0.0010
# Epoch 28/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8222 - loss: 0.6987 - val_accuracy: 0.2784 - val_loss: 2.5993 - learning_rate: 0.0010
# Epoch 29/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8614 - loss: 0.6373 - val_accuracy: 0.2898 - val_loss: 2.5862 - learning_rate: 0.0010
# Epoch 30/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8406 - loss: 0.6809 - val_accuracy: 0.2955 - val_loss: 2.5747 - learning_rate: 0.0010
# Epoch 31/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8360 - loss: 0.6301 - val_accuracy: 0.2955 - val_loss: 2.5655 - learning_rate: 0.0010
# Epoch 32/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8406 - loss: 0.5792 - val_accuracy: 0.2898 - val_loss: 2.5585 - learning_rate: 0.0010
# Epoch 33/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8661 - loss: 0.5786 - val_accuracy: 0.2955 - val_loss: 2.5468 - learning_rate: 0.0010
# Epoch 34/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8591 - loss: 0.5690 - val_accuracy: 0.3011 - val_loss: 2.5360 - learning_rate: 0.0010
# Epoch 35/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8753 - loss: 0.5099 - val_accuracy: 0.3182 - val_loss: 2.5239 - learning_rate: 0.0010
# Epoch 36/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9192 - loss: 0.4376 - val_accuracy: 0.3466 - val_loss: 2.5106 - learning_rate: 0.0010
# Epoch 37/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8915 - loss: 0.5024 - val_accuracy: 0.3693 - val_loss: 2.5019 - learning_rate: 0.0010
# Epoch 38/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8984 - loss: 0.4045 - val_accuracy: 0.3693 - val_loss: 2.4957 - learning_rate: 0.0010
# Epoch 39/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9030 - loss: 0.4426 - val_accuracy: 0.3580 - val_loss: 2.4954 - learning_rate: 0.0010
# Epoch 40/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9284 - loss: 0.3986 - val_accuracy: 0.3523 - val_loss: 2.4969 - learning_rate: 0.0010
# Epoch 41/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9307 - loss: 0.3912 - val_accuracy: 0.3466 - val_loss: 2.4979 - learning_rate: 0.0010
# Epoch 42/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9307 - loss: 0.3641 - val_accuracy: 0.3523 - val_loss: 2.4951 - learning_rate: 0.0010
# Epoch 43/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9400 - loss: 0.2894 - val_accuracy: 0.3466 - val_loss: 2.4877 - learning_rate: 0.0010
# Epoch 44/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9284 - loss: 0.3303 - val_accuracy: 0.3523 - val_loss: 2.4814 - learning_rate: 0.0010
# Epoch 45/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9330 - loss: 0.3260 - val_accuracy: 0.3409 - val_loss: 2.4768 - learning_rate: 0.0010
# Epoch 46/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9446 - loss: 0.3011 - val_accuracy: 0.3295 - val_loss: 2.4751 - learning_rate: 0.0010
# Epoch 47/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9515 - loss: 0.2779 - val_accuracy: 0.3239 - val_loss: 2.4770 - learning_rate: 0.0010
# Epoch 48/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9353 - loss: 0.3003 - val_accuracy: 0.3352 - val_loss: 2.4759 - learning_rate: 0.0010
# Epoch 49/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9353 - loss: 0.3099 - val_accuracy: 0.3409 - val_loss: 2.4772 - learning_rate: 0.0010
# Epoch 50/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9376 - loss: 0.2708 - val_accuracy: 0.3409 - val_loss: 2.4794 - learning_rate: 0.0010
# Epoch 51/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9492 - loss: 0.2715 - val_accuracy: 0.3523 - val_loss: 2.4842 - learning_rate: 0.0010
# Epoch 52/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9492 - loss: 0.2311 - val_accuracy: 0.3409 - val_loss: 2.4927 - learning_rate: 0.0010
# Epoch 53/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9515 - loss: 0.2537 - val_accuracy: 0.3409 - val_loss: 2.5002 - learning_rate: 0.0010
# Epoch 54/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9677 - loss: 0.2142 - val_accuracy: 0.3239 - val_loss: 2.5069 - learning_rate: 0.0010
# Epoch 55/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9723 - loss: 0.2179 - val_accuracy: 0.3068 - val_loss: 2.5200 - learning_rate: 0.0010
# Epoch 56/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9630 - loss: 0.2033 - val_accuracy: 0.2727 - val_loss: 2.5412 - learning_rate: 0.0010
# Epoch 57/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9815 - loss: 0.1739 - val_accuracy: 0.2784 - val_loss: 2.5693 - learning_rate: 0.0010
# Epoch 58/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9723 - loss: 0.1940 - val_accuracy: 0.2557 - val_loss: 2.6022 - learning_rate: 0.0010
# Epoch 59/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9700 - loss: 0.1896 - val_accuracy: 0.2273 - val_loss: 2.6391 - learning_rate: 0.0010
# Epoch 60/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9792 - loss: 0.1724 - val_accuracy: 0.2216 - val_loss: 2.6764 - learning_rate: 0.0010
# Epoch 61/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9769 - loss: 0.1654 - val_accuracy: 0.2159 - val_loss: 2.7236 - learning_rate: 0.0010
# Epoch 62/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9792 - loss: 0.1758 - val_accuracy: 0.2102 - val_loss: 2.7536 - learning_rate: 0.0010
# Epoch 63/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9700 - loss: 0.1741 - val_accuracy: 0.2159 - val_loss: 2.7851 - learning_rate: 0.0010
# Epoch 64/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9792 - loss: 0.1518 - val_accuracy: 0.2216 - val_loss: 2.8006 - learning_rate: 0.0010
# Epoch 65/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9838 - loss: 0.1668 - val_accuracy: 0.2216 - val_loss: 2.8193 - learning_rate: 0.0010
# Epoch 66/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9769 - loss: 0.1535 - val_accuracy: 0.2443 - val_loss: 2.8362 - learning_rate: 0.0010
# Epoch 67/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9746 - loss: 0.1605 - val_accuracy: 0.2670 - val_loss: 2.8164 - learning_rate: 0.0010
# Epoch 68/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9792 - loss: 0.1478 - val_accuracy: 0.3011 - val_loss: 2.8086 - learning_rate: 0.0010
# Epoch 69/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9954 - loss: 0.1149 - val_accuracy: 0.3068 - val_loss: 2.7962 - learning_rate: 0.0010
# Epoch 70/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9815 - loss: 0.1346 - val_accuracy: 0.3125 - val_loss: 2.7974 - learning_rate: 0.0010
# Epoch 71/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9885 - loss: 0.1330 - val_accuracy: 0.3239 - val_loss: 2.7897 - learning_rate: 0.0010
# Epoch 72/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9885 - loss: 0.1254 - val_accuracy: 0.3352 - val_loss: 2.7753 - learning_rate: 0.0010
# Epoch 73/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9954 - loss: 0.1081 - val_accuracy: 0.3466 - val_loss: 2.7686 - learning_rate: 0.0010
# Epoch 74/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9908 - loss: 0.1049 - val_accuracy: 0.3466 - val_loss: 2.7498 - learning_rate: 0.0010
# Epoch 75/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9885 - loss: 0.1273 - val_accuracy: 0.3580 - val_loss: 2.7427 - learning_rate: 0.0010
# Epoch 76/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9815 - loss: 0.1289 - val_accuracy: 0.3523 - val_loss: 2.7254 - learning_rate: 0.0010
# Epoch 77/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9885 - loss: 0.1126 - val_accuracy: 0.3580 - val_loss: 2.7109 - learning_rate: 0.0010
# Epoch 78/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9908 - loss: 0.1119 - val_accuracy: 0.3693 - val_loss: 2.6857 - learning_rate: 0.0010
# Epoch 79/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9861 - loss: 0.1111 - val_accuracy: 0.3750 - val_loss: 2.6674 - learning_rate: 0.0010
# Epoch 80/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9931 - loss: 0.1049 - val_accuracy: 0.3750 - val_loss: 2.6662 - learning_rate: 5.0000e-04
# Epoch 81/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9861 - loss: 0.1057 - val_accuracy: 0.3750 - val_loss: 2.6669 - learning_rate: 5.0000e-04
# Epoch 82/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9977 - loss: 0.0848 - val_accuracy: 0.3750 - val_loss: 2.6712 - learning_rate: 5.0000e-04
# Epoch 83/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9861 - loss: 0.1023 - val_accuracy: 0.3693 - val_loss: 2.6808 - learning_rate: 5.0000e-04
# Epoch 84/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9931 - loss: 0.1215 - val_accuracy: 0.3466 - val_loss: 2.6891 - learning_rate: 5.0000e-04
# Epoch 85/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9931 - loss: 0.0850 - val_accuracy: 0.3466 - val_loss: 2.6917 - learning_rate: 5.0000e-04
# Epoch 86/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0808 - val_accuracy: 0.3466 - val_loss: 2.7024 - learning_rate: 5.0000e-04
# Epoch 87/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9815 - loss: 0.1110 - val_accuracy: 0.3466 - val_loss: 2.7214 - learning_rate: 5.0000e-04
# Epoch 88/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9885 - loss: 0.0903 - val_accuracy: 0.3466 - val_loss: 2.7405 - learning_rate: 5.0000e-04
# Epoch 89/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9954 - loss: 0.0844 - val_accuracy: 0.3466 - val_loss: 2.7661 - learning_rate: 5.0000e-04
# Epoch 90/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9977 - loss: 0.0790 - val_accuracy: 0.3409 - val_loss: 2.7890 - learning_rate: 5.0000e-04
# Epoch 91/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9931 - loss: 0.0979 - val_accuracy: 0.3409 - val_loss: 2.8135 - learning_rate: 5.0000e-04
# Epoch 92/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9908 - loss: 0.0866 - val_accuracy: 0.3409 - val_loss: 2.8363 - learning_rate: 5.0000e-04
# Epoch 93/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0725 - val_accuracy: 0.3409 - val_loss: 2.8592 - learning_rate: 5.0000e-04
# Epoch 94/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9977 - loss: 0.0678 - val_accuracy: 0.3409 - val_loss: 2.8835 - learning_rate: 5.0000e-04
# Epoch 95/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0765 - val_accuracy: 0.3409 - val_loss: 2.9080 - learning_rate: 5.0000e-04
# Epoch 96/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9977 - loss: 0.0720 - val_accuracy: 0.3409 - val_loss: 2.9279 - learning_rate: 5.0000e-04
# Epoch 97/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9977 - loss: 0.0833 - val_accuracy: 0.3352 - val_loss: 2.9499 - learning_rate: 5.0000e-04
# Epoch 98/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9954 - loss: 0.0798 - val_accuracy: 0.3352 - val_loss: 2.9674 - learning_rate: 5.0000e-04
# Epoch 99/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0689 - val_accuracy: 0.3352 - val_loss: 2.9825 - learning_rate: 5.0000e-04
# Epoch 100/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0715 - val_accuracy: 0.3352 - val_loss: 2.9882 - learning_rate: 2.5000e-04
# Epoch 101/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9954 - loss: 0.0631 - val_accuracy: 0.3352 - val_loss: 2.9932 - learning_rate: 2.5000e-04
# Epoch 102/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9954 - loss: 0.0793 - val_accuracy: 0.3352 - val_loss: 2.9964 - learning_rate: 2.5000e-04
# Epoch 103/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0696 - val_accuracy: 0.3352 - val_loss: 2.9982 - learning_rate: 2.5000e-04
# Epoch 104/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9954 - loss: 0.0752 - val_accuracy: 0.3352 - val_loss: 2.9977 - learning_rate: 2.5000e-04
# Epoch 105/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9931 - loss: 0.0615 - val_accuracy: 0.3466 - val_loss: 2.9939 - learning_rate: 2.5000e-04
# Epoch 106/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9931 - loss: 0.0720 - val_accuracy: 0.3466 - val_loss: 2.9863 - learning_rate: 2.5000e-04
# Epoch 107/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9931 - loss: 0.0897 - val_accuracy: 0.3466 - val_loss: 2.9741 - learning_rate: 2.5000e-04
# Epoch 108/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9931 - loss: 0.0684 - val_accuracy: 0.3466 - val_loss: 2.9653 - learning_rate: 2.5000e-04
# Epoch 109/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9885 - loss: 0.0697 - val_accuracy: 0.3523 - val_loss: 2.9540 - learning_rate: 2.5000e-04
# Epoch 110/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9954 - loss: 0.0647 - val_accuracy: 0.3636 - val_loss: 2.9421 - learning_rate: 2.5000e-04
# Epoch 111/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0684 - val_accuracy: 0.3636 - val_loss: 2.9377 - learning_rate: 1.2500e-04
# Epoch 112/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9954 - loss: 0.0723 - val_accuracy: 0.3636 - val_loss: 2.9357 - learning_rate: 1.2500e-04
# Epoch 113/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9931 - loss: 0.0711 - val_accuracy: 0.3750 - val_loss: 2.9331 - learning_rate: 1.2500e-04
# Epoch 114/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9977 - loss: 0.0600 - val_accuracy: 0.3750 - val_loss: 2.9310 - learning_rate: 1.2500e-04
# Epoch 115/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9977 - loss: 0.0749 - val_accuracy: 0.3750 - val_loss: 2.9306 - learning_rate: 1.2500e-04
# Epoch 116/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0663 - val_accuracy: 0.3750 - val_loss: 2.9267 - learning_rate: 1.2500e-04
# Epoch 117/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0604 - val_accuracy: 0.3750 - val_loss: 2.9236 - learning_rate: 1.2500e-04
# Epoch 118/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9977 - loss: 0.0640 - val_accuracy: 0.3750 - val_loss: 2.9208 - learning_rate: 1.2500e-04
# Epoch 119/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0663 - val_accuracy: 0.3750 - val_loss: 2.9205 - learning_rate: 1.2500e-04
# Epoch 120/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9954 - loss: 0.0618 - val_accuracy: 0.3750 - val_loss: 2.9241 - learning_rate: 6.2500e-05
# Epoch 121/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9954 - loss: 0.0759 - val_accuracy: 0.3750 - val_loss: 2.9290 - learning_rate: 6.2500e-05
# Epoch 122/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0523 - val_accuracy: 0.3750 - val_loss: 2.9324 - learning_rate: 6.2500e-05
# Epoch 123/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0705 - val_accuracy: 0.3750 - val_loss: 2.9367 - learning_rate: 6.2500e-05
# Epoch 124/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9954 - loss: 0.0654 - val_accuracy: 0.3750 - val_loss: 2.9406 - learning_rate: 6.2500e-05
# Epoch 125/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9931 - loss: 0.0668 - val_accuracy: 0.3750 - val_loss: 2.9450 - learning_rate: 6.2500e-05
# Epoch 126/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9931 - loss: 0.0567 - val_accuracy: 0.3750 - val_loss: 2.9508 - learning_rate: 6.2500e-05
# Epoch 127/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0865 - val_accuracy: 0.3750 - val_loss: 2.9553 - learning_rate: 6.2500e-05
# Epoch 128/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0605 - val_accuracy: 0.3750 - val_loss: 2.9593 - learning_rate: 6.2500e-05
# Epoch 129/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9931 - loss: 0.0699 - val_accuracy: 0.3750 - val_loss: 2.9625 - learning_rate: 3.1250e-05
# Epoch 130/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0531 - val_accuracy: 0.3750 - val_loss: 2.9666 - learning_rate: 3.1250e-05
# Epoch 131/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9908 - loss: 0.0847 - val_accuracy: 0.3750 - val_loss: 2.9710 - learning_rate: 3.1250e-05
# Epoch 132/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9931 - loss: 0.0728 - val_accuracy: 0.3750 - val_loss: 2.9747 - learning_rate: 3.1250e-05
# Epoch 133/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9977 - loss: 0.0601 - val_accuracy: 0.3750 - val_loss: 2.9778 - learning_rate: 3.1250e-05
# Epoch 134/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9977 - loss: 0.0616 - val_accuracy: 0.3750 - val_loss: 2.9803 - learning_rate: 3.1250e-05
# Epoch 135/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9977 - loss: 0.0590 - val_accuracy: 0.3750 - val_loss: 2.9828 - learning_rate: 3.1250e-05
# Epoch 136/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9954 - loss: 0.0660 - val_accuracy: 0.3750 - val_loss: 2.9850 - learning_rate: 3.1250e-05
# Epoch 137/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9954 - loss: 0.0610 - val_accuracy: 0.3750 - val_loss: 2.9872 - learning_rate: 3.1250e-05
# Epoch 138/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0655 - val_accuracy: 0.3750 - val_loss: 2.9884 - learning_rate: 1.5625e-05
# Epoch 139/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9931 - loss: 0.0605 - val_accuracy: 0.3750 - val_loss: 2.9903 - learning_rate: 1.5625e-05
# Epoch 140/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9908 - loss: 0.0678 - val_accuracy: 0.3750 - val_loss: 2.9920 - learning_rate: 1.5625e-05
# Epoch 141/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9931 - loss: 0.0785 - val_accuracy: 0.3750 - val_loss: 2.9936 - learning_rate: 1.5625e-05
# Epoch 142/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9954 - loss: 0.0586 - val_accuracy: 0.3750 - val_loss: 2.9953 - learning_rate: 1.5625e-05
# Epoch 143/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9954 - loss: 0.0645 - val_accuracy: 0.3750 - val_loss: 2.9958 - learning_rate: 1.5625e-05
# Epoch 144/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0719 - val_accuracy: 0.3750 - val_loss: 2.9963 - learning_rate: 1.5625e-05
# Epoch 145/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0784 - val_accuracy: 0.3750 - val_loss: 2.9964 - learning_rate: 1.5625e-05
# Epoch 146/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9931 - loss: 0.0602 - val_accuracy: 0.3750 - val_loss: 2.9971 - learning_rate: 1.5625e-05
# Epoch 147/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9885 - loss: 0.0770 - val_accuracy: 0.3750 - val_loss: 2.9963 - learning_rate: 7.8125e-06
# Epoch 148/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9908 - loss: 0.0724 - val_accuracy: 0.3750 - val_loss: 2.9958 - learning_rate: 7.8125e-06
# Epoch 149/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9977 - loss: 0.0611 - val_accuracy: 0.3750 - val_loss: 2.9963 - learning_rate: 7.8125e-06
# Epoch 150/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9838 - loss: 0.0797 - val_accuracy: 0.3750 - val_loss: 2.9955 - learning_rate: 7.8125e-06
# Epoch 151/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9977 - loss: 0.0617 - val_accuracy: 0.3750 - val_loss: 2.9953 - learning_rate: 7.8125e-06
# Epoch 152/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0691 - val_accuracy: 0.3750 - val_loss: 2.9944 - learning_rate: 7.8125e-06
# Epoch 153/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9954 - loss: 0.0751 - val_accuracy: 0.3750 - val_loss: 2.9932 - learning_rate: 7.8125e-06
# Epoch 154/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0618 - val_accuracy: 0.3807 - val_loss: 2.9924 - learning_rate: 7.8125e-06
# Epoch 155/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9885 - loss: 0.0811 - val_accuracy: 0.3807 - val_loss: 2.9908 - learning_rate: 7.8125e-06
# Epoch 156/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9977 - loss: 0.0621 - val_accuracy: 0.3807 - val_loss: 2.9896 - learning_rate: 5.0000e-06
# Epoch 157/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9885 - loss: 0.0710 - val_accuracy: 0.3807 - val_loss: 2.9896 - learning_rate: 5.0000e-06
# Epoch 158/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9885 - loss: 0.0837 - val_accuracy: 0.3807 - val_loss: 2.9882 - learning_rate: 5.0000e-06
# Epoch 159/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9977 - loss: 0.0704 - val_accuracy: 0.3807 - val_loss: 2.9872 - learning_rate: 5.0000e-06
# Epoch 160/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9977 - loss: 0.0638 - val_accuracy: 0.3807 - val_loss: 2.9853 - learning_rate: 5.0000e-06
# Epoch 161/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 0.0607 - val_accuracy: 0.3807 - val_loss: 2.9837 - learning_rate: 5.0000e-06
# Epoch 162/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9954 - loss: 0.0659 - val_accuracy: 0.3807 - val_loss: 2.9824 - learning_rate: 5.0000e-06
# Epoch 163/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9931 - loss: 0.0548 - val_accuracy: 0.3807 - val_loss: 2.9801 - learning_rate: 5.0000e-06
# Epoch 164/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9908 - loss: 0.0742 - val_accuracy: 0.3807 - val_loss: 2.9782 - learning_rate: 5.0000e-06
# Epoch 165/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0541 - val_accuracy: 0.3807 - val_loss: 2.9763 - learning_rate: 5.0000e-06
# Epoch 166/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0594 - val_accuracy: 0.3807 - val_loss: 2.9734 - learning_rate: 5.0000e-06
# Epoch 167/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0772 - val_accuracy: 0.3750 - val_loss: 2.9705 - learning_rate: 5.0000e-06
# Epoch 168/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9977 - loss: 0.0733 - val_accuracy: 0.3750 - val_loss: 2.9690 - learning_rate: 5.0000e-06
# Epoch 169/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9977 - loss: 0.0666 - val_accuracy: 0.3750 - val_loss: 2.9677 - learning_rate: 5.0000e-06
# Epoch 170/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9931 - loss: 0.0678 - val_accuracy: 0.3750 - val_loss: 2.9652 - learning_rate: 5.0000e-06
# Epoch 171/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0572 - val_accuracy: 0.3750 - val_loss: 2.9628 - learning_rate: 5.0000e-06
# Epoch 172/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9954 - loss: 0.0618 - val_accuracy: 0.3750 - val_loss: 2.9603 - learning_rate: 5.0000e-06
# Epoch 173/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9977 - loss: 0.0571 - val_accuracy: 0.3750 - val_loss: 2.9573 - learning_rate: 5.0000e-06
# Epoch 174/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0582 - val_accuracy: 0.3750 - val_loss: 2.9554 - learning_rate: 5.0000e-06
# Epoch 175/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9977 - loss: 0.0662 - val_accuracy: 0.3807 - val_loss: 2.9531 - learning_rate: 5.0000e-06
# Epoch 176/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9977 - loss: 0.0683 - val_accuracy: 0.3807 - val_loss: 2.9510 - learning_rate: 5.0000e-06
# Epoch 177/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0693 - val_accuracy: 0.3807 - val_loss: 2.9481 - learning_rate: 5.0000e-06
# Epoch 178/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0673 - val_accuracy: 0.3807 - val_loss: 2.9453 - learning_rate: 5.0000e-06
# Epoch 179/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0565 - val_accuracy: 0.3807 - val_loss: 2.9421 - learning_rate: 5.0000e-06
# Epoch 180/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0657 - val_accuracy: 0.3807 - val_loss: 2.9385 - learning_rate: 5.0000e-06
# Epoch 181/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0687 - val_accuracy: 0.3807 - val_loss: 2.9360 - learning_rate: 5.0000e-06
# Epoch 182/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9931 - loss: 0.0744 - val_accuracy: 0.3807 - val_loss: 2.9328 - learning_rate: 5.0000e-06
# Epoch 183/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9908 - loss: 0.0648 - val_accuracy: 0.3807 - val_loss: 2.9300 - learning_rate: 5.0000e-06
# Epoch 184/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9954 - loss: 0.0637 - val_accuracy: 0.3807 - val_loss: 2.9267 - learning_rate: 5.0000e-06
# Epoch 185/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9908 - loss: 0.0720 - val_accuracy: 0.3807 - val_loss: 2.9241 - learning_rate: 5.0000e-06
# Epoch 186/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9954 - loss: 0.0649 - val_accuracy: 0.3807 - val_loss: 2.9207 - learning_rate: 5.0000e-06
# Epoch 187/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9908 - loss: 0.0663 - val_accuracy: 0.3807 - val_loss: 2.9177 - learning_rate: 5.0000e-06
# Epoch 188/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9931 - loss: 0.0676 - val_accuracy: 0.3807 - val_loss: 2.9143 - learning_rate: 5.0000e-06
# Epoch 189/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0761 - val_accuracy: 0.3807 - val_loss: 2.9105 - learning_rate: 5.0000e-06
# Epoch 190/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0608 - val_accuracy: 0.3864 - val_loss: 2.9066 - learning_rate: 5.0000e-06
# Epoch 191/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0676 - val_accuracy: 0.3920 - val_loss: 2.9029 - learning_rate: 5.0000e-06
# Epoch 192/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0746 - val_accuracy: 0.3920 - val_loss: 2.8994 - learning_rate: 5.0000e-06
# Epoch 193/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0700 - val_accuracy: 0.3864 - val_loss: 2.8959 - learning_rate: 5.0000e-06
# Epoch 194/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9931 - loss: 0.0620 - val_accuracy: 0.3920 - val_loss: 2.8923 - learning_rate: 5.0000e-06
# Epoch 195/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0647 - val_accuracy: 0.3920 - val_loss: 2.8882 - learning_rate: 5.0000e-06
# Epoch 196/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0544 - val_accuracy: 0.3920 - val_loss: 2.8844 - learning_rate: 5.0000e-06
# Epoch 197/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0639 - val_accuracy: 0.3977 - val_loss: 2.8807 - learning_rate: 5.0000e-06
# Epoch 198/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9954 - loss: 0.0617 - val_accuracy: 0.3977 - val_loss: 2.8758 - learning_rate: 5.0000e-06
# Epoch 199/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9931 - loss: 0.0675 - val_accuracy: 0.3977 - val_loss: 2.8718 - learning_rate: 5.0000e-06
# Epoch 200/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9977 - loss: 0.0680 - val_accuracy: 0.3977 - val_loss: 2.8678 - learning_rate: 5.0000e-06
# Epoch 201/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9977 - loss: 0.0636 - val_accuracy: 0.3977 - val_loss: 2.8641 - learning_rate: 5.0000e-06
# Epoch 202/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9954 - loss: 0.0617 - val_accuracy: 0.3977 - val_loss: 2.8602 - learning_rate: 5.0000e-06
# Epoch 203/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9977 - loss: 0.0617 - val_accuracy: 0.3977 - val_loss: 2.8558 - learning_rate: 5.0000e-06
# Epoch 204/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9954 - loss: 0.0743 - val_accuracy: 0.3977 - val_loss: 2.8513 - learning_rate: 5.0000e-06
# Epoch 205/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9931 - loss: 0.0681 - val_accuracy: 0.4034 - val_loss: 2.8467 - learning_rate: 5.0000e-06
# Epoch 206/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0628 - val_accuracy: 0.4034 - val_loss: 2.8423 - learning_rate: 5.0000e-06
# Epoch 207/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9977 - loss: 0.0606 - val_accuracy: 0.4034 - val_loss: 2.8373 - learning_rate: 5.0000e-06
# Epoch 208/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9931 - loss: 0.0634 - val_accuracy: 0.4034 - val_loss: 2.8319 - learning_rate: 5.0000e-06
# Epoch 209/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9977 - loss: 0.0647 - val_accuracy: 0.4034 - val_loss: 2.8264 - learning_rate: 5.0000e-06
# Epoch 210/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9931 - loss: 0.0704 - val_accuracy: 0.4034 - val_loss: 2.8217 - learning_rate: 5.0000e-06
# Epoch 211/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0562 - val_accuracy: 0.4091 - val_loss: 2.8167 - learning_rate: 5.0000e-06
# Epoch 212/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0738 - val_accuracy: 0.4034 - val_loss: 2.8115 - learning_rate: 5.0000e-06
# Epoch 213/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9954 - loss: 0.0650 - val_accuracy: 0.4034 - val_loss: 2.8075 - learning_rate: 5.0000e-06
# Epoch 214/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0618 - val_accuracy: 0.4034 - val_loss: 2.8018 - learning_rate: 5.0000e-06
# Epoch 215/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0736 - val_accuracy: 0.4034 - val_loss: 2.7967 - learning_rate: 5.0000e-06
# Epoch 216/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9931 - loss: 0.0721 - val_accuracy: 0.4034 - val_loss: 2.7923 - learning_rate: 5.0000e-06
# Epoch 217/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9885 - loss: 0.0727 - val_accuracy: 0.4034 - val_loss: 2.7867 - learning_rate: 5.0000e-06
# Epoch 218/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0583 - val_accuracy: 0.4148 - val_loss: 2.7818 - learning_rate: 5.0000e-06
# Epoch 219/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0668 - val_accuracy: 0.4148 - val_loss: 2.7764 - learning_rate: 5.0000e-06
# Epoch 220/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0598 - val_accuracy: 0.4148 - val_loss: 2.7716 - learning_rate: 5.0000e-06
# Epoch 221/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9977 - loss: 0.0530 - val_accuracy: 0.4148 - val_loss: 2.7658 - learning_rate: 5.0000e-06
# Epoch 222/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0598 - val_accuracy: 0.4148 - val_loss: 2.7606 - learning_rate: 5.0000e-06
# Epoch 223/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0627 - val_accuracy: 0.4148 - val_loss: 2.7547 - learning_rate: 5.0000e-06
# Epoch 224/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0696 - val_accuracy: 0.4148 - val_loss: 2.7500 - learning_rate: 5.0000e-06
# Epoch 225/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0634 - val_accuracy: 0.4148 - val_loss: 2.7437 - learning_rate: 5.0000e-06
# Epoch 226/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0502 - val_accuracy: 0.4148 - val_loss: 2.7385 - learning_rate: 5.0000e-06
# Epoch 227/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0623 - val_accuracy: 0.4148 - val_loss: 2.7326 - learning_rate: 5.0000e-06
# Epoch 228/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0620 - val_accuracy: 0.4148 - val_loss: 2.7268 - learning_rate: 5.0000e-06
# Epoch 229/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9931 - loss: 0.0639 - val_accuracy: 0.4148 - val_loss: 2.7209 - learning_rate: 5.0000e-06
# Epoch 230/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0674 - val_accuracy: 0.4148 - val_loss: 2.7153 - learning_rate: 5.0000e-06
# Epoch 231/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9954 - loss: 0.0610 - val_accuracy: 0.4148 - val_loss: 2.7095 - learning_rate: 5.0000e-06
# Epoch 232/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0464 - val_accuracy: 0.4205 - val_loss: 2.7037 - learning_rate: 5.0000e-06
# Epoch 233/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0701 - val_accuracy: 0.4205 - val_loss: 2.6981 - learning_rate: 5.0000e-06
# Epoch 234/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0648 - val_accuracy: 0.4205 - val_loss: 2.6928 - learning_rate: 5.0000e-06
# Epoch 235/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0668 - val_accuracy: 0.4205 - val_loss: 2.6875 - learning_rate: 5.0000e-06
# Epoch 236/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0520 - val_accuracy: 0.4205 - val_loss: 2.6815 - learning_rate: 5.0000e-06
# Epoch 237/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9908 - loss: 0.0739 - val_accuracy: 0.4205 - val_loss: 2.6758 - learning_rate: 5.0000e-06
# Epoch 238/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0580 - val_accuracy: 0.4205 - val_loss: 2.6702 - learning_rate: 5.0000e-06
# Epoch 239/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0619 - val_accuracy: 0.4205 - val_loss: 2.6648 - learning_rate: 5.0000e-06
# Epoch 240/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0640 - val_accuracy: 0.4205 - val_loss: 2.6586 - learning_rate: 5.0000e-06
# Epoch 241/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9931 - loss: 0.0695 - val_accuracy: 0.4261 - val_loss: 2.6527 - learning_rate: 5.0000e-06
# Epoch 242/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9954 - loss: 0.0693 - val_accuracy: 0.4261 - val_loss: 2.6465 - learning_rate: 5.0000e-06
# Epoch 243/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0666 - val_accuracy: 0.4205 - val_loss: 2.6405 - learning_rate: 5.0000e-06
# Epoch 244/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0657 - val_accuracy: 0.4261 - val_loss: 2.6342 - learning_rate: 5.0000e-06
# Epoch 245/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0611 - val_accuracy: 0.4261 - val_loss: 2.6276 - learning_rate: 5.0000e-06
# Epoch 246/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9931 - loss: 0.0597 - val_accuracy: 0.4318 - val_loss: 2.6217 - learning_rate: 5.0000e-06
# Epoch 247/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9908 - loss: 0.0662 - val_accuracy: 0.4318 - val_loss: 2.6154 - learning_rate: 5.0000e-06
# Epoch 248/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0532 - val_accuracy: 0.4318 - val_loss: 2.6091 - learning_rate: 5.0000e-06
# Epoch 249/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9954 - loss: 0.0631 - val_accuracy: 0.4318 - val_loss: 2.6027 - learning_rate: 5.0000e-06
# Epoch 250/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0600 - val_accuracy: 0.4318 - val_loss: 2.5967 - learning_rate: 5.0000e-06
# Epoch 251/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0658 - val_accuracy: 0.4318 - val_loss: 2.5905 - learning_rate: 5.0000e-06
# Epoch 252/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0587 - val_accuracy: 0.4318 - val_loss: 2.5844 - learning_rate: 5.0000e-06
# Epoch 253/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9977 - loss: 0.0716 - val_accuracy: 0.4318 - val_loss: 2.5777 - learning_rate: 5.0000e-06
# Epoch 254/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0506 - val_accuracy: 0.4318 - val_loss: 2.5715 - learning_rate: 5.0000e-06
# Epoch 255/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9954 - loss: 0.0661 - val_accuracy: 0.4375 - val_loss: 2.5647 - learning_rate: 5.0000e-06
# Epoch 256/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9931 - loss: 0.0660 - val_accuracy: 0.4375 - val_loss: 2.5587 - learning_rate: 5.0000e-06
# Epoch 257/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0775 - val_accuracy: 0.4375 - val_loss: 2.5527 - learning_rate: 5.0000e-06
# Epoch 258/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0645 - val_accuracy: 0.4375 - val_loss: 2.5465 - learning_rate: 5.0000e-06
# Epoch 259/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0623 - val_accuracy: 0.4375 - val_loss: 2.5407 - learning_rate: 5.0000e-06
# Epoch 260/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0637 - val_accuracy: 0.4375 - val_loss: 2.5342 - learning_rate: 5.0000e-06
# Epoch 261/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9977 - loss: 0.0605 - val_accuracy: 0.4375 - val_loss: 2.5278 - learning_rate: 5.0000e-06
# Epoch 262/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9931 - loss: 0.0635 - val_accuracy: 0.4375 - val_loss: 2.5217 - learning_rate: 5.0000e-06
# Epoch 263/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0578 - val_accuracy: 0.4375 - val_loss: 2.5158 - learning_rate: 5.0000e-06
# Epoch 264/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0543 - val_accuracy: 0.4375 - val_loss: 2.5093 - learning_rate: 5.0000e-06
# Epoch 265/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0574 - val_accuracy: 0.4432 - val_loss: 2.5030 - learning_rate: 5.0000e-06
# Epoch 266/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0717 - val_accuracy: 0.4432 - val_loss: 2.4966 - learning_rate: 5.0000e-06
# Epoch 267/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9931 - loss: 0.0720 - val_accuracy: 0.4432 - val_loss: 2.4901 - learning_rate: 5.0000e-06
# Epoch 268/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9908 - loss: 0.0704 - val_accuracy: 0.4432 - val_loss: 2.4835 - learning_rate: 5.0000e-06
# Epoch 269/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0549 - val_accuracy: 0.4432 - val_loss: 2.4764 - learning_rate: 5.0000e-06
# Epoch 270/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9908 - loss: 0.0614 - val_accuracy: 0.4432 - val_loss: 2.4694 - learning_rate: 5.0000e-06
# Epoch 271/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0555 - val_accuracy: 0.4432 - val_loss: 2.4631 - learning_rate: 5.0000e-06
# Epoch 272/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0645 - val_accuracy: 0.4432 - val_loss: 2.4558 - learning_rate: 5.0000e-06
# Epoch 273/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0594 - val_accuracy: 0.4489 - val_loss: 2.4500 - learning_rate: 5.0000e-06
# Epoch 274/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0728 - val_accuracy: 0.4489 - val_loss: 2.4439 - learning_rate: 5.0000e-06
# Epoch 275/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9931 - loss: 0.0629 - val_accuracy: 0.4489 - val_loss: 2.4374 - learning_rate: 5.0000e-06
# Epoch 276/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9885 - loss: 0.0735 - val_accuracy: 0.4489 - val_loss: 2.4308 - learning_rate: 5.0000e-06
# Epoch 277/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0575 - val_accuracy: 0.4489 - val_loss: 2.4243 - learning_rate: 5.0000e-06
# Epoch 278/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0583 - val_accuracy: 0.4545 - val_loss: 2.4176 - learning_rate: 5.0000e-06
# Epoch 279/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0595 - val_accuracy: 0.4545 - val_loss: 2.4113 - learning_rate: 5.0000e-06
# Epoch 280/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0624 - val_accuracy: 0.4545 - val_loss: 2.4050 - learning_rate: 5.0000e-06
# Epoch 281/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9908 - loss: 0.0734 - val_accuracy: 0.4545 - val_loss: 2.3982 - learning_rate: 5.0000e-06
# Epoch 282/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9861 - loss: 0.0848 - val_accuracy: 0.4545 - val_loss: 2.3911 - learning_rate: 5.0000e-06
# Epoch 283/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9954 - loss: 0.0630 - val_accuracy: 0.4545 - val_loss: 2.3838 - learning_rate: 5.0000e-06
# Epoch 284/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0679 - val_accuracy: 0.4545 - val_loss: 2.3770 - learning_rate: 5.0000e-06
# Epoch 285/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0689 - val_accuracy: 0.4602 - val_loss: 2.3702 - learning_rate: 5.0000e-06
# Epoch 286/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9931 - loss: 0.0532 - val_accuracy: 0.4602 - val_loss: 2.3633 - learning_rate: 5.0000e-06
# Epoch 287/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9977 - loss: 0.0550 - val_accuracy: 0.4602 - val_loss: 2.3573 - learning_rate: 5.0000e-06
# Epoch 288/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9954 - loss: 0.0660 - val_accuracy: 0.4602 - val_loss: 2.3508 - learning_rate: 5.0000e-06
# Epoch 289/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0554 - val_accuracy: 0.4659 - val_loss: 2.3443 - learning_rate: 5.0000e-06
# Epoch 290/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9908 - loss: 0.0673 - val_accuracy: 0.4659 - val_loss: 2.3380 - learning_rate: 5.0000e-06
# Epoch 291/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9931 - loss: 0.0667 - val_accuracy: 0.4659 - val_loss: 2.3312 - learning_rate: 5.0000e-06
# Epoch 292/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0552 - val_accuracy: 0.4659 - val_loss: 2.3241 - learning_rate: 5.0000e-06
# Epoch 293/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0654 - val_accuracy: 0.4716 - val_loss: 2.3172 - learning_rate: 5.0000e-06
# Epoch 294/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9908 - loss: 0.0702 - val_accuracy: 0.4716 - val_loss: 2.3103 - learning_rate: 5.0000e-06
# Epoch 295/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0722 - val_accuracy: 0.4716 - val_loss: 2.3031 - learning_rate: 5.0000e-06
# Epoch 296/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0679 - val_accuracy: 0.4773 - val_loss: 2.2963 - learning_rate: 5.0000e-06
# Epoch 297/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9908 - loss: 0.0736 - val_accuracy: 0.4886 - val_loss: 2.2898 - learning_rate: 5.0000e-06
# Epoch 298/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9885 - loss: 0.0821 - val_accuracy: 0.4886 - val_loss: 2.2832 - learning_rate: 5.0000e-06
# Epoch 299/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0648 - val_accuracy: 0.4886 - val_loss: 2.2764 - learning_rate: 5.0000e-06
# Epoch 300/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9931 - loss: 0.0739 - val_accuracy: 0.4943 - val_loss: 2.2697 - learning_rate: 5.0000e-06
# Epoch 301/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0726 - val_accuracy: 0.5000 - val_loss: 2.2630 - learning_rate: 5.0000e-06
# Epoch 302/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0675 - val_accuracy: 0.5000 - val_loss: 2.2560 - learning_rate: 5.0000e-06
# Epoch 303/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9931 - loss: 0.0689 - val_accuracy: 0.5057 - val_loss: 2.2498 - learning_rate: 5.0000e-06
# Epoch 304/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9977 - loss: 0.0585 - val_accuracy: 0.5057 - val_loss: 2.2433 - learning_rate: 5.0000e-06
# Epoch 305/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9908 - loss: 0.0813 - val_accuracy: 0.5114 - val_loss: 2.2365 - learning_rate: 5.0000e-06
# Epoch 306/600
# ...
# Epoch 499/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9931 - loss: 0.0629 - val_accuracy: 0.8239 - val_loss: 0.7190 - learning_rate: 5.0000e-06
# Epoch 500/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0499 - val_accuracy: 0.8239 - val_loss: 0.7189 - learning_rate: 5.0000e-06
# Epoch 501/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0497 - val_accuracy: 0.8239 - val_loss: 0.7190 - learning_rate: 5.0000e-06
# Epoch 502/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0646 - val_accuracy: 0.8239 - val_loss: 0.7193 - learning_rate: 5.0000e-06
# Epoch 503/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0464 - val_accuracy: 0.8239 - val_loss: 0.7194 - learning_rate: 5.0000e-06
# Epoch 504/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0432 - val_accuracy: 0.8239 - val_loss: 0.7194 - learning_rate: 5.0000e-06
# Epoch 505/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0465 - val_accuracy: 0.8239 - val_loss: 0.7196 - learning_rate: 5.0000e-06
# Epoch 506/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0459 - val_accuracy: 0.8239 - val_loss: 0.7197 - learning_rate: 5.0000e-06
# Epoch 507/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0536 - val_accuracy: 0.8239 - val_loss: 0.7199 - learning_rate: 5.0000e-06
# Epoch 508/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0474 - val_accuracy: 0.8239 - val_loss: 0.7200 - learning_rate: 5.0000e-06
# Epoch 509/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0527 - val_accuracy: 0.8239 - val_loss: 0.7204 - learning_rate: 5.0000e-06
# Epoch 510/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0391 - val_accuracy: 0.8239 - val_loss: 0.7204 - learning_rate: 5.0000e-06
# Epoch 511/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0419 - val_accuracy: 0.8239 - val_loss: 0.7204 - learning_rate: 5.0000e-06
# Epoch 512/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9931 - loss: 0.0470 - val_accuracy: 0.8239 - val_loss: 0.7205 - learning_rate: 5.0000e-06
# Epoch 513/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9954 - loss: 0.0496 - val_accuracy: 0.8239 - val_loss: 0.7204 - learning_rate: 5.0000e-06
# Epoch 514/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0441 - val_accuracy: 0.8239 - val_loss: 0.7205 - learning_rate: 5.0000e-06
# Epoch 515/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0520 - val_accuracy: 0.8239 - val_loss: 0.7205 - learning_rate: 5.0000e-06
# Epoch 516/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0398 - val_accuracy: 0.8239 - val_loss: 0.7206 - learning_rate: 5.0000e-06
# Epoch 517/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9954 - loss: 0.0541 - val_accuracy: 0.8239 - val_loss: 0.7207 - learning_rate: 5.0000e-06
# Epoch 518/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0483 - val_accuracy: 0.8182 - val_loss: 0.7208 - learning_rate: 5.0000e-06
# Epoch 519/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9908 - loss: 0.0518 - val_accuracy: 0.8182 - val_loss: 0.7209 - learning_rate: 5.0000e-06
# Epoch 520/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0432 - val_accuracy: 0.8182 - val_loss: 0.7212 - learning_rate: 5.0000e-06
# Epoch 521/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0554 - val_accuracy: 0.8182 - val_loss: 0.7214 - learning_rate: 5.0000e-06
# Epoch 522/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0451 - val_accuracy: 0.8182 - val_loss: 0.7214 - learning_rate: 5.0000e-06
# Epoch 523/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9954 - loss: 0.0442 - val_accuracy: 0.8182 - val_loss: 0.7217 - learning_rate: 5.0000e-06
# Epoch 524/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0437 - val_accuracy: 0.8182 - val_loss: 0.7218 - learning_rate: 5.0000e-06
# Epoch 525/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0351 - val_accuracy: 0.8182 - val_loss: 0.7220 - learning_rate: 5.0000e-06
# Epoch 526/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0462 - val_accuracy: 0.8182 - val_loss: 0.7221 - learning_rate: 5.0000e-06
# Epoch 527/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0424 - val_accuracy: 0.8182 - val_loss: 0.7223 - learning_rate: 5.0000e-06
# Epoch 528/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0489 - val_accuracy: 0.8182 - val_loss: 0.7223 - learning_rate: 5.0000e-06
# Epoch 529/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0389 - val_accuracy: 0.8182 - val_loss: 0.7224 - learning_rate: 5.0000e-06
# Epoch 530/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0405 - val_accuracy: 0.8182 - val_loss: 0.7225 - learning_rate: 5.0000e-06
# Epoch 531/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0539 - val_accuracy: 0.8182 - val_loss: 0.7227 - learning_rate: 5.0000e-06
# Epoch 532/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0400 - val_accuracy: 0.8182 - val_loss: 0.7228 - learning_rate: 5.0000e-06
# Epoch 533/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0475 - val_accuracy: 0.8182 - val_loss: 0.7229 - learning_rate: 5.0000e-06
# Epoch 534/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9977 - loss: 0.0510 - val_accuracy: 0.8182 - val_loss: 0.7230 - learning_rate: 5.0000e-06
# Epoch 535/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0422 - val_accuracy: 0.8239 - val_loss: 0.7230 - learning_rate: 5.0000e-06
# Epoch 536/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0445 - val_accuracy: 0.8239 - val_loss: 0.7231 - learning_rate: 5.0000e-06
# Epoch 537/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0407 - val_accuracy: 0.8239 - val_loss: 0.7232 - learning_rate: 5.0000e-06
# Epoch 538/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0468 - val_accuracy: 0.8239 - val_loss: 0.7233 - learning_rate: 5.0000e-06
# Epoch 539/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0529 - val_accuracy: 0.8239 - val_loss: 0.7235 - learning_rate: 5.0000e-06
# Epoch 540/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0519 - val_accuracy: 0.8239 - val_loss: 0.7237 - learning_rate: 5.0000e-06
# Epoch 541/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9954 - loss: 0.0576 - val_accuracy: 0.8239 - val_loss: 0.7239 - learning_rate: 5.0000e-06
# Epoch 542/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9908 - loss: 0.0584 - val_accuracy: 0.8239 - val_loss: 0.7240 - learning_rate: 5.0000e-06
# Epoch 543/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0467 - val_accuracy: 0.8239 - val_loss: 0.7240 - learning_rate: 5.0000e-06
# Epoch 544/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0420 - val_accuracy: 0.8239 - val_loss: 0.7240 - learning_rate: 5.0000e-06
# Epoch 545/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9977 - loss: 0.0519 - val_accuracy: 0.8239 - val_loss: 0.7239 - learning_rate: 5.0000e-06
# Epoch 546/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0469 - val_accuracy: 0.8239 - val_loss: 0.7239 - learning_rate: 5.0000e-06
# Epoch 547/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0500 - val_accuracy: 0.8239 - val_loss: 0.7241 - learning_rate: 5.0000e-06
# Epoch 548/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9954 - loss: 0.0502 - val_accuracy: 0.8239 - val_loss: 0.7241 - learning_rate: 5.0000e-06
# Epoch 549/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0587 - val_accuracy: 0.8239 - val_loss: 0.7240 - learning_rate: 5.0000e-06
# Epoch 550/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0402 - val_accuracy: 0.8239 - val_loss: 0.7242 - learning_rate: 5.0000e-06
# Epoch 551/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9977 - loss: 0.0488 - val_accuracy: 0.8239 - val_loss: 0.7242 - learning_rate: 5.0000e-06
# Epoch 552/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0532 - val_accuracy: 0.8239 - val_loss: 0.7243 - learning_rate: 5.0000e-06
# Epoch 553/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0458 - val_accuracy: 0.8239 - val_loss: 0.7244 - learning_rate: 5.0000e-06
# Epoch 554/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9954 - loss: 0.0473 - val_accuracy: 0.8239 - val_loss: 0.7243 - learning_rate: 5.0000e-06
# Epoch 555/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0454 - val_accuracy: 0.8239 - val_loss: 0.7243 - learning_rate: 5.0000e-06
# Epoch 556/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0403 - val_accuracy: 0.8239 - val_loss: 0.7242 - learning_rate: 5.0000e-06
# Epoch 557/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0548 - val_accuracy: 0.8239 - val_loss: 0.7242 - learning_rate: 5.0000e-06
# Epoch 558/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0495 - val_accuracy: 0.8239 - val_loss: 0.7241 - learning_rate: 5.0000e-06
# Epoch 559/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0400 - val_accuracy: 0.8239 - val_loss: 0.7242 - learning_rate: 5.0000e-06
# Epoch 560/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0439 - val_accuracy: 0.8239 - val_loss: 0.7243 - learning_rate: 5.0000e-06
# Epoch 561/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0467 - val_accuracy: 0.8239 - val_loss: 0.7243 - learning_rate: 5.0000e-06
# Epoch 562/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0457 - val_accuracy: 0.8239 - val_loss: 0.7245 - learning_rate: 5.0000e-06
# Epoch 563/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0465 - val_accuracy: 0.8239 - val_loss: 0.7247 - learning_rate: 5.0000e-06
# Epoch 564/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0402 - val_accuracy: 0.8239 - val_loss: 0.7250 - learning_rate: 5.0000e-06
# Epoch 565/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0364 - val_accuracy: 0.8239 - val_loss: 0.7252 - learning_rate: 5.0000e-06
# Epoch 566/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0599 - val_accuracy: 0.8239 - val_loss: 0.7254 - learning_rate: 5.0000e-06
# Epoch 567/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0569 - val_accuracy: 0.8239 - val_loss: 0.7257 - learning_rate: 5.0000e-06
# Epoch 568/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0447 - val_accuracy: 0.8239 - val_loss: 0.7259 - learning_rate: 5.0000e-06
# Epoch 569/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9931 - loss: 0.0520 - val_accuracy: 0.8239 - val_loss: 0.7257 - learning_rate: 5.0000e-06
# Epoch 570/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9977 - loss: 0.0509 - val_accuracy: 0.8239 - val_loss: 0.7259 - learning_rate: 5.0000e-06
# Epoch 571/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0408 - val_accuracy: 0.8239 - val_loss: 0.7258 - learning_rate: 5.0000e-06
# Epoch 572/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0496 - val_accuracy: 0.8239 - val_loss: 0.7259 - learning_rate: 5.0000e-06
# Epoch 573/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0440 - val_accuracy: 0.8239 - val_loss: 0.7261 - learning_rate: 5.0000e-06
# Epoch 574/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0495 - val_accuracy: 0.8239 - val_loss: 0.7259 - learning_rate: 5.0000e-06
# Epoch 575/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0476 - val_accuracy: 0.8239 - val_loss: 0.7258 - learning_rate: 5.0000e-06
# Epoch 576/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0414 - val_accuracy: 0.8239 - val_loss: 0.7257 - learning_rate: 5.0000e-06
# Epoch 577/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0492 - val_accuracy: 0.8239 - val_loss: 0.7255 - learning_rate: 5.0000e-06
# Epoch 578/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9954 - loss: 0.0487 - val_accuracy: 0.8239 - val_loss: 0.7254 - learning_rate: 5.0000e-06
# Epoch 579/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0543 - val_accuracy: 0.8239 - val_loss: 0.7251 - learning_rate: 5.0000e-06
# Epoch 580/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9977 - loss: 0.0436 - val_accuracy: 0.8239 - val_loss: 0.7249 - learning_rate: 5.0000e-06
# Epoch 581/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9977 - loss: 0.0483 - val_accuracy: 0.8239 - val_loss: 0.7247 - learning_rate: 5.0000e-06
# Epoch 582/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0478 - val_accuracy: 0.8239 - val_loss: 0.7245 - learning_rate: 5.0000e-06
# Epoch 583/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9908 - loss: 0.0536 - val_accuracy: 0.8239 - val_loss: 0.7244 - learning_rate: 5.0000e-06
# Epoch 584/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0441 - val_accuracy: 0.8239 - val_loss: 0.7241 - learning_rate: 5.0000e-06
# Epoch 585/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9954 - loss: 0.0452 - val_accuracy: 0.8239 - val_loss: 0.7242 - learning_rate: 5.0000e-06
# Epoch 586/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9977 - loss: 0.0508 - val_accuracy: 0.8239 - val_loss: 0.7240 - learning_rate: 5.0000e-06
# Epoch 587/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0483 - val_accuracy: 0.8239 - val_loss: 0.7238 - learning_rate: 5.0000e-06
# Epoch 588/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0379 - val_accuracy: 0.8239 - val_loss: 0.7235 - learning_rate: 5.0000e-06
# Epoch 589/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9977 - loss: 0.0328 - val_accuracy: 0.8239 - val_loss: 0.7232 - learning_rate: 5.0000e-06
# Epoch 590/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0452 - val_accuracy: 0.8239 - val_loss: 0.7231 - learning_rate: 5.0000e-06
# Epoch 591/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0415 - val_accuracy: 0.8239 - val_loss: 0.7232 - learning_rate: 5.0000e-06
# Epoch 592/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9977 - loss: 0.0473 - val_accuracy: 0.8239 - val_loss: 0.7231 - learning_rate: 5.0000e-06
# Epoch 593/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9954 - loss: 0.0575 - val_accuracy: 0.8239 - val_loss: 0.7229 - learning_rate: 5.0000e-06
# Epoch 594/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9977 - loss: 0.0512 - val_accuracy: 0.8239 - val_loss: 0.7229 - learning_rate: 5.0000e-06
# Epoch 595/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0395 - val_accuracy: 0.8239 - val_loss: 0.7228 - learning_rate: 5.0000e-06
# Epoch 596/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9954 - loss: 0.0396 - val_accuracy: 0.8239 - val_loss: 0.7228 - learning_rate: 5.0000e-06
# Epoch 597/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9977 - loss: 0.0439 - val_accuracy: 0.8182 - val_loss: 0.7228 - learning_rate: 5.0000e-06
# Epoch 598/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9954 - loss: 0.0398 - val_accuracy: 0.8182 - val_loss: 0.7229 - learning_rate: 5.0000e-06
# Epoch 599/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9931 - loss: 0.0489 - val_accuracy: 0.8182 - val_loss: 0.7230 - learning_rate: 5.0000e-06
# Epoch 600/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9977 - loss: 0.0465 - val_accuracy: 0.8182 - val_loss: 0.7233 - learning_rate: 5.0000e-06

# %%
# Plot training & validation accuracy values
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Test'], loc='upper left')
plt.show()
