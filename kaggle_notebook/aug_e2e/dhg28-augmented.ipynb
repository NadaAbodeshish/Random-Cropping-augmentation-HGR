# %%
# !git clone https://github.com/NadaAbodeshish/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion.git
# Out:
# Cloning into 'augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion'...
# remote: Enumerating objects: 479, done.
# remote: Counting objects: 100% (177/177), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 479 (delta 129), reused 112 (delta 65), pack-reused 302 (from 1)
# Receiving objects: 100% (479/479), 58.82 MiB | 38.41 MiB/s, done.
# Resolving deltas: 100% (308/308), done.

# %%
# !ls /kaggle/input/dhg28a/augmenttttdrrsds-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/images_d_28
# Out:
# 'DHG1428.mVOs-3d.28g-noisy(raw).960px-[allVOs].adaptive-mean'

# %%
# %cd augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion
# Out:
# /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion

# %%
# !cp -r /kaggle/input/dhg28a/augmenttttdrrsds-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/images_d_28/* /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/images_d/

# %%
# %cd experiments.server
# Out:
# /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/experiments.server

# %%
# !pip install pytorchcv
# !pip install matplotlib
# !pip install geffnet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.2/134.2 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.2/585.2 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# !python mVO.e2eEnsembleTuning.py -IG 0 -nC 28 -mVOs top-down custom front-away -dsN DHG1428 -IISE 0 -ISIS 0
# Out:
# Debug: Number of items in training split: 1960
# Debug: Number of items in validation split: 840
# Debug: Expected classes: 28, Detected classes: 28
# Debug: Detected class vocab: ['01-Grab', '02-Tap', '03-Expand', '04-Pinch', '05-RotationCW', '06-RotationCCW', '07-SwipeRight', '08-SwipeLeft', '09-SwipeUp', '10-SwipeDown', '11-SwipeX', '12-Swipe+', '13-SwipeV', '14-Shake', '15-Grab', '16-Tap', '17-Expand', '18-Pinch', '19-RotationCW', '20-RotationCCW', '21-SwipeRight', '22-SwipeLeft', '23-SwipeUp', '24-SwipeDown', '25-SwipeX', '26-Swipe+', '27-SwipeV', '28-Shake']
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...
