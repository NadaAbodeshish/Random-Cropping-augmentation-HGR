# %%
! pip install -q keras

# %%
import numpy as np
import math
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
from tqdm import tqdm
import pickle
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt
from scipy.spatial.distance import cdist

from keras.optimizers import *
from keras.models import Model
from keras.layers import *
from keras import backend as K
import keras
import tensorflow as tf

# %% [markdown]
# 1. Define configurations

# %%
random.seed(1234)

class Config():
    def __init__(self):
        self.frame_l = 32 # the length of frames
        self.joint_n = 15 # the number of joints
        self.joint_d = 2 # the dimension of joints
        self.clc_num = 21 # the number of class
        self.feat_d = 105
        self.filters = 64
C = Config()

# %% [markdown]
# 2. Define data processing functions

# %%
# Temple resizing function
def zoom(p,target_l=64,joints_num=25,joints_dim=3):
    l = p.shape[0]
    p_new = np.empty([target_l,joints_num,joints_dim])
    for m in range(joints_num):
        for n in range(joints_dim):
            p[:,m,n] = medfilt(p[:,m,n],3)
            p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
    return p_new



# Calculate JCD feature
def norm_scale(x):
    return (x-np.mean(x))/np.mean(x)

def get_CG(p,C):
    M = []
    iu = np.triu_indices(C.joint_n,1,C.joint_n)
    for f in range(C.frame_l):
        d_m = cdist(p[f],p[f],'euclidean')
        d_m = d_m[iu]
        M.append(d_m)
    M = np.stack(M)
    M = norm_scale(M)
    return M
    
import numpy as np

def mixup_data(X, Y, alpha=1.0):
    '''
    X: Input data
    Y: Corresponding labels .
    alpha: MixUp interpolation strength.

    Returns:
    - Mixed inputs
    - Mixed labels
    - Lambda value used for mixing
    '''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1.0

    batch_size = X.shape[0]
    index = np.random.permutation(batch_size)

    mixed_X = lam * X + (1 - lam) * X[index]
    mixed_Y = lam * Y + (1 - lam) * Y[index]

    return mixed_X, mixed_Y, lam


def data_generator_with_mixup(T, C, le, apply_mixup=False, alpha=1.0):
    X_0 = []
    X_1 = []
    Y = []
    for i in tqdm(range(len(T['pose']))):
        p = np.copy(T['pose'][i])
        p = zoom(p, target_l=C.frame_l, joints_num=C.joint_n, joints_dim=C.joint_d)

        label = np.zeros(C.clc_num)
        label[le.transform(T['label'])[i] - 1] = 1

        M = get_CG(p, C)

        X_0.append(M)
        X_1.append(p)
        Y.append(label)

    X_0 = np.stack(X_0)
    X_1 = np.stack(X_1)
    Y = np.stack(Y)

    if apply_mixup:
        X_1, Y, _ = mixup_data(X_1, Y, alpha)

    return X_0, X_1, Y



# Genrate dataset
def data_generator(T,C,le):
    X_0 = []
    X_1 = []
    Y = []
    for i in tqdm(range(len(T['pose']))):
        p = np.copy(T['pose'][i])
        p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)

        label = np.zeros(C.clc_num)
        label[le.transform(T['label'])[i]-1] = 1

        M = get_CG(p,C)

        X_0.append(M)
        X_1.append(p)
        Y.append(label)

    X_0 = np.stack(X_0)
    X_1 = np.stack(X_1)
    Y = np.stack(Y)
    return X_0,X_1,Y

# %% [markdown]
# 3. Define network

# %%
def poses_diff(x):
    H, W = x.get_shape()[1],x.get_shape()[2]
    x = tf.subtract(x[:,1:,...],x[:,:-1,...])
    x = tf.image.resize(x,size=[H,W])
    return x

def pose_motion(P,frame_l):
    P_diff_slow = Lambda(lambda x: poses_diff(x))(P)
    P_diff_slow = Reshape((frame_l,-1))(P_diff_slow)
    P_fast = Lambda(lambda x: x[:,::2,...])(P)
    P_diff_fast = Lambda(lambda x: poses_diff(x))(P_fast)
    P_diff_fast = Reshape((int(frame_l/2),-1))(P_diff_fast)
    return P_diff_slow,P_diff_fast

def c1D(x,filters,kernel):
    x = Conv1D(filters, kernel_size=kernel,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def block(x,filters):
    x = c1D(x,filters,3)
    x = c1D(x,filters,3)
    return x

def d1D(x,filters):
    x = Dense(filters,use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def build_FM(frame_l=32,joint_n=22,joint_d=2,feat_d=231,filters=16):
    M = Input(shape=(frame_l,feat_d))
    P = Input(shape=(frame_l,joint_n,joint_d))

    diff_slow,diff_fast = pose_motion(P,frame_l)

    x = c1D(M,filters*2,1)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,3)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,1)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x_d_slow = c1D(diff_slow,filters*2,1)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,3)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,1)
    x_d_slow = MaxPool1D(2)(x_d_slow)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)

    x_d_fast = c1D(diff_fast,filters*2,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,3)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)

    x = concatenate([x,x_d_slow,x_d_fast])
    x = block(x,filters*2)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*4)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*8)
    x = SpatialDropout1D(0.1)(x)

    return Model(inputs=[M,P],outputs=x)


def build_DD_Net(C):
    M = Input(name='M', shape=(C.frame_l,C.feat_d))
    P = Input(name='P', shape=(C.frame_l,C.joint_n,C.joint_d))

    FM = build_FM(C.frame_l,C.joint_n,C.joint_d,C.feat_d,C.filters)

    x = FM([M,P])

    x = GlobalMaxPool1D()(x)

    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = Dense(C.clc_num, activation='softmax')(x)

    ######################Self-supervised part
    model = Model(inputs=[M,P],outputs=x)
    return model

# %%
DD_Net = build_DD_Net(C)
DD_Net.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ M (InputLayer)            │ (None, 32, 105)        │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ P (InputLayer)            │ (None, 32, 15, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ functional (Functional)   │ (None, 4, 512)         │      1,714,816 │ M[0][0], P[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling1d      │ (None, 512)            │              0 │ functional[0][0]       │
# │ (GlobalMaxPooling1D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 128)            │         65,536 │ global_max_pooling1d[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 128)            │            512 │ dense[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_15            │ (None, 128)            │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 128)            │              0 │ leaky_re_lu_15[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 128)            │         16,384 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 128)            │            512 │ dense_1[0][0]          │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_16            │ (None, 128)            │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128)            │              0 │ leaky_re_lu_16[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 21)             │          2,709 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,800,469 (6.87 MB)
#  Trainable params: 1,794,837 (6.85 MB)
#  Non-trainable params: 5,632 (22.00 KB)

# %% [markdown]
# 4. Load dataset (download GT_train_1.pkl and  GT_test_1.pkl from github )

# %%
# !wget https://github.com/fandulu/DD-Net/archive/master.zip
# !unzip master.zip
# !rm master.zip
# Out:
# --2025-01-21 13:24:07--  https://github.com/fandulu/DD-Net/archive/master.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master [following]
# --2025-01-21 13:24:08--  https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [          <=>       ]  79.09M  14.4MB/s    in 5.5s
#
# 2025-01-21 13:24:13 (14.4 MB/s) - ‘master.zip’ saved [82934337]
#
# Archive:  master.zip
# f26a9994b0bafc41096fa269eab89c2757d71499
#    creating: DD-Net-master/
#   inflating: DD-Net-master/.gitignore
#    creating: DD-Net-master/JHMDB/
#   inflating: DD-Net-master/JHMDB/README.md
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_heavy.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_lite.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_middle.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_data_preprocessing.ipynb
#   inflating: DD-Net-master/JHMDB/utils.py
#    creating: DD-Net-master/JHMDB/weights/
#  extracting: DD-Net-master/JHMDB/weights/__init__.py
#   inflating: DD-Net-master/LICENSE
#   inflating: DD-Net-master/README.md
#    creating: DD-Net-master/SHREC/
#   inflating: DD-Net-master/SHREC/README.md
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_lite.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_data_preprocessing.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_lite.ipynb
#    creating: DD-Net-master/SHREC/images/
#   inflating: DD-Net-master/SHREC/images/SHREC_14.png
#   inflating: DD-Net-master/SHREC/images/SHREC_28.png
#   inflating: DD-Net-master/SHREC/utils.py
#    creating: DD-Net-master/SHREC/weights/
#  extracting: DD-Net-master/SHREC/weights/.gitkeep
#  extracting: DD-Net-master/SHREC/weights/__init__.py
#    creating: DD-Net-master/data/
#    creating: DD-Net-master/data/JHMDB/
#   inflating: DD-Net-master/data/JHMDB/GT_test_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_3.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_3.pkl
#   inflating: DD-Net-master/data/JHMDB/joint_positions.zip
#   inflating: DD-Net-master/data/JHMDB/splits.zip
#    creating: DD-Net-master/data/SHREC/
#  extracting: DD-Net-master/data/SHREC/__init__.py
#   inflating: DD-Net-master/data/SHREC/test.pickle
#   inflating: DD-Net-master/data/SHREC/test.pkl
#   inflating: DD-Net-master/data/SHREC/train.pickle
#   inflating: DD-Net-master/data/SHREC/train.pkl
#    creating: DD-Net-master/mics/
#  extracting: DD-Net-master/mics/__init__.py
#   inflating: DD-Net-master/mics/demo.png
#   inflating: DD-Net-master/mics/look.gif
#   inflating: DD-Net-master/mics/paper.png

# %% [markdown]
# # 新段落

# %%
Train = pickle.load(open("/kaggle/working/DD-Net-master/data/JHMDB/GT_train_1.pkl", "rb"))
Test = pickle.load(open("/kaggle/working/DD-Net-master/data/JHMDB/GT_test_1.pkl", "rb"))

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(Train['label'])

X_0, X_1, Y = data_generator_with_mixup(Train, C, le, apply_mixup=True, alpha=1.0)
X_test_0,X_test_1,Y_test = data_generator(Test,C,le)
# Out:
#   0%|          | 0/433 [00:00<?, ?it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#   4%|▎         | 16/433 [00:00<00:02, 157.11it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#   8%|▊         | 33/433 [00:00<00:02, 164.33it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  12%|█▏        | 50/433 [00:00<00:02, 166.49it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  15%|█▌        | 67/433 [00:00<00:02, 164.09it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  20%|█▉        | 85/433 [00:00<00:02, 165.81it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  24%|██▍       | 103/433 [00:00<00:01, 167.07it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  28%|██▊       | 121/433 [00:00<00:01, 169.53it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  32%|███▏      | 138/433 [00:00<00:01, 166.84it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  36%|███▌      | 155/433 [00:00<00:01, 164.27it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  40%|███▉      | 172/433 [00:01<00:01, 164.16it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# ...
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  75%|███████▌  | 132/176 [00:00<00:00, 160.45it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  85%|████████▍ | 149/176 [00:00<00:00, 161.12it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  94%|█████████▍| 166/176 [00:01<00:00, 162.65it/s]<ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-ade86d5a595c>:8: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 176/176 [00:01<00:00, 159.85it/s]

# %% [markdown]
# 5. Start train on split 1

# %%
lr = 1e-3
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
                    batch_size=len(Y),
                    epochs=600,
                    verbose=True,
                    shuffle=True,
                    callbacks=[lrScheduler],
                    validation_data=([X_test_0,X_test_1],Y_test)
                    )
lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
                    batch_size=len(Y),
                    epochs=600,
                    verbose=True,
                    shuffle=True,
                    callbacks=[lrScheduler],
                    validation_data=([X_test_0,X_test_1],Y_test)
                    )
# Out:
# Epoch 1/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 20s 20s/step - accuracy: 0.9353 - loss: 0.8254 - val_accuracy: 0.6989 - val_loss: 1.0056 - learning_rate: 0.0010
# Epoch 2/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8268 - loss: 0.9476 - val_accuracy: 0.6591 - val_loss: 1.1464 - learning_rate: 0.0010
# Epoch 3/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9145 - loss: 0.8992 - val_accuracy: 0.6136 - val_loss: 1.2094 - learning_rate: 0.0010
# Epoch 4/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9353 - loss: 0.8900 - val_accuracy: 0.5909 - val_loss: 1.2612 - learning_rate: 0.0010
# Epoch 5/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9261 - loss: 0.8916 - val_accuracy: 0.6307 - val_loss: 1.2010 - learning_rate: 0.0010
# Epoch 6/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8707 - loss: 0.9237 - val_accuracy: 0.6136 - val_loss: 1.1741 - learning_rate: 0.0010
# Epoch 7/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9030 - loss: 0.9217 - val_accuracy: 0.6364 - val_loss: 1.1724 - learning_rate: 5.0000e-04
# Epoch 8/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9099 - loss: 0.8965 - val_accuracy: 0.6534 - val_loss: 1.1728 - learning_rate: 5.0000e-04
# Epoch 9/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9192 - loss: 0.8898 - val_accuracy: 0.6477 - val_loss: 1.1757 - learning_rate: 5.0000e-04
# Epoch 10/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9376 - loss: 0.8932 - val_accuracy: 0.6591 - val_loss: 1.1716 - learning_rate: 5.0000e-04
# Epoch 11/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9261 - loss: 0.8601 - val_accuracy: 0.6591 - val_loss: 1.1583 - learning_rate: 5.0000e-04
# Epoch 12/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9099 - loss: 0.8812 - val_accuracy: 0.6648 - val_loss: 1.1372 - learning_rate: 5.0000e-04
# Epoch 13/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9169 - loss: 0.8657 - val_accuracy: 0.6477 - val_loss: 1.1302 - learning_rate: 5.0000e-04
# Epoch 14/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9122 - loss: 0.8752 - val_accuracy: 0.6420 - val_loss: 1.1273 - learning_rate: 5.0000e-04
# Epoch 15/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9284 - loss: 0.8427 - val_accuracy: 0.6364 - val_loss: 1.1254 - learning_rate: 5.0000e-04
# Epoch 16/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9053 - loss: 0.8602 - val_accuracy: 0.6477 - val_loss: 1.1151 - learning_rate: 2.5000e-04
# Epoch 17/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9145 - loss: 0.8436 - val_accuracy: 0.6534 - val_loss: 1.1093 - learning_rate: 2.5000e-04
# Epoch 18/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8984 - loss: 0.8511 - val_accuracy: 0.6648 - val_loss: 1.0980 - learning_rate: 2.5000e-04
# Epoch 19/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9376 - loss: 0.8265 - val_accuracy: 0.6648 - val_loss: 1.0876 - learning_rate: 2.5000e-04
# Epoch 20/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9238 - loss: 0.8406 - val_accuracy: 0.6705 - val_loss: 1.0780 - learning_rate: 2.5000e-04
# Epoch 21/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9446 - loss: 0.8269 - val_accuracy: 0.6648 - val_loss: 1.0643 - learning_rate: 2.5000e-04
# Epoch 22/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9169 - loss: 0.8491 - val_accuracy: 0.6705 - val_loss: 1.0504 - learning_rate: 2.5000e-04
# Epoch 23/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9307 - loss: 0.8435 - val_accuracy: 0.6705 - val_loss: 1.0400 - learning_rate: 2.5000e-04
# Epoch 24/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9446 - loss: 0.8030 - val_accuracy: 0.6818 - val_loss: 1.0335 - learning_rate: 2.5000e-04
# Epoch 25/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9353 - loss: 0.8052 - val_accuracy: 0.6818 - val_loss: 1.0330 - learning_rate: 2.5000e-04
# Epoch 26/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9261 - loss: 0.8288 - val_accuracy: 0.6932 - val_loss: 1.0312 - learning_rate: 2.5000e-04
# Epoch 27/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9215 - loss: 0.8136 - val_accuracy: 0.6875 - val_loss: 1.0340 - learning_rate: 2.5000e-04
# Epoch 28/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9284 - loss: 0.8203 - val_accuracy: 0.6875 - val_loss: 1.0434 - learning_rate: 2.5000e-04
# Epoch 29/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9330 - loss: 0.8140 - val_accuracy: 0.6932 - val_loss: 1.0554 - learning_rate: 2.5000e-04
# Epoch 30/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9145 - loss: 0.8000 - val_accuracy: 0.6932 - val_loss: 1.0600 - learning_rate: 1.2500e-04
# Epoch 31/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9446 - loss: 0.7873 - val_accuracy: 0.6932 - val_loss: 1.0642 - learning_rate: 1.2500e-04
# Epoch 32/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9215 - loss: 0.8229 - val_accuracy: 0.6875 - val_loss: 1.0659 - learning_rate: 1.2500e-04
# Epoch 33/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9215 - loss: 0.8065 - val_accuracy: 0.6875 - val_loss: 1.0689 - learning_rate: 1.2500e-04
# Epoch 34/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9423 - loss: 0.8111 - val_accuracy: 0.6818 - val_loss: 1.0731 - learning_rate: 1.2500e-04
# Epoch 35/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9145 - loss: 0.8260 - val_accuracy: 0.6818 - val_loss: 1.0750 - learning_rate: 1.2500e-04
# Epoch 36/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9215 - loss: 0.8062 - val_accuracy: 0.6875 - val_loss: 1.0740 - learning_rate: 1.2500e-04
# Epoch 37/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9169 - loss: 0.8107 - val_accuracy: 0.6818 - val_loss: 1.0708 - learning_rate: 1.2500e-04
# Epoch 38/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9446 - loss: 0.7944 - val_accuracy: 0.6818 - val_loss: 1.0686 - learning_rate: 1.2500e-04
# Epoch 39/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9353 - loss: 0.7776 - val_accuracy: 0.6818 - val_loss: 1.0664 - learning_rate: 6.2500e-05
# Epoch 40/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9400 - loss: 0.8056 - val_accuracy: 0.6761 - val_loss: 1.0643 - learning_rate: 6.2500e-05
# Epoch 41/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9284 - loss: 0.7796 - val_accuracy: 0.6761 - val_loss: 1.0630 - learning_rate: 6.2500e-05
# Epoch 42/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9122 - loss: 0.7934 - val_accuracy: 0.6761 - val_loss: 1.0609 - learning_rate: 6.2500e-05
# Epoch 43/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9330 - loss: 0.7924 - val_accuracy: 0.6761 - val_loss: 1.0597 - learning_rate: 6.2500e-05
# Epoch 44/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9215 - loss: 0.8023 - val_accuracy: 0.6761 - val_loss: 1.0574 - learning_rate: 6.2500e-05
# Epoch 45/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9284 - loss: 0.7944 - val_accuracy: 0.6761 - val_loss: 1.0565 - learning_rate: 6.2500e-05
# Epoch 46/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9145 - loss: 0.7911 - val_accuracy: 0.6818 - val_loss: 1.0543 - learning_rate: 6.2500e-05
# Epoch 47/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9330 - loss: 0.7761 - val_accuracy: 0.6818 - val_loss: 1.0525 - learning_rate: 6.2500e-05
# Epoch 48/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9330 - loss: 0.7985 - val_accuracy: 0.6818 - val_loss: 1.0520 - learning_rate: 6.2500e-05
# Epoch 49/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9099 - loss: 0.7957 - val_accuracy: 0.6818 - val_loss: 1.0521 - learning_rate: 6.2500e-05
# Epoch 50/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9307 - loss: 0.8038 - val_accuracy: 0.6932 - val_loss: 1.0528 - learning_rate: 6.2500e-05
# Epoch 51/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9446 - loss: 0.7804 - val_accuracy: 0.6932 - val_loss: 1.0538 - learning_rate: 6.2500e-05
# Epoch 52/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9053 - loss: 0.7973 - val_accuracy: 0.6932 - val_loss: 1.0552 - learning_rate: 6.2500e-05
# Epoch 53/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9446 - loss: 0.7837 - val_accuracy: 0.6932 - val_loss: 1.0556 - learning_rate: 3.1250e-05
# Epoch 54/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9400 - loss: 0.7621 - val_accuracy: 0.6932 - val_loss: 1.0556 - learning_rate: 3.1250e-05
# Epoch 55/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9423 - loss: 0.7823 - val_accuracy: 0.6932 - val_loss: 1.0553 - learning_rate: 3.1250e-05
# Epoch 56/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9330 - loss: 0.8024 - val_accuracy: 0.6932 - val_loss: 1.0548 - learning_rate: 3.1250e-05
# Epoch 57/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9284 - loss: 0.7721 - val_accuracy: 0.6875 - val_loss: 1.0547 - learning_rate: 3.1250e-05
# Epoch 58/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9215 - loss: 0.8120 - val_accuracy: 0.6932 - val_loss: 1.0539 - learning_rate: 3.1250e-05
# Epoch 59/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9561 - loss: 0.7676 - val_accuracy: 0.6932 - val_loss: 1.0535 - learning_rate: 3.1250e-05
# Epoch 60/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9469 - loss: 0.7806 - val_accuracy: 0.6932 - val_loss: 1.0532 - learning_rate: 3.1250e-05
# Epoch 61/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9307 - loss: 0.7852 - val_accuracy: 0.6932 - val_loss: 1.0531 - learning_rate: 3.1250e-05
# Epoch 62/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9607 - loss: 0.7653 - val_accuracy: 0.6875 - val_loss: 1.0528 - learning_rate: 1.5625e-05
# Epoch 63/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9076 - loss: 0.7932 - val_accuracy: 0.6875 - val_loss: 1.0523 - learning_rate: 1.5625e-05
# Epoch 64/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9423 - loss: 0.7707 - val_accuracy: 0.6875 - val_loss: 1.0518 - learning_rate: 1.5625e-05
# Epoch 65/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9307 - loss: 0.7882 - val_accuracy: 0.6875 - val_loss: 1.0509 - learning_rate: 1.5625e-05
# Epoch 66/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9238 - loss: 0.7896 - val_accuracy: 0.6875 - val_loss: 1.0498 - learning_rate: 1.5625e-05
# Epoch 67/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9423 - loss: 0.7975 - val_accuracy: 0.6875 - val_loss: 1.0487 - learning_rate: 1.5625e-05
# Epoch 68/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9330 - loss: 0.7875 - val_accuracy: 0.6875 - val_loss: 1.0475 - learning_rate: 1.5625e-05
# Epoch 69/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9353 - loss: 0.7764 - val_accuracy: 0.6932 - val_loss: 1.0463 - learning_rate: 1.5625e-05
# Epoch 70/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9284 - loss: 0.8001 - val_accuracy: 0.6932 - val_loss: 1.0452 - learning_rate: 1.5625e-05
# Epoch 71/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9053 - loss: 0.8067 - val_accuracy: 0.6932 - val_loss: 1.0447 - learning_rate: 7.8125e-06
# Epoch 72/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9353 - loss: 0.7761 - val_accuracy: 0.6932 - val_loss: 1.0441 - learning_rate: 7.8125e-06
# Epoch 73/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9446 - loss: 0.7651 - val_accuracy: 0.6932 - val_loss: 1.0435 - learning_rate: 7.8125e-06
# Epoch 74/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9284 - loss: 0.7996 - val_accuracy: 0.6932 - val_loss: 1.0430 - learning_rate: 7.8125e-06
# Epoch 75/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9353 - loss: 0.7896 - val_accuracy: 0.6932 - val_loss: 1.0424 - learning_rate: 7.8125e-06
# Epoch 76/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9400 - loss: 0.7931 - val_accuracy: 0.6932 - val_loss: 1.0417 - learning_rate: 7.8125e-06
# Epoch 77/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9076 - loss: 0.7950 - val_accuracy: 0.6932 - val_loss: 1.0411 - learning_rate: 7.8125e-06
# Epoch 78/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9400 - loss: 0.7765 - val_accuracy: 0.6932 - val_loss: 1.0404 - learning_rate: 7.8125e-06
# Epoch 79/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9376 - loss: 0.7778 - val_accuracy: 0.6932 - val_loss: 1.0398 - learning_rate: 7.8125e-06
# Epoch 80/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9469 - loss: 0.7712 - val_accuracy: 0.6932 - val_loss: 1.0392 - learning_rate: 5.0000e-06
# Epoch 81/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9353 - loss: 0.7896 - val_accuracy: 0.6932 - val_loss: 1.0387 - learning_rate: 5.0000e-06
# Epoch 82/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9307 - loss: 0.7777 - val_accuracy: 0.6932 - val_loss: 1.0383 - learning_rate: 5.0000e-06
# Epoch 83/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9423 - loss: 0.7765 - val_accuracy: 0.6989 - val_loss: 1.0378 - learning_rate: 5.0000e-06
# Epoch 84/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9192 - loss: 0.7983 - val_accuracy: 0.6989 - val_loss: 1.0374 - learning_rate: 5.0000e-06
# Epoch 85/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9284 - loss: 0.7901 - val_accuracy: 0.6989 - val_loss: 1.0369 - learning_rate: 5.0000e-06
# Epoch 86/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9238 - loss: 0.7858 - val_accuracy: 0.6989 - val_loss: 1.0364 - learning_rate: 5.0000e-06
# Epoch 87/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9469 - loss: 0.7772 - val_accuracy: 0.6989 - val_loss: 1.0359 - learning_rate: 5.0000e-06
# Epoch 88/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9376 - loss: 0.7765 - val_accuracy: 0.6989 - val_loss: 1.0354 - learning_rate: 5.0000e-06
# Epoch 89/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9492 - loss: 0.7761 - val_accuracy: 0.6989 - val_loss: 1.0350 - learning_rate: 5.0000e-06
# Epoch 90/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9307 - loss: 0.7901 - val_accuracy: 0.6989 - val_loss: 1.0345 - learning_rate: 5.0000e-06
# Epoch 91/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9238 - loss: 0.7839 - val_accuracy: 0.6989 - val_loss: 1.0343 - learning_rate: 5.0000e-06
# Epoch 92/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9469 - loss: 0.7673 - val_accuracy: 0.6989 - val_loss: 1.0338 - learning_rate: 5.0000e-06
# Epoch 93/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9492 - loss: 0.7775 - val_accuracy: 0.6989 - val_loss: 1.0336 - learning_rate: 5.0000e-06
# Epoch 94/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9307 - loss: 0.7853 - val_accuracy: 0.6989 - val_loss: 1.0332 - learning_rate: 5.0000e-06
# Epoch 95/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9400 - loss: 0.7792 - val_accuracy: 0.6989 - val_loss: 1.0329 - learning_rate: 5.0000e-06
# Epoch 96/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9307 - loss: 0.7750 - val_accuracy: 0.6989 - val_loss: 1.0326 - learning_rate: 5.0000e-06
# Epoch 97/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9284 - loss: 0.8080 - val_accuracy: 0.6989 - val_loss: 1.0323 - learning_rate: 5.0000e-06
# Epoch 98/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9330 - loss: 0.7834 - val_accuracy: 0.6989 - val_loss: 1.0320 - learning_rate: 5.0000e-06
# Epoch 99/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9192 - loss: 0.7878 - val_accuracy: 0.6989 - val_loss: 1.0317 - learning_rate: 5.0000e-06
# Epoch 100/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9330 - loss: 0.7800 - val_accuracy: 0.6989 - val_loss: 1.0317 - learning_rate: 5.0000e-06
# Epoch 101/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9446 - loss: 0.7762 - val_accuracy: 0.6989 - val_loss: 1.0316 - learning_rate: 5.0000e-06
# Epoch 102/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9169 - loss: 0.7796 - val_accuracy: 0.6989 - val_loss: 1.0314 - learning_rate: 5.0000e-06
# Epoch 103/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9122 - loss: 0.7807 - val_accuracy: 0.6989 - val_loss: 1.0312 - learning_rate: 5.0000e-06
# Epoch 104/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9376 - loss: 0.7934 - val_accuracy: 0.6989 - val_loss: 1.0310 - learning_rate: 5.0000e-06
# Epoch 105/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9307 - loss: 0.7893 - val_accuracy: 0.6989 - val_loss: 1.0308 - learning_rate: 5.0000e-06
# Epoch 106/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9423 - loss: 0.7948 - val_accuracy: 0.6989 - val_loss: 1.0306 - learning_rate: 5.0000e-06
# Epoch 107/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9307 - loss: 0.7824 - val_accuracy: 0.6989 - val_loss: 1.0304 - learning_rate: 5.0000e-06
# Epoch 108/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9400 - loss: 0.7742 - val_accuracy: 0.6989 - val_loss: 1.0301 - learning_rate: 5.0000e-06
# Epoch 109/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9330 - loss: 0.7947 - val_accuracy: 0.6989 - val_loss: 1.0298 - learning_rate: 5.0000e-06
# Epoch 110/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9353 - loss: 0.7882 - val_accuracy: 0.6989 - val_loss: 1.0294 - learning_rate: 5.0000e-06
# Epoch 111/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9353 - loss: 0.7984 - val_accuracy: 0.6989 - val_loss: 1.0289 - learning_rate: 5.0000e-06
# Epoch 112/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9284 - loss: 0.7804 - val_accuracy: 0.6989 - val_loss: 1.0287 - learning_rate: 5.0000e-06
# Epoch 113/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9423 - loss: 0.7962 - val_accuracy: 0.7045 - val_loss: 1.0284 - learning_rate: 5.0000e-06
# Epoch 114/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9446 - loss: 0.7573 - val_accuracy: 0.7045 - val_loss: 1.0281 - learning_rate: 5.0000e-06
# Epoch 115/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9330 - loss: 0.7799 - val_accuracy: 0.7045 - val_loss: 1.0277 - learning_rate: 5.0000e-06
# Epoch 116/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9053 - loss: 0.8046 - val_accuracy: 0.7045 - val_loss: 1.0274 - learning_rate: 5.0000e-06
# Epoch 117/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9330 - loss: 0.7981 - val_accuracy: 0.7045 - val_loss: 1.0270 - learning_rate: 5.0000e-06
# Epoch 118/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9192 - loss: 0.7794 - val_accuracy: 0.7045 - val_loss: 1.0267 - learning_rate: 5.0000e-06
# Epoch 119/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9192 - loss: 0.7779 - val_accuracy: 0.7045 - val_loss: 1.0262 - learning_rate: 5.0000e-06
# Epoch 120/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9469 - loss: 0.7790 - val_accuracy: 0.7045 - val_loss: 1.0259 - learning_rate: 5.0000e-06
# Epoch 121/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9307 - loss: 0.7881 - val_accuracy: 0.7045 - val_loss: 1.0256 - learning_rate: 5.0000e-06
# Epoch 122/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.
600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9423 - loss: 0.7638 - val_accuracy: 0.7045 - val_loss: 1.0138 - learning_rate: 5.0000e-06
# Epoch 195/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9307 - loss: 0.7864 - val_accuracy: 0.7045 - val_loss: 1.0137 - learning_rate: 5.0000e-06
# Epoch 196/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9261 - loss: 0.7949 - val_accuracy: 0.7045 - val_loss: 1.0137 - learning_rate: 5.0000e-06
# Epoch 197/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9353 - loss: 0.7690 - val_accuracy: 0.7045 - val_loss: 1.0136 - learning_rate: 5.0000e-06
# Epoch 198/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9423 - loss: 0.7869 - val_accuracy: 0.7045 - val_loss: 1.0134 - learning_rate: 5.0000e-06
# Epoch 199/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9492 - loss: 0.7714 - val_accuracy: 0.7045 - val_loss: 1.0131 - learning_rate: 5.0000e-06
# Epoch 200/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9400 - loss: 0.7582 - val_accuracy: 0.7045 - val_loss: 1.0130 - learning_rate: 5.0000e-06
# Epoch 201/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9400 - loss: 0.7538 - val_accuracy: 0.6989 - val_loss: 1.0129 - learning_rate: 5.0000e-06
# Epoch 202/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9446 - loss: 0.7758 - val_accuracy: 0.6989 - val_loss: 1.0129 - learning_rate: 5.0000e-06
# Epoch 203/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9515 - loss: 0.7701 - val_accuracy: 0.6989 - val_loss: 1.0129 - learning_rate: 5.0000e-06
# Epoch 204/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9654 - loss: 0.7529 - val_accuracy: 0.7045 - val_loss: 1.0129 - learning_rate: 5.0000e-06
# Epoch 205/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9353 - loss: 0.7755 - val_accuracy: 0.7045 - val_loss: 1.0129 - learning_rate: 5.0000e-06
# Epoch 206/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9284 - loss: 0.7849 - val_accuracy: 0.7045 - val_loss: 1.0129 - learning_rate: 5.0000e-06
# Epoch 207/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9446 - loss: 0.7611 - val_accuracy: 0.6989 - val_loss: 1.0128 - learning_rate: 5.0000e-06
# Epoch 208/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9192 - loss: 0.7967 - val_accuracy: 0.6989 - val_loss: 1.0128 - learning_rate: 5.0000e-06
# Epoch 209/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9469 - loss: 0.7770 - val_accuracy: 0.6989 - val_loss: 1.0128 - learning_rate: 5.0000e-06
# Epoch 210/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9169 - loss: 0.7777 - val_accuracy: 0.6989 - val_loss: 1.0128 - learning_rate: 5.0000e-06
# Epoch 211/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9469 - loss: 0.7557 - val_accuracy: 0.6989 - val_loss: 1.0130 - learning_rate: 5.0000e-06
# Epoch 212/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9330 - loss: 0.7634 - val_accuracy: 0.6989 - val_loss: 1.0130 - learning_rate: 5.0000e-06
# Epoch 213/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9446 - loss: 0.7647 - val_accuracy: 0.6989 - val_loss: 1.0129 - learning_rate: 5.0000e-06
# Epoch 214/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9330 - loss: 0.7613 - val_accuracy: 0.6989 - val_loss: 1.0127 - learning_rate: 5.0000e-06
# Epoch 215/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9400 - loss: 0.7699 - val_accuracy: 0.6989 - val_loss: 1.0126 - learning_rate: 5.0000e-06
# Epoch 216/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9353 - loss: 0.7637 - val_accuracy: 0.6989 - val_loss: 1.0125 - learning_rate: 5.0000e-06
# Epoch 217/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9469 - loss: 0.7476 - val_accuracy: 0.6989 - val_loss: 1.0125 - learning_rate: 5.0000e-06
# Epoch 218/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9400 - loss: 0.7720 - val_accuracy: 0.6989 - val_loss: 1.0125 - learning_rate: 5.0000e-06
# Epoch 219/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9515 - loss: 0.7602 - val_accuracy: 0.6989 - val_loss: 1.0124 - learning_rate: 5.0000e-06
# Epoch 220/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9284 - loss: 0.7799 - val_accuracy: 0.6989 - val_loss: 1.0122 - learning_rate: 5.0000e-06
# Epoch 221/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9261 - loss: 0.7699 - val_accuracy: 0.6989 - val_loss: 1.0121 - learning_rate: 5.0000e-06
# Epoch 222/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9215 - loss: 0.7851 - val_accuracy: 0.6989 - val_loss: 1.0120 - learning_rate: 5.0000e-06
# Epoch 223/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9446 - loss: 0.7699 - val_accuracy: 0.6989 - val_loss: 1.0120 - learning_rate: 5.0000e-06
# Epoch 224/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9145 - loss: 0.7945 - val_accuracy: 0.6989 - val_loss: 1.0120 - learning_rate: 5.0000e-06
# Epoch 225/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9284 - loss: 0.7772 - val_accuracy: 0.6989 - val_loss: 1.0121 - learning_rate: 5.0000e-06
# Epoch 226/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9261 - loss: 0.7787 - val_accuracy: 0.6989 - val_loss: 1.0120 - learning_rate: 5.0000e-06
# Epoch 227/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9469 - loss: 0.7514 - val_accuracy: 0.6989 - val_loss: 1.0118 - learning_rate: 5.0000e-06
# Epoch 228/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9469 - loss: 0.7736 - val_accuracy: 0.6989 - val_loss: 1.0117 - learning_rate: 5.0000e-06
# Epoch 229/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9515 - loss: 0.7629 - val_accuracy: 0.6989 - val_loss: 1.0115 - learning_rate: 5.0000e-06
# Epoch 230/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9192 - loss: 0.7883 - val_accuracy: 0.6989 - val_loss: 1.0113 - learning_rate: 5.0000e-06
# Epoch 231/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9400 - loss: 0.7855 - val_accuracy: 0.6989 - val_loss: 1.0114 - learning_rate: 5.0000e-06
# Epoch 232/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9215 - loss: 0.7721 - val_accuracy: 0.6989 - val_loss: 1.0112 - learning_rate: 5.0000e-06
# Epoch 233/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9261 - loss: 0.7799 - val_accuracy: 0.6989 - val_loss: 1.0112 - learning_rate: 5.0000e-06
# Epoch 234/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9492 - loss: 0.7718 - val_accuracy: 0.6989 - val_loss: 1.0110 - learning_rate: 5.0000e-06
# Epoch 235/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9307 - loss: 0.7650 - val_accuracy: 0.6989 - val_loss: 1.0109 - learning_rate: 5.0000e-06
# Epoch 236/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9284 - loss: 0.7807 - val_accuracy: 0.6989 - val_loss: 1.0107 - learning_rate: 5.0000e-06
# Epoch 237/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9099 - loss: 0.7795 - val_accuracy: 0.6989 - val_loss: 1.0105 - learning_rate: 5.0000e-06
# Epoch 238/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9400 - loss: 0.7665 - val_accuracy: 0.6989 - val_loss: 1.0103 - learning_rate: 5.0000e-06
# Epoch 239/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9515 - loss: 0.7840 - val_accuracy: 0.6989 - val_loss: 1.0101 - learning_rate: 5.0000e-06
# Epoch 240/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9330 - loss: 0.7779 - val_accuracy: 0.6989 - val_loss: 1.0098 - learning_rate: 5.0000e-06
# Epoch 241/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9515 - loss: 0.7631 - val_accuracy: 0.6989 - val_loss: 1.0097 - learning_rate: 5.0000e-06
# Epoch 242/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.
600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9215 - loss: 0.7915 - val_accuracy: 0.7045 - val_loss: 1.0066 - learning_rate: 5.0000e-06
# Epoch 268/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9122 - loss: 0.7907 - val_accuracy: 0.7045 - val_loss: 1.0067 - learning_rate: 5.0000e-06
# Epoch 269/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9284 - loss: 0.7933 - val_accuracy: 0.7045 - val_loss: 1.0065 - learning_rate: 5.0000e-06
# Epoch 270/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9307 - loss: 0.7913 - val_accuracy: 0.7045 - val_loss: 1.0065 - learning_rate: 5.0000e-06
# Epoch 271/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9446 - loss: 0.7721 - val_accuracy: 0.7045 - val_loss: 1.0064 - learning_rate: 5.0000e-06
# Epoch 272/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9469 - loss: 0.7749 - val_accuracy: 0.7102 - val_loss: 1.0064 - learning_rate: 5.0000e-06
# Epoch 273/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9353 - loss: 0.7780 - val_accuracy: 0.7102 - val_loss: 1.0064 - learning_rate: 5.0000e-06
# Epoch 274/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9330 - loss: 0.7975 - val_accuracy: 0.7102 - val_loss: 1.0064 - learning_rate: 5.0000e-06
# Epoch 275/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9330 - loss: 0.7890 - val_accuracy: 0.7102 - val_loss: 1.0065 - learning_rate: 5.0000e-06
# Epoch 276/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9169 - loss: 0.7680 - val_accuracy: 0.7102 - val_loss: 1.0065 - learning_rate: 5.0000e-06
# Epoch 277/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9492 - loss: 0.7677 - val_accuracy: 0.7102 - val_loss: 1.0066 - learning_rate: 5.0000e-06
# Epoch 278/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9423 - loss: 0.7680 - val_accuracy: 0.7102 - val_loss: 1.0067 - learning_rate: 5.0000e-06
# Epoch 279/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9307 - loss: 0.7802 - val_accuracy: 0.7102 - val_loss: 1.0068 - learning_rate: 5.0000e-06
# Epoch 280/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9192 - loss: 0.7731 - val_accuracy: 0.7045 - val_loss: 1.0069 - learning_rate: 5.0000e-06
# Epoch 281/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9630 - loss: 0.7676 - val_accuracy: 0.7045 - val_loss: 1.0070 - learning_rate: 5.0000e-06
# Epoch 282/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9261 - loss: 0.7759 - val_accuracy: 0.7045 - val_loss: 1.0072 - learning_rate: 5.0000e-06
# Epoch 283/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9238 - loss: 0.7940 - val_accuracy: 0.7045 - val_loss: 1.0074 - learning_rate: 5.0000e-06
# Epoch 284/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9238 - loss: 0.7752 - val_accuracy: 0.7045 - val_loss: 1.0077 - learning_rate: 5.0000e-06
# Epoch 285/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9492 - loss: 0.7643 - val_accuracy: 0.7045 - val_loss: 1.0079 - learning_rate: 5.0000e-06
# Epoch 286/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9122 - loss: 0.7842 - val_accuracy: 0.7045 - val_loss: 1.0081 - learning_rate: 5.0000e-06
# Epoch 287/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9353 - loss: 0.7668 - val_accuracy: 0.7045 - val_loss: 1.0082 - learning_rate: 5.0000e-06
# Epoch 288/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9215 - loss: 0.7852 - val_accuracy: 0.7045 - val_loss: 1.0084 - learning_rate: 5.0000e-06
# Epoch 289/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9053 - loss: 0.7725 - val_accuracy: 0.7045 - val_loss: 1.0087 - learning_rate: 5.0000e-06
# Epoch 290/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9330 - loss: 0.7749 - val_accuracy: 0.7045 - val_loss: 1.0090 - learning_rate: 5.0000e-06
# Epoch 291/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.
600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9099 - loss: 0.7503 - val_accuracy: 0.7102 - val_loss: 0.9981 - learning_rate: 5.0000e-06
# Epoch 530/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9261 - loss: 0.7413 - val_accuracy: 0.7102 - val_loss: 0.9981 - learning_rate: 5.0000e-06
# Epoch 531/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9284 - loss: 0.7437 - val_accuracy: 0.7102 - val_loss: 0.9982 - learning_rate: 5.0000e-06
# Epoch 532/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9330 - loss: 0.7586 - val_accuracy: 0.7102 - val_loss: 0.9983 - learning_rate: 5.0000e-06
# Epoch 533/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9330 - loss: 0.7480 - val_accuracy: 0.7102 - val_loss: 0.9983 - learning_rate: 5.0000e-06
# Epoch 534/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8938 - loss: 0.7576 - val_accuracy: 0.7102 - val_loss: 0.9983 - learning_rate: 5.0000e-06
# Epoch 535/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9169 - loss: 0.7688 - val_accuracy: 0.7102 - val_loss: 0.9979 - learning_rate: 5.0000e-06
# Epoch 536/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9330 - loss: 0.7498 - val_accuracy: 0.7102 - val_loss: 0.9978 - learning_rate: 5.0000e-06
# Epoch 537/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9261 - loss: 0.7432 - val_accuracy: 0.7102 - val_loss: 0.9976 - learning_rate: 5.0000e-06
# Epoch 538/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9330 - loss: 0.7470 - val_accuracy: 0.7102 - val_loss: 0.9974 - learning_rate: 5.0000e-06
# Epoch 539/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9284 - loss: 0.7413 - val_accuracy: 0.7102 - val_loss: 0.9971 - learning_rate: 5.0000e-06
# Epoch 540/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9330 - loss: 0.7459 - val_accuracy: 0.7102 - val_loss: 0.9968 - learning_rate: 5.0000e-06
# Epoch 541/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9215 - loss: 0.7520 - val_accuracy: 0.7102 - val_loss: 0.9966 - learning_rate: 5.0000e-06
# Epoch 542/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9284 - loss: 0.7495 - val_accuracy: 0.7102 - val_loss: 0.9964 - learning_rate: 5.0000e-06
# Epoch 543/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9169 - loss: 0.7388 - val_accuracy: 0.7102 - val_loss: 0.9962 - learning_rate: 5.0000e-06
# Epoch 544/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9376 - loss: 0.7292 - val_accuracy: 0.7102 - val_loss: 0.9959 - learning_rate: 5.0000e-06
# Epoch 545/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9469 - loss: 0.7375 - val_accuracy: 0.7102 - val_loss: 0.9957 - learning_rate: 5.0000e-06
# Epoch 546/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9330 - loss: 0.7526 - val_accuracy: 0.7102 - val_loss: 0.9954 - learning_rate: 5.0000e-06
# Epoch 547/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9307 - loss: 0.7530 - val_accuracy: 0.7102 - val_loss: 0.9950 - learning_rate: 5.0000e-06
# Epoch 548/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9515 - loss: 0.7475 - val_accuracy: 0.7102 - val_loss: 0.9947 - learning_rate: 5.0000e-06
# Epoch 549/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9307 - loss: 0.7490 - val_accuracy: 0.7045 - val_loss: 0.9944 - learning_rate: 5.0000e-06
# Epoch 550/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9353 - loss: 0.7515 - val_accuracy: 0.7045 - val_loss: 0.9940 - learning_rate: 5.0000e-06
# Epoch 551/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9353 - loss: 0.7630 - val_accuracy: 0.7045 - val_loss: 0.9936 - learning_rate: 5.0000e-06
# Epoch 552/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9261 - loss: 0.7511 - val_accuracy: 0.7045 - val_loss: 0.9932 - learning_rate: 5.0000e-06
# Epoch 553/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.
600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9353 - loss: 0.7358 - val_accuracy: 0.7102 - val_loss: 0.9909 - learning_rate: 5.0000e-06
# Epoch 578/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9376 - loss: 0.7427 - val_accuracy: 0.7102 - val_loss: 0.9907 - learning_rate: 5.0000e-06
# Epoch 579/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9446 - loss: 0.7517 - val_accuracy: 0.7102 - val_loss: 0.9907 - learning_rate: 5.0000e-06
# Epoch 580/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9469 - loss: 0.7283 - val_accuracy: 0.7102 - val_loss: 0.9906 - learning_rate: 5.0000e-06
# Epoch 581/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9192 - loss: 0.7530 - val_accuracy: 0.7102 - val_loss: 0.9907 - learning_rate: 5.0000e-06
# Epoch 582/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9284 - loss: 0.7448 - val_accuracy: 0.7102 - val_loss: 0.9906 - learning_rate: 5.0000e-06
# Epoch 583/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9330 - loss: 0.7471 - val_accuracy: 0.7102 - val_loss: 0.9905 - learning_rate: 5.0000e-06
# Epoch 584/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9353 - loss: 0.7657 - val_accuracy: 0.7102 - val_loss: 0.9906 - learning_rate: 5.0000e-06
# Epoch 585/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9284 - loss: 0.7426 - val_accuracy: 0.7102 - val_loss: 0.9907 - learning_rate: 5.0000e-06
# Epoch 586/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9215 - loss: 0.7378 - val_accuracy: 0.7102 - val_loss: 0.9907 - learning_rate: 5.0000e-06
# Epoch 587/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9215 - loss: 0.7466 - val_accuracy: 0.7102 - val_loss: 0.9909 - learning_rate: 5.0000e-06
# Epoch 588/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9330 - loss: 0.7469 - val_accuracy: 0.7102 - val_loss: 0.9910 - learning_rate: 5.0000e-06
# Epoch 589/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9307 - loss: 0.7490 - val_accuracy: 0.7102 - val_loss: 0.9911 - learning_rate: 5.0000e-06
# Epoch 590/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9515 - loss: 0.7144 - val_accuracy: 0.7102 - val_loss: 0.9911 - learning_rate: 5.0000e-06
# Epoch 591/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9400 - loss: 0.7189 - val_accuracy: 0.7102 - val_loss: 0.9912 - learning_rate: 5.0000e-06
# Epoch 592/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9353 - loss: 0.7601 - val_accuracy: 0.7102 - val_loss: 0.9914 - learning_rate: 5.0000e-06
# Epoch 593/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9192 - loss: 0.7503 - val_accuracy: 0.7102 - val_loss: 0.9914 - learning_rate: 5.0000e-06
# Epoch 594/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9400 - loss: 0.7295 - val_accuracy: 0.7102 - val_loss: 0.9916 - learning_rate: 5.0000e-06
# Epoch 595/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9446 - loss: 0.7270 - val_accuracy: 0.7102 - val_loss: 0.9918 - learning_rate: 5.0000e-06
# Epoch 596/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9307 - loss: 0.7338 - val_accuracy: 0.7102 - val_loss: 0.9921 - learning_rate: 5.0000e-06
# Epoch 597/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9353 - loss: 0.7437 - val_accuracy: 0.7102 - val_loss: 0.9921 - learning_rate: 5.0000e-06
# Epoch 598/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9400 - loss: 0.7393 - val_accuracy: 0.7102 - val_loss: 0.9921 - learning_rate: 5.0000e-06
# Epoch 599/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9238 - loss: 0.7483 - val_accuracy: 0.7102 - val_loss: 0.9922 - learning_rate: 5.0000e-06
# Epoch 600/600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9284 - loss: 0.7524 - val_accuracy: 0.7102 - val_loss: 0.9923 - learning_rate: 5.0000e-06

# %%
# Plot training & validation accuracy values
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Test'], loc='upper left')
plt.show()
