# %%
# !git clone https://github.com/NadaAbodeshish/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion.git
# Out:
# Cloning into 'augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion'...
# remote: Enumerating objects: 470, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 470 (delta 125), reused 106 (delta 63), pack-reused 302 (from 1)
# Receiving objects: 100% (470/470), 58.81 MiB | 37.66 MiB/s, done.
# Resolving deltas: 100% (304/304), done.

# %%
# !ls /kaggle/input/shrecx4-rot/augmenttttdrrsds-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/images_d_augmented_2
# Out:
# 'SHREC2017.mVOs-3d.14g-noisy(raw).960px-[allVOs].adaptive-mean'

# %%
# %cd augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion
# Out:
# /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion

# %%
# !cp -r /kaggle/input/shrecx4-rot/augmenttttdrrsds-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/images_d_augmented_2/* /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/images_d/

# %%
# %cd experiments.server
# Out:
# /kaggle/working/augmented-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/experiments.server

# %%
# !pip install pytorchcv
# !pip install matplotlib
# !pip install geffnet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.2/134.2 kB 3.5 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.2/585.2 kB 16.2 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 1.7 MB/s eta 0:00:00
# ...

# %%
# !python mVO.e2eEnsembleTuning.py -IG 0 -nC 14 -mVOs top-down custom front-away -dsN SHREC2017 -IISE 0 -ISIS 0
# Out:
# Debug: Number of items in training split: 1960
# Debug: Number of items in validation split: 840
# Debug: Expected classes: 14, Detected classes: 14
# Debug: Detected class vocab: ['01-Grab', '02-Tap', '03-Expand', '04-Pinch', '05-RotationCW', '06-RotationCCW', '07-SwipeRight', '08-SwipeLeft', '09-SwipeUp', '10-SwipeDown', '11-SwipeX', '12-Swipe+', '13-SwipeV', '14-Shake']
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
# ...
