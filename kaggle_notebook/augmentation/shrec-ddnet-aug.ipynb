# %%
! pip install -q keras

# %%
import numpy as np
import math
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
from tqdm import tqdm
import pickle
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt 
from scipy.spatial.distance import cdist

from keras.optimizers import *
from keras.models import Model
from keras.layers import *
# from keras.layers.core import *
# from tensorflow.keras.callbacks import *
# from keras.layers.convolutional import *
from keras import backend as K
import keras
import tensorflow as tf

# %%
random.seed(1234)

# Configuration class
class Config:
    def __init__(self):
        self.frame_l = 64  # Updated frame length
        self.joint_n = 22  # Number of joints
        self.joint_d = 3   # Dimension of joints
        self.clc_coarse = 14  # Number of coarse classes
        self.clc_fine = 28    # Number of fine-grained classes
        self.feat_d = 231
        self.filters = 64

# Create an instance of Config
C = Config()

# %%
from PIL import ImageEnhance

# Update configurations and preprocessing

def updated_sampling_frame(p, C, crop_size_ratio=0.95, zoom_range=(0.9, 1.1), rotation_range=(-15, 15),
                           brightness_range=(0.8, 1.2), contrast_range=(0.8, 1.2)):
    """
    Updated sampling frame function with additional preprocessing steps: random crop, zoom, rotation,
    and brightness/contrast adjustments.

    Args:
        p: Input pose data (numpy array).
        C: Configuration class instance.
        crop_size_ratio: Proportion of the original image to crop.
        zoom_range: Tuple for random zoom range.
        rotation_range: Tuple for random rotation angle range.
        brightness_range: Tuple for random brightness adjustment range.
        contrast_range: Tuple for random contrast adjustment range.
    """
    width, height = C.joint_n, C.frame_l  # Assuming width and height as joints and frames (pose dimensions)
    crop_width, crop_height = int(width * crop_size_ratio), int(height * crop_size_ratio)
    left = random.randint(0, width - crop_width)
    top = random.randint(0, height - crop_height)

    # Crop the pose data (simulate random cropping in an image-like manner)
    cropped_pose = p[top:top + crop_height, left:left + crop_width, :]

    # Zooming by resizing with a random scale factor
    zoom_factor = random.uniform(*zoom_range)
    zoom_width, zoom_height = int(crop_width * zoom_factor), int(crop_height * zoom_factor)
    zoomed_pose = cv2.resize(cropped_pose, (zoom_width, zoom_height), interpolation=cv2.INTER_LINEAR)

    # Rescale back to original dimensions
    resized_pose = cv2.resize(zoomed_pose, (width, height), interpolation=cv2.INTER_LINEAR)

    # Simulate random rotation (pose augmentation)
    rotation_angle = random.uniform(*rotation_range)
    rotation_matrix = cv2.getRotationMatrix2D((width // 2, height // 2), rotation_angle, 1)
    rotated_pose = cv2.warpAffine(resized_pose, rotation_matrix, (width, height))

    # Simulate brightness and contrast adjustments on pose data
    brightness_factor = random.uniform(*brightness_range)
    contrast_factor = random.uniform(*contrast_range)
    adjusted_pose = np.clip(rotated_pose * contrast_factor + brightness_factor, 0, 255)

    return adjusted_pose


# Integrate updated preprocessing in the training dataset loading
def preprocess_dataset(data, C, crop_size_ratio, zoom_range, rotation_range, brightness_range, contrast_range):
    processed_X_0, processed_X_1, processed_Y = [], [], []
    for i in tqdm(range(len(data['pose']))):
        p = np.copy(data['pose'][i]).reshape([-1, C.joint_n, C.joint_d])
        p = updated_sampling_frame(
            p, C, crop_size_ratio, zoom_range, rotation_range, brightness_range, contrast_range
        )
        p = normlize_range(p)  # Normalize the processed data

        label = np.zeros(C.clc_coarse)
        label[data['coarse_label'][i] - 1] = 1

        M = get_CG(p, C)  # Compute the contact graph

        processed_X_0.append(M)
        processed_X_1.append(p)
        processed_Y.append(label)

    return np.stack(processed_X_0), np.stack(processed_X_1), np.stack(processed_Y)

# %%
# Temple resizing function
import numpy as np
import os
import pandas as pd
import random
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt 

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

###################################################################################
    
    
#Rescale to be 64 frames
def zoom(p,target_l=64,joints_num=25,joints_dim=3):
    l = p.shape[0]
    p_new = np.empty([target_l,joints_num,joints_dim]) 
    for m in range(joints_num):
        for n in range(joints_dim):
            p[:,m,n] = medfilt(p[:,m,n],3)
            p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]         
    return p_new

def sampling_frame(p,C):
    full_l = p.shape[0] # full length
    if random.uniform(0,1)<0.5: # aligment sampling
        valid_l = np.round(np.random.uniform(0.9,1)*full_l)
        s = random.randint(0, full_l-int(valid_l))
        e = s+valid_l # sample end point
        p = p[int(s):int(e),:,:]    
    else: # without aligment sampling
        valid_l = np.round(np.random.uniform(0.9,1)*full_l)
        index = np.sort(np.random.choice(range(0,full_l),int(valid_l),replace=False))
        p = p[index,:,:]
    p = zoom(p,C.frame_l,C.joint_n,C.joint_d)
    return p

from scipy.spatial.distance import cdist
def get_CG(p,C):
    M = []
    iu = np.triu_indices(C.joint_n,1,C.joint_n)
    for f in range(C.frame_l):
        #distance max 
        d_m = cdist(p[f],np.concatenate([p[f],np.zeros([1,C.joint_d])]),'euclidean')       
        d_m = d_m[iu] 
        M.append(d_m)
    M = np.stack(M)   
    return M

def normlize_range(p):
    # normolize to start point, use the center for hand case
    p[:,:,0] = p[:,:,0]-np.mean(p[:,:,0])
    p[:,:,1] = p[:,:,1]-np.mean(p[:,:,1])
    p[:,:,2] = p[:,:,2]-np.mean(p[:,:,2])
    return p

def cm_analysis(y_true, y_pred, filename, labels, ymap=None, figsize=(8,8)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                #annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
                annot[i, j] = '%.1f' % (p)
            elif c == 0:
                annot[i, j] = ''
            else:
                #annot[i, j] = '%.1f%%\n%d' % (p, c)
                annot[i, j] = '%.1f' % (p)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax, cbar=False, cmap="YlGnBu")
    plt.savefig(filename)

# %%
def poses_diff(x):
    H, W = x.get_shape()[1],x.get_shape()[2]
    x = tf.subtract(x[:,1:,...],x[:,:-1,...])
    x = tf.image.resize(x,size=[H,W]) 
    return x

def pose_motion(P,frame_l):
    P_diff_slow = Lambda(lambda x: poses_diff(x))(P)
    P_diff_slow = Reshape((frame_l,-1))(P_diff_slow)
    P_fast = Lambda(lambda x: x[:,::2,...])(P)
    P_diff_fast = Lambda(lambda x: poses_diff(x))(P_fast)
    P_diff_fast = Reshape((int(frame_l/2),-1))(P_diff_fast)
    return P_diff_slow,P_diff_fast
    
def c1D(x,filters,kernel):
    x = Conv1D(filters, kernel_size=kernel,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def block(x,filters):
    x = c1D(x,filters,3)
    x = c1D(x,filters,3)
    return x
    
def d1D(x,filters):
    x = Dense(filters,use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def build_FM(frame_l=32,joint_n=22,joint_d=2,feat_d=231,filters=16):   
    M = Input(shape=(frame_l,feat_d))
    P = Input(shape=(frame_l,joint_n,joint_d))
    
    diff_slow,diff_fast = pose_motion(P,frame_l)
    
    x = c1D(M,filters*2,1)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,3)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,1)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x_d_slow = c1D(diff_slow,filters*2,1)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,3)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,1)
    x_d_slow = MaxPool1D(2)(x_d_slow)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
        
    x_d_fast = c1D(diff_fast,filters*2,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,3) 
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,1) 
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
   
    x = concatenate([x,x_d_slow,x_d_fast])
    x = block(x,filters*2)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)
    
    x = block(x,filters*4)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*8)
    x = SpatialDropout1D(0.1)(x)
    
    return Model(inputs=[M,P],outputs=x)


def build_DD_Net(frame_l=32,joint_n=22,joint_d=3,feat_d=231,clc_num=14,filters=16):
    M = Input(name='M', shape=(frame_l,feat_d))  
    P = Input(name='P', shape=(frame_l,joint_n,joint_d)) 
    
    FM = build_FM(frame_l,joint_n,joint_d,feat_d,filters)
    
    x = FM([M,P])

    x = GlobalMaxPool1D()(x)
    
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = Dense(clc_num, activation='softmax')(x)
    
    ######################Self-supervised part
    model = Model(inputs=[M,P],outputs=x)
    return model

# %%
DD_Net = build_DD_Net(C.frame_l,C.joint_n,C.joint_d,C.feat_d,C.clc_coarse,C.filters)
DD_Net.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ M (InputLayer)      │ (None, 64, 231)   │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ P (InputLayer)      │ (None, 64, 22, 3) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_1        │ (None, 8, 512)    │  1,740,160 │ M[0][0], P[0][0]  │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ functional_1[0][… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     65,536 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 128)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ leaky_re_lu_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     16,384 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 128)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ leaky_re_lu_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 14)        │      1,806 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,824,910 (6.96 MB)
#  Trainable params: 1,819,278 (6.94 MB)
#  Non-trainable params: 5,632 (22.00 KB)

# %%
# !wget https://github.com/fandulu/DD-Net/archive/master.zip
# !unzip master.zip
# !rm master.zip
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# --2024-12-11 23:27:05--  https://github.com/fandulu/DD-Net/archive/master.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master [following]
# --2024-12-11 23:27:05--  https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: 'master.zip'
#
# master.zip              [             <=>    ]  79.09M  14.1MB/s    in 5.6s
#
# 2024-12-11 23:27:11 (14.1 MB/s) - 'master.zip' saved [82934337]
#
# Archive:  master.zip
# f26a9994b0bafc41096fa269eab89c2757d71499
#    creating: DD-Net-master/
#   inflating: DD-Net-master/.gitignore
#    creating: DD-Net-master/JHMDB/
#   inflating: DD-Net-master/JHMDB/README.md
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_heavy.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_lite.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_middle.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_data_preprocessing.ipynb
#   inflating: DD-Net-master/JHMDB/utils.py
#    creating: DD-Net-master/JHMDB/weights/
#  extracting: DD-Net-master/JHMDB/weights/__init__.py
#   inflating: DD-Net-master/LICENSE
#   inflating: DD-Net-master/README.md
#    creating: DD-Net-master/SHREC/
#   inflating: DD-Net-master/SHREC/README.md
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_lite.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_data_preprocessing.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_lite.ipynb
#    creating: DD-Net-master/SHREC/images/
#   inflating: DD-Net-master/SHREC/images/SHREC_14.png
#   inflating: DD-Net-master/SHREC/images/SHREC_28.png
#   inflating: DD-Net-master/SHREC/utils.py
#    creating: DD-Net-master/SHREC/weights/
#  extracting: DD-Net-master/SHREC/weights/.gitkeep
#  extracting: DD-Net-master/SHREC/weights/__init__.py
#    creating: DD-Net-master/data/
#    creating: DD-Net-master/data/JHMDB/
#   inflating: DD-Net-master/data/JHMDB/GT_test_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_3.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_3.pkl
#   inflating: DD-Net-master/data/JHMDB/joint_positions.zip
#   inflating: DD-Net-master/data/JHMDB/splits.zip
#    creating: DD-Net-master/data/SHREC/
#  extracting: DD-Net-master/data/SHREC/__init__.py
#   inflating: DD-Net-master/data/SHREC/test.pickle
#   inflating: DD-Net-master/data/SHREC/test.pkl
#   inflating: DD-Net-master/data/SHREC/train.pickle
#   inflating: DD-Net-master/data/SHREC/train.pkl
#    creating: DD-Net-master/mics/
#  extracting: DD-Net-master/mics/__init__.py
#   inflating: DD-Net-master/mics/demo.png
#   inflating: DD-Net-master/mics/look.gif
#   inflating: DD-Net-master/mics/paper.png

# %%
Train = pickle.load(open("/kaggle/working/DD-Net-master/data/SHREC/train.pkl", "rb"))
Test = pickle.load(open("/kaggle/working/DD-Net-master/data/SHREC/test.pkl", "rb"))

# %%
def preprocess_training_data_with_augmentation(
    data, C, num_augmented_versions=3, crop_size_ratio=0.95, zoom_range=(0.9, 1.1),
    rotation_range=(-15, 15), brightness_range=(0.8, 1.2), contrast_range=(0.8, 1.2)
):
    """
    Preprocess the training data to include the original data and generate multiple augmented versions of each sample.

    Args:
        data: The dataset to preprocess (e.g., Train or Test dictionary).
        C: Configuration object with parameters for preprocessing.
        num_augmented_versions: Number of augmented versions to generate per sample.
        crop_size_ratio: Proportion of the image to crop.
        zoom_range: Range of random zoom factors.
        rotation_range: Range of random rotation angles.
        brightness_range: Range of random brightness adjustments.
        contrast_range: Range of random contrast adjustments.

    Returns:
        X_0: Contact graph features.
        X_1: Preprocessed pose data.
        Y: One-hot encoded labels.
    """
    print(f"Original data size: {len(data['pose'])} samples")

    X_0, X_1, Y = [], [], []

    for i in tqdm(range(len(data['pose']))):
        # Add the original data
        p = np.copy(data['pose'][i]).reshape([-1, C.joint_n, C.joint_d])
        p = normlize_range(p)  # Normalize the original data
        if p.shape[0] != C.frame_l:
            p = zoom(p, target_l=C.frame_l, joints_num=C.joint_n, joints_dim=C.joint_d)  # Ensure correct shape
        label = np.zeros(C.clc_coarse)
        label[data['coarse_label'][i] - 1] = 1
        M = get_CG(p, C)  # Compute contact graph
        X_0.append(M)
        X_1.append(p)
        Y.append(label)

        # Generate augmented versions
        for _ in range(num_augmented_versions):
            p_augmented = np.copy(data['pose'][i]).reshape([-1, C.joint_n, C.joint_d])
            p_augmented = updated_sampling_frame(
                p_augmented, C, crop_size_ratio, zoom_range, rotation_range, brightness_range, contrast_range
            )
            if p_augmented.shape[0] != C.frame_l:
                p_augmented = zoom(p_augmented, target_l=C.frame_l, joints_num=C.joint_n, joints_dim=C.joint_d)
            p_augmented = normlize_range(p_augmented)
            M_augmented = get_CG(p_augmented, C)
            X_0.append(M_augmented)
            X_1.append(p_augmented)
            Y.append(label)  # Same label for augmentations

    print(f"Processed data sizes: X_0={len(X_0)}, X_1={len(X_1)}, Y={len(Y)}")
    return np.stack(X_0), np.stack(X_1), np.stack(Y)

  
# preprocessing for training data
X_0, X_1, Y = preprocess_training_data_with_augmentation(
    Train, C, num_augmented_versions=3, crop_size_ratio=0.95, 
              zoom_range=(0.9, 1.1), rotation_range=(-15, 15), 
              brightness_range=(0.8, 1.2), contrast_range=(0.8, 1.2)
)
# Out:
# Original data size: 1960 samples
#   0%|          | 0/1960 [00:00<?, ?it/s]/tmp/ipykernel_23/3227346658.py:23: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 1960/1960 [00:28<00:00, 68.99it/s]
# Processed data sizes: X_0=7840, X_1=7840, Y=7840

# %%
X_test_0 = []
X_test_1 = []
Y_test = []
for i in tqdm(range(len(Test['pose']))): 
    p = np.copy(Test['pose'][i]).reshape([-1,22,3])
    p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)
    p = normlize_range(p)
    
    label = np.zeros(C.clc_coarse)
    label[Test['coarse_label'][i]-1] = 1   

    M = get_CG(p,C)

    X_test_0.append(M)
    X_test_1.append(p)
    Y_test.append(label)

X_test_0 = np.stack(X_test_0) 
X_test_1 = np.stack(X_test_1)  
Y_test = np.stack(Y_test)
# Out:
#   0%|          | 0/840 [00:00<?, ?it/s]/tmp/ipykernel_23/3227346658.py:23: DeprecationWarning: Please import `zoom` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 840/840 [00:09<00:00, 91.34it/s]

# %%
# it may takes several times to reach the reported performance
lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
            batch_size=len(Y),
            epochs=400,
            verbose=True,
            shuffle=True,
            callbacks=[lrScheduler],
            validation_data=([X_test_0,X_test_1],Y_test)      
            )

lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
            batch_size=len(Y),
            epochs=500,
            verbose=True,
            shuffle=True,
            callbacks=[lrScheduler],
            validation_data=([X_test_0,X_test_1],Y_test)      
            )
# Out:
# Epoch 1/400
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733959757.925513     112 service.cc:145] XLA service 0x7e12180089a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733959757.925565     112 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1733959757.925569     112 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 2024-12-11 23:29:43.869338: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[7840,512,1,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[7840,512,1,8]{3,2,1,0}, f32[512,512,1,3]{3,2,1,0}), window={size=1x3 pad=0_0x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-12-11 23:29:44.670669: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.801433898s
# Trying algorithm eng3{k11=2} for conv (f32[7840,512,1,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[7840,512,1,8]{3,2,1,0}, f32[512,512,1,3]{3,2,1,0}), window={size=1x3 pad=0_0x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1733959820.745582     112 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72s/step - accuracy: 0.0724 - loss: 3.3614
# 2024-12-11 23:30:23.651536: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[840,128,1,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[840,231,1,64]{3,2,1,0}, f32[128,231,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-12-11 23:30:24.016954: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.365525069s
# Trying algorithm eng3{k11=2} for conv (f32[840,128,1,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[840,231,1,64]{3,2,1,0}, f32[128,231,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-12-11 23:30:25.898632: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[840,128,1,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[840,192,1,32]{3,2,1,0}, f32[128,192,1,3]{3,2,1,0}), window={size=1x3 pad=0_0x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-12-11 23:30:26.009740: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.111228419s
# Trying algorithm eng3{k11=2} for conv (f32[840,128,1,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[840,192,1,32]{3,2,1,0}, f32[128,192,1,3]{3,2,1,0}), window={size=1x3 pad=0_0x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 79s 79s/step - accuracy: 0.0724 - loss: 3.3614 - val_accuracy: 0.0679 - val_loss: 2.6388 - learning_rate: 1.0000e-04
# Epoch 2/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0695 - loss: 3.3536 - val_accuracy: 0.0774 - val_loss: 2.6386 - learning_rate: 1.0000e-04
# Epoch 3/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0744 - loss: 3.3196 - val_accuracy: 0.0810 - val_loss: 2.6385 - learning_rate: 1.0000e-04
# Epoch 4/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0760 - loss: 3.2897 - val_accuracy: 0.0810 - val_loss: 2.6384 - learning_rate: 1.0000e-04
# Epoch 5/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0754 - loss: 3.2578 - val_accuracy: 0.0810 - val_loss: 2.6384 - learning_rate: 1.0000e-04
# Epoch 6/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0807 - loss: 3.2568 - val_accuracy: 0.0810 - val_loss: 2.6385 - learning_rate: 1.0000e-04
# Epoch 7/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0816 - loss: 3.2146 - val_accuracy: 0.0810 - val_loss: 2.6386 - learning_rate: 1.0000e-04
# Epoch 8/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0809 - loss: 3.2029 - val_accuracy: 0.0810 - val_loss: 2.6387 - learning_rate: 1.0000e-04
# Epoch 9/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0851 - loss: 3.1882 - val_accuracy: 0.0810 - val_loss: 2.6388 - learning_rate: 1.0000e-04
# Epoch 10/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0857 - loss: 3.1748 - val_accuracy: 0.0810 - val_loss: 2.6390 - learning_rate: 1.0000e-04
# Epoch 11/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0881 - loss: 3.1205 - val_accuracy: 0.0810 - val_loss: 2.6392 - learning_rate: 1.0000e-04
# Epoch 12/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0920 - loss: 3.1457 - val_accuracy: 0.0810 - val_loss: 2.6394 - learning_rate: 1.0000e-04
# Epoch 13/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0963 - loss: 3.1035 - val_accuracy: 0.0810 - val_loss: 2.6396 - learning_rate: 1.0000e-04
# Epoch 14/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0932 - loss: 3.0813 - val_accuracy: 0.0810 - val_loss: 2.6398 - learning_rate: 1.0000e-04
# Epoch 15/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0901 - loss: 3.0795 - val_accuracy: 0.0810 - val_loss: 2.6400 - learning_rate: 1.0000e-04
# Epoch 16/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1028 - loss: 3.0437 - val_accuracy: 0.0810 - val_loss: 2.6403 - learning_rate: 1.0000e-04
# Epoch 17/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0957 - loss: 3.0315 - val_accuracy: 0.0810 - val_loss: 2.6405 - learning_rate: 1.0000e-04
# Epoch 18/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1032 - loss: 3.0183 - val_accuracy: 0.0810 - val_loss: 2.6408 - learning_rate: 1.0000e-04
# Epoch 19/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1033 - loss: 3.0046 - val_accuracy: 0.0810 - val_loss: 2.6411 - learning_rate: 1.0000e-04
# Epoch 20/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1043 - loss: 2.9879 - val_accuracy: 0.0810 - val_loss: 2.6414 - learning_rate: 1.0000e-04
# Epoch 21/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1144 - loss: 2.9597 - val_accuracy: 0.0810 - val_loss: 2.6418 - learning_rate: 1.0000e-04
# Epoch 22/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1144 - loss: 2.9587 - val_accuracy: 0.0810 - val_loss: 2.6422 - learning_rate: 1.0000e-04
# Epoch 23/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1099 - loss: 2.9615 - val_accuracy: 0.0810 - val_loss: 2.6427 - learning_rate: 1.0000e-04
# Epoch 24/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1142 - loss: 2.9248 - val_accuracy: 0.0810 - val_loss: 2.6432 - learning_rate: 1.0000e-04
# Epoch 25/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1193 - loss: 2.9098 - val_accuracy: 0.0810 - val_loss: 2.6437 - learning_rate: 1.0000e-04
# Epoch 26/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.1213 - loss: 2.8892 - val_accuracy: 0.0810 - val_loss: 2.6443 - learning_rate: 1.0000e-04
# Epoch 27/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1212 - loss: 2.8838 - val_accuracy: 0.0810 - val_loss: 2.6449 - learning_rate: 1.0000e-04
# Epoch 28/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1264 - loss: 2.8600 - val_accuracy: 0.0810 - val_loss: 2.6457 - learning_rate: 1.0000e-04
# Epoch 29/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1328 - loss: 2.8411 - val_accuracy: 0.0810 - val_loss: 2.6465 - learning_rate: 1.0000e-04
# Epoch 30/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1327 - loss: 2.8043 - val_accuracy: 0.0810 - val_loss: 2.6475 - learning_rate: 1.0000e-04
# Epoch 31/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1358 - loss: 2.8076 - val_accuracy: 0.0810 - val_loss: 2.6486 - learning_rate: 1.0000e-04
# Epoch 32/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1402 - loss: 2.7924 - val_accuracy: 0.0810 - val_loss: 2.6497 - learning_rate: 1.0000e-04
# Epoch 33/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1454 - loss: 2.7714 - val_accuracy: 0.0810 - val_loss: 2.6509 - learning_rate: 1.0000e-04
# Epoch 34/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1468 - loss: 2.7556 - val_accuracy: 0.0810 - val_loss: 2.6522 - learning_rate: 1.0000e-04
# Epoch 35/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1538 - loss: 2.7249 - val_accuracy: 0.0810 - val_loss: 2.6535 - learning_rate: 1.0000e-04
# Epoch 36/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1543 - loss: 2.7232 - val_accuracy: 0.0810 - val_loss: 2.6550 - learning_rate: 1.0000e-04
# Epoch 37/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1560 - loss: 2.6992 - val_accuracy: 0.0810 - val_loss: 2.6565 - learning_rate: 1.0000e-04
# Epoch 38/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1620 - loss: 2.6910 - val_accuracy: 0.0810 - val_loss: 2.6582 - learning_rate: 1.0000e-04
# Epoch 39/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1696 - loss: 2.6655 - val_accuracy: 0.0810 - val_loss: 2.6599 - learning_rate: 1.0000e-04
# Epoch 40/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1661 - loss: 2.6664 - val_accuracy: 0.0810 - val_loss: 2.6616 - learning_rate: 1.0000e-04
# Epoch 41/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1722 - loss: 2.6286 - val_accuracy: 0.0810 - val_loss: 2.6634 - learning_rate: 1.0000e-04
# Epoch 42/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1675 - loss: 2.6401 - val_accuracy: 0.0810 - val_loss: 2.6653 - learning_rate: 1.0000e-04
# Epoch 43/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1855 - loss: 2.5685 - val_accuracy: 0.0810 - val_loss: 2.6673 - learning_rate: 1.0000e-04
# Epoch 44/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1847 - loss: 2.5724 - val_accuracy: 0.0810 - val_loss: 2.6693 - learning_rate: 1.0000e-04
# Epoch 45/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1911 - loss: 2.5451 - val_accuracy: 0.0810 - val_loss: 2.6714 - learning_rate: 1.0000e-04
# Epoch 46/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2022 - loss: 2.4986 - val_accuracy: 0.1131 - val_loss: 2.6736 - learning_rate: 1.0000e-04
# Epoch 47/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1915 - loss: 2.5130 - val_accuracy: 0.0833 - val_loss: 2.6756 - learning_rate: 1.0000e-04
# Epoch 48/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2065 - loss: 2.4694 - val_accuracy: 0.0679 - val_loss: 2.6777 - learning_rate: 1.0000e-04
# Epoch 49/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2245 - loss: 2.4280 - val_accuracy: 0.0619 - val_loss: 2.6798 - learning_rate: 1.0000e-04
# Epoch 50/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2181 - loss: 2.4081 - val_accuracy: 0.0607 - val_loss: 2.6820 - learning_rate: 1.0000e-04
# Epoch 51/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2250 - loss: 2.4019 - val_accuracy: 0.0607 - val_loss: 2.6842 - learning_rate: 1.0000e-04
# Epoch 52/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2357 - loss: 2.3734 - val_accuracy: 0.0607 - val_loss: 2.6865 - learning_rate: 1.0000e-04
# Epoch 53/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2365 - loss: 2.3712 - val_accuracy: 0.0607 - val_loss: 2.6888 - learning_rate: 1.0000e-04
# Epoch 54/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2409 - loss: 2.3405 - val_accuracy: 0.0607 - val_loss: 2.6911 - learning_rate: 1.0000e-04
# Epoch 55/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2485 - loss: 2.3187 - val_accuracy: 0.0607 - val_loss: 2.6933 - learning_rate: 1.0000e-04
# Epoch 56/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2496 - loss: 2.3104 - val_accuracy: 0.0607 - val_loss: 2.6957 - learning_rate: 1.0000e-04
# Epoch 57/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2661 - loss: 2.2772 - val_accuracy: 0.0607 - val_loss: 2.6982 - learning_rate: 1.0000e-04
# Epoch 58/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2545 - loss: 2.2537 - val_accuracy: 0.0607 - val_loss: 2.7006 - learning_rate: 1.0000e-04
# Epoch 59/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2806 - loss: 2.2190 - val_accuracy: 0.0607 - val_loss: 2.7033 - learning_rate: 1.0000e-04
# Epoch 60/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2760 - loss: 2.2022 - val_accuracy: 0.0607 - val_loss: 2.7062 - learning_rate: 1.0000e-04
# Epoch 61/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2807 - loss: 2.1809 - val_accuracy: 0.0607 - val_loss: 2.7091 - learning_rate: 1.0000e-04
# Epoch 62/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2911 - loss: 2.1502 - val_accuracy: 0.0607 - val_loss: 2.7121 - learning_rate: 1.0000e-04
# Epoch 63/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3003 - loss: 2.1248 - val_accuracy: 0.0607 - val_loss: 2.7153 - learning_rate: 1.0000e-04
# Epoch 64/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3013 - loss: 2.1017 - val_accuracy: 0.0619 - val_loss: 2.7185 - learning_rate: 1.0000e-04
# Epoch 65/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3073 - loss: 2.1039 - val_accuracy: 0.0619 - val_loss: 2.7220 - learning_rate: 1.0000e-04
# Epoch 66/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3193 - loss: 2.0871 - val_accuracy: 0.0619 - val_loss: 2.7256 - learning_rate: 1.0000e-04
# Epoch 67/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3203 - loss: 2.0444 - val_accuracy: 0.0667 - val_loss: 2.7293 - learning_rate: 1.0000e-04
# Epoch 68/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3386 - loss: 2.0072 - val_accuracy: 0.0833 - val_loss: 2.7331 - learning_rate: 1.0000e-04
# Epoch 69/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3421 - loss: 1.9948 - val_accuracy: 0.0929 - val_loss: 2.7370 - learning_rate: 1.0000e-04
# Epoch 70/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3508 - loss: 1.9792 - val_accuracy: 0.1000 - val_loss: 2.7409 - learning_rate: 1.0000e-04
# Epoch 71/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3538 - loss: 1.9621 - val_accuracy: 0.0952 - val_loss: 2.7449 - learning_rate: 1.0000e-04
# Epoch 72/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3724 - loss: 1.9170 - val_accuracy: 0.0726 - val_loss: 2.7491 - learning_rate: 1.0000e-04
# Epoch 73/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3647 - loss: 1.9119 - val_accuracy: 0.0655 - val_loss: 2.7535 - learning_rate: 1.0000e-04
# Epoch 74/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3726 - loss: 1.8916 - val_accuracy: 0.0655 - val_loss: 2.7578 - learning_rate: 1.0000e-04
# Epoch 75/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3806 - loss: 1.8837 - val_accuracy: 0.0655 - val_loss: 2.7625 - learning_rate: 1.0000e-04
# Epoch 76/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3819 - loss: 1.8744 - val_accuracy: 0.0655 - val_loss: 2.7674 - learning_rate: 1.0000e-04
# Epoch 77/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3912 - loss: 1.8418 - val_accuracy: 0.0655 - val_loss: 2.7726 - learning_rate: 1.0000e-04
# Epoch 78/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3977 - loss: 1.8283 - val_accuracy: 0.0655 - val_loss: 2.7780 - learning_rate: 1.0000e-04
# Epoch 79/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3991 - loss: 1.8181 - val_accuracy: 0.0655 - val_loss: 2.7833 - learning_rate: 1.0000e-04
# Epoch 80/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4179 - loss: 1.7842 - val_accuracy: 0.0655 - val_loss: 2.7887 - learning_rate: 1.0000e-04
# Epoch 81/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4196 - loss: 1.7570 - val_accuracy: 0.0655 - val_loss: 2.7940 - learning_rate: 1.0000e-04
# Epoch 82/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4254 - loss: 1.7476 - val_accuracy: 0.0655 - val_loss: 2.7996 - learning_rate: 1.0000e-04
# Epoch 83/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4364 - loss: 1.7265 - val_accuracy: 0.0655 - val_loss: 2.8055 - learning_rate: 1.0000e-04
# Epoch 84/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4332 - loss: 1.7200 - val_accuracy: 0.0655 - val_loss: 2.8113 - learning_rate: 1.0000e-04
# Epoch 85/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4406 - loss: 1.6972 - val_accuracy: 0.0655 - val_loss: 2.8172 - learning_rate: 1.0000e-04
# Epoch 86/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4501 - loss: 1.6799 - val_accuracy: 0.0655 - val_loss: 2.8232 - learning_rate: 1.0000e-04
# Epoch 87/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4603 - loss: 1.6596 - val_accuracy: 0.0655 - val_loss: 2.8292 - learning_rate: 1.0000e-04
# Epoch 88/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4601 - loss: 1.6496 - val_accuracy: 0.0655 - val_loss: 2.8351 - learning_rate: 1.0000e-04
# Epoch 89/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4671 - loss: 1.6268 - val_accuracy: 0.0655 - val_loss: 2.8411 - learning_rate: 1.0000e-04
# Epoch 90/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4686 - loss: 1.6214 - val_accuracy: 0.0655 - val_loss: 2.8475 - learning_rate: 1.0000e-04
# Epoch 91/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4818 - loss: 1.5954 - val_accuracy: 0.0655 - val_loss: 2.8542 - learning_rate: 1.0000e-04
# Epoch 92/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4821 - loss: 1.5907 - val_accuracy: 0.0655 - val_loss: 2.8611 - learning_rate: 1.0000e-04
# Epoch 93/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4955 - loss: 1.5789 - val_accuracy: 0.0655 - val_loss: 2.8680 - learning_rate: 1.0000e-04
# Epoch 94/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4958 - loss: 1.5580 - val_accuracy: 0.0655 - val_loss: 2.8751 - learning_rate: 1.0000e-04
# Epoch 95/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4990 - loss: 1.5387 - val_accuracy: 0.0655 - val_loss: 2.8823 - learning_rate: 1.0000e-04
# Epoch 96/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4992 - loss: 1.5346 - val_accuracy: 0.0655 - val_loss: 2.8896 - learning_rate: 1.0000e-04
# Epoch 97/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5088 - loss: 1.5178 - val_accuracy: 0.0655 - val_loss: 2.8967 - learning_rate: 1.0000e-04
# Epoch 98/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5207 - loss: 1.5024 - val_accuracy: 0.0655 - val_loss: 2.9040 - learning_rate: 1.0000e-04
# Epoch 99/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5255 - loss: 1.4842 - val_accuracy: 0.0655 - val_loss: 2.9114 - learning_rate: 1.0000e-04
# Epoch 100/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5284 - loss: 1.4674 - val_accuracy: 0.0655 - val_loss: 2.9189 - learning_rate: 1.0000e-04
# Epoch 101/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5348 - loss: 1.4547 - val_accuracy: 0.0655 - val_loss: 2.9268 - learning_rate: 1.0000e-04
# Epoch 102/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5365 - loss: 1.4419 - val_accuracy: 0.0655 - val_loss: 2.9349 - learning_rate: 1.0000e-04
# Epoch 103/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5408 - loss: 1.4341 - val_accuracy: 0.0655 - val_loss: 2.9434 - learning_rate: 1.0000e-04
# Epoch 104/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5468 - loss: 1.4194 - val_accuracy: 0.0655 - val_loss: 2.9524 - learning_rate: 1.0000e-04
# Epoch 105/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5455 - loss: 1.4049 - val_accuracy: 0.0655 - val_loss: 2.9614 - learning_rate: 1.0000e-04
# Epoch 106/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5550 - loss: 1.4096 - val_accuracy: 0.0655 - val_loss: 2.9704 - learning_rate: 1.0000e-04
# Epoch 107/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5548 - loss: 1.4072 - val_accuracy: 0.0655 - val_loss: 2.9798 - learning_rate: 1.0000e-04
# Epoch 108/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5584 - loss: 1.3791 - val_accuracy: 0.0655 - val_loss: 2.9892 - learning_rate: 1.0000e-04
# Epoch 109/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5749 - loss: 1.3478 - val_accuracy: 0.0655 - val_loss: 2.9987 - learning_rate: 1.0000e-04
# Epoch 110/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5770 - loss: 1.3549 - val_accuracy: 0.0655 - val_loss: 3.0080 - learning_rate: 1.0000e-04
# Epoch 111/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5722 - loss: 1.3523 - val_accuracy: 0.0655 - val_loss: 3.0169 - learning_rate: 1.0000e-04
# Epoch 112/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5755 - loss: 1.3401 - val_accuracy: 0.0655 - val_loss: 3.0255 - learning_rate: 1.0000e-04
# Epoch 113/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5913 - loss: 1.3108 - val_accuracy: 0.0655 - val_loss: 3.0345 - learning_rate: 1.0000e-04
# Epoch 114/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5776 - loss: 1.3247 - val_accuracy: 0.0655 - val_loss: 3.0438 - learning_rate: 1.0000e-04
# Epoch 115/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5918 - loss: 1.2964 - val_accuracy: 0.0655 - val_loss: 3.0533 - learning_rate: 1.0000e-04
# Epoch 116/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5963 - loss: 1.2931 - val_accuracy: 0.0655 - val_loss: 3.0633 - learning_rate: 1.0000e-04
# Epoch 117/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6015 - loss: 1.2801 - val_accuracy: 0.0655 - val_loss: 3.0735 - learning_rate: 1.0000e-04
# Epoch 118/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6010 - loss: 1.2601 - val_accuracy: 0.0655 - val_loss: 3.0839 - learning_rate: 1.0000e-04
# Epoch 119/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6031 - loss: 1.2811 - val_accuracy: 0.0655 - val_loss: 3.0942 - learning_rate: 1.0000e-04
# Epoch 120/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6036 - loss: 1.2625 - val_accuracy: 0.0655 - val_loss: 3.1049 - learning_rate: 1.0000e-04
# Epoch 121/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6102 - loss: 1.2537 - val_accuracy: 0.0655 - val_loss: 3.1159 - learning_rate: 1.0000e-04
# Epoch 122/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6196 - loss: 1.2250 - val_accuracy: 0.0655 - val_loss: 3.1269 - learning_rate: 1.0000e-04
# Epoch 123/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6136 - loss: 1.2253 - val_accuracy: 0.0655 - val_loss: 3.1378 - learning_rate: 1.0000e-04
# Epoch 124/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6264 - loss: 1.2166 - val_accuracy: 0.0655 - val_loss: 3.1490 - learning_rate: 1.0000e-04
# Epoch 125/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6181 - loss: 1.2239 - val_accuracy: 0.0655 - val_loss: 3.1593 - learning_rate: 1.0000e-04
# Epoch 126/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6319 - loss: 1.1935 - val_accuracy: 0.0655 - val_loss: 3.1697 - learning_rate: 1.0000e-04
# Epoch 127/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6286 - loss: 1.1933 - val_accuracy: 0.0655 - val_loss: 3.1804 - learning_rate: 1.0000e-04
# Epoch 128/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6309 - loss: 1.1843 - val_accuracy: 0.0655 - val_loss: 3.1910 - learning_rate: 1.0000e-04
# Epoch 129/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6311 - loss: 1.1841 - val_accuracy: 0.0655 - val_loss: 3.2010 - learning_rate: 1.0000e-04
# Epoch 130/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6371 - loss: 1.1722 - val_accuracy: 0.0655 - val_loss: 3.2104 - learning_rate: 1.0000e-04
# Epoch 131/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6427 - loss: 1.1508 - val_accuracy: 0.0655 - val_loss: 3.2196 - learning_rate: 1.0000e-04
# Epoch 132/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6427 - loss: 1.1549 - val_accuracy: 0.0655 - val_loss: 3.2284 - learning_rate: 1.0000e-04
# Epoch 133/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6480 - loss: 1.1483 - val_accuracy: 0.0655 - val_loss: 3.2371 - learning_rate: 1.0000e-04
# Epoch 134/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6491 - loss: 1.1432 - val_accuracy: 0.0655 - val_loss: 3.2450 - learning_rate: 1.0000e-04
# Epoch 135/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6557 - loss: 1.1259 - val_accuracy: 0.0655 - val_loss: 3.2532 - learning_rate: 1.0000e-04
# Epoch 136/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6636 - loss: 1.1063 - val_accuracy: 0.0655 - val_loss: 3.2618 - learning_rate: 1.0000e-04
# Epoch 137/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6538 - loss: 1.1224 - val_accuracy: 0.0655 - val_loss: 3.2712 - learning_rate: 1.0000e-04
# Epoch 138/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6667 - loss: 1.1150 - val_accuracy: 0.0655 - val_loss: 3.2805 - learning_rate: 1.0000e-04
# Epoch 139/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6673 - loss: 1.0959 - val_accuracy: 0.0655 - val_loss: 3.2903 - learning_rate: 1.0000e-04
# Epoch 140/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6589 - loss: 1.1037 - val_accuracy: 0.0655 - val_loss: 3.3004 - learning_rate: 1.0000e-04
# Epoch 141/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6608 - loss: 1.0947 - val_accuracy: 0.0655 - val_loss: 3.3109 - learning_rate: 1.0000e-04
# Epoch 142/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6728 - loss: 1.0790 - val_accuracy: 0.0655 - val_loss: 3.3219 - learning_rate: 1.0000e-04
# Epoch 143/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6793 - loss: 1.0668 - val_accuracy: 0.0655 - val_loss: 3.3320 - learning_rate: 1.0000e-04
# Epoch 144/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6776 - loss: 1.0604 - val_accuracy: 0.0655 - val_loss: 3.3428 - learning_rate: 1.0000e-04
# Epoch 145/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6721 - loss: 1.0612 - val_accuracy: 0.0655 - val_loss: 3.3537 - learning_rate: 1.0000e-04
# Epoch 146/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6837 - loss: 1.0489 - val_accuracy: 0.0655 - val_loss: 3.3639 - learning_rate: 1.0000e-04
# Epoch 147/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6908 - loss: 1.0316 - val_accuracy: 0.0655 - val_loss: 3.3744 - learning_rate: 1.0000e-04
# Epoch 148/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6939 - loss: 1.0349 - val_accuracy: 0.0655 - val_loss: 3.3843 - learning_rate: 1.0000e-04
# Epoch 149/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6890 - loss: 1.0352 - val_accuracy: 0.0655 - val_loss: 3.3934 - learning_rate: 1.0000e-04
# Epoch 150/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6884 - loss: 1.0223 - val_accuracy: 0.0655 - val_loss: 3.4031 - learning_rate: 1.0000e-04
# Epoch 151/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7000 - loss: 1.0051 - val_accuracy: 0.0655 - val_loss: 3.4134 - learning_rate: 1.0000e-04
# Epoch 152/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7023 - loss: 1.0085 - val_accuracy: 0.0655 - val_loss: 3.4229 - learning_rate: 1.0000e-04
# Epoch 153/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7014 - loss: 1.0022 - val_accuracy: 0.0655 - val_loss: 3.4310 - learning_rate: 1.0000e-04
# Epoch 154/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6968 - loss: 1.0027 - val_accuracy: 0.0655 - val_loss: 3.4385 - learning_rate: 1.0000e-04
# Epoch 155/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6999 - loss: 0.9927 - val_accuracy: 0.0655 - val_loss: 3.4452 - learning_rate: 1.0000e-04
# Epoch 156/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7120 - loss: 0.9770 - val_accuracy: 0.0655 - val_loss: 3.4518 - learning_rate: 1.0000e-04
# Epoch 157/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7009 - loss: 0.9862 - val_accuracy: 0.0655 - val_loss: 3.4572 - learning_rate: 1.0000e-04
# Epoch 158/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7122 - loss: 0.9745 - val_accuracy: 0.0655 - val_loss: 3.4629 - learning_rate: 1.0000e-04
# Epoch 159/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7199 - loss: 0.9563 - val_accuracy: 0.0655 - val_loss: 3.4686 - learning_rate: 1.0000e-04
# Epoch 160/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7139 - loss: 0.9627 - val_accuracy: 0.0655 - val_loss: 3.4746 - learning_rate: 1.0000e-04
# Epoch 161/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7171 - loss: 0.9566 - val_accuracy: 0.0655 - val_loss: 3.4798 - learning_rate: 1.0000e-04
# Epoch 162/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7235 - loss: 0.9423 - val_accuracy: 0.0655 - val_loss: 3.4848 - learning_rate: 1.0000e-04
# Epoch 163/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7184 - loss: 0.9457 - val_accuracy: 0.0655 - val_loss: 3.4901 - learning_rate: 1.0000e-04
# Epoch 164/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7293 - loss: 0.9225 - val_accuracy: 0.0655 - val_loss: 3.4958 - learning_rate: 1.0000e-04
# Epoch 165/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7320 - loss: 0.9204 - val_accuracy: 0.0655 - val_loss: 3.5014 - learning_rate: 1.0000e-04
# Epoch 166/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7282 - loss: 0.9201 - val_accuracy: 0.0655 - val_loss: 3.5062 - learning_rate: 1.0000e-04
# Epoch 167/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7253 - loss: 0.9179 - val_accuracy: 0.0655 - val_loss: 3.5108 - learning_rate: 1.0000e-04
# Epoch 168/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7321 - loss: 0.9117 - val_accuracy: 0.0655 - val_loss: 3.5167 - learning_rate: 1.0000e-04
# Epoch 169/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7389 - loss: 0.8973 - val_accuracy: 0.0655 - val_loss: 3.5237 - learning_rate: 1.0000e-04
# Epoch 170/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7413 - loss: 0.8930 - val_accuracy: 0.0655 - val_loss: 3.5332 - learning_rate: 1.0000e-04
# Epoch 171/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7403 - loss: 0.8898 - val_accuracy: 0.0655 - val_loss: 3.5431 - learning_rate: 1.0000e-04
# Epoch 172/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7329 - loss: 0.8948 - val_accuracy: 0.0655 - val_loss: 3.5515 - learning_rate: 1.0000e-04
# Epoch 173/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7453 - loss: 0.8758 - val_accuracy: 0.0655 - val_loss: 3.5600 - learning_rate: 1.0000e-04
# Epoch 174/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7434 - loss: 0.8782 - val_accuracy: 0.0655 - val_loss: 3.5680 - learning_rate: 1.0000e-04
# Epoch 175/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7421 - loss: 0.8797 - val_accuracy: 0.0655 - val_loss: 3.5752 - learning_rate: 1.0000e-04
# Epoch 176/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7518 - loss: 0.8572 - val_accuracy: 0.0655 - val_loss: 3.5819 - learning_rate: 1.0000e-04
# Epoch 177/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7457 - loss: 0.8651 - val_accuracy: 0.0655 - val_loss: 3.5876 - learning_rate: 1.0000e-04
# Epoch 178/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7536 - loss: 0.8544 - val_accuracy: 0.0655 - val_loss: 3.5910 - learning_rate: 1.0000e-04
# Epoch 179/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7614 - loss: 0.8380 - val_accuracy: 0.0655 - val_loss: 3.5946 - learning_rate: 1.0000e-04
# Epoch 180/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7551 - loss: 0.8500 - val_accuracy: 0.0655 - val_loss: 3.5958 - learning_rate: 1.0000e-04
# Epoch 181/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7606 - loss: 0.8331 - val_accuracy: 0.0655 - val_loss: 3.5970 - learning_rate: 1.0000e-04
# Epoch 182/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7634 - loss: 0.8320 - val_accuracy: 0.0655 - val_loss: 3.5973 - learning_rate: 1.0000e-04
# Epoch 183/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7610 - loss: 0.8334 - val_accuracy: 0.0655 - val_loss: 3.5978 - learning_rate: 1.0000e-04
# Epoch 184/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7598 - loss: 0.8237 - val_accuracy: 0.0655 - val_loss: 3.5992 - learning_rate: 1.0000e-04
# Epoch 185/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7608 - loss: 0.8287 - val_accuracy: 0.0667 - val_loss: 3.6004 - learning_rate: 1.0000e-04
# Epoch 186/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7630 - loss: 0.8325 - val_accuracy: 0.0679 - val_loss: 3.6005 - learning_rate: 1.0000e-04
# Epoch 187/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7689 - loss: 0.8062 - val_accuracy: 0.0679 - val_loss: 3.6011 - learning_rate: 1.0000e-04
# Epoch 188/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7764 - loss: 0.7923 - val_accuracy: 0.0690 - val_loss: 3.6029 - learning_rate: 1.0000e-04
# Epoch 189/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7742 - loss: 0.7947 - val_accuracy: 0.0690 - val_loss: 3.6033 - learning_rate: 1.0000e-04
# Epoch 190/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7703 - loss: 0.8009 - val_accuracy: 0.0690 - val_loss: 3.6048 - learning_rate: 1.0000e-04
# Epoch 191/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7703 - loss: 0.7961 - val_accuracy: 0.0690 - val_loss: 3.6067 - learning_rate: 1.0000e-04
# Epoch 192/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7698 - loss: 0.7937 - val_accuracy: 0.0702 - val_loss: 3.6080 - learning_rate: 1.0000e-04
# Epoch 193/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7730 - loss: 0.7784 - val_accuracy: 0.0702 - val_loss: 3.6092 - learning_rate: 1.0000e-04
# Epoch 194/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7787 - loss: 0.7782 - val_accuracy: 0.0702 - val_loss: 3.6110 - learning_rate: 1.0000e-04
# Epoch 195/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7797 - loss: 0.7752 - val_accuracy: 0.0702 - val_loss: 3.6123 - learning_rate: 1.0000e-04
# Epoch 196/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7763 - loss: 0.7875 - val_accuracy: 0.0702 - val_loss: 3.6141 - learning_rate: 1.0000e-04
# Epoch 197/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7884 - loss: 0.7663 - val_accuracy: 0.0702 - val_loss: 3.6137 - learning_rate: 1.0000e-04
# Epoch 198/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7884 - loss: 0.7546 - val_accuracy: 0.0702 - val_loss: 3.6143 - learning_rate: 1.0000e-04
# Epoch 199/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7885 - loss: 0.7567 - val_accuracy: 0.0702 - val_loss: 3.6165 - learning_rate: 1.0000e-04
# Epoch 200/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7823 - loss: 0.7630 - val_accuracy: 0.0702 - val_loss: 3.6173 - learning_rate: 1.0000e-04
# Epoch 201/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7846 - loss: 0.7655 - val_accuracy: 0.0714 - val_loss: 3.6172 - learning_rate: 1.0000e-04
# Epoch 202/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7862 - loss: 0.7475 - val_accuracy: 0.0714 - val_loss: 3.6151 - learning_rate: 1.0000e-04
# Epoch 203/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7929 - loss: 0.7473 - val_accuracy: 0.0714 - val_loss: 3.6122 - learning_rate: 1.0000e-04
# Epoch 204/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7893 - loss: 0.7366 - val_accuracy: 0.0714 - val_loss: 3.6101 - learning_rate: 1.0000e-04
# Epoch 205/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7935 - loss: 0.7292 - val_accuracy: 0.0714 - val_loss: 3.6064 - learning_rate: 1.0000e-04
# Epoch 206/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7908 - loss: 0.7319 - val_accuracy: 0.0726 - val_loss: 3.6047 - learning_rate: 1.0000e-04
# Epoch 207/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7983 - loss: 0.7233 - val_accuracy: 0.0738 - val_loss: 3.6028 - learning_rate: 1.0000e-04
# Epoch 208/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7950 - loss: 0.7262 - val_accuracy: 0.0750 - val_loss: 3.6030 - learning_rate: 1.0000e-04
# Epoch 209/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7981 - loss: 0.7204 - val_accuracy: 0.0750 - val_loss: 3.6036 - learning_rate: 1.0000e-04
# Epoch 210/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7989 - loss: 0.7228 - val_accuracy: 0.0762 - val_loss: 3.6053 - learning_rate: 1.0000e-04
# Epoch 211/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8089 - loss: 0.6927 - val_accuracy: 0.0786 - val_loss: 3.6053 - learning_rate: 1.0000e-04
# Epoch 212/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8047 - loss: 0.7049 - val_accuracy: 0.0798 - val_loss: 3.6033 - learning_rate: 1.0000e-04
# Epoch 213/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8056 - loss: 0.7028 - val_accuracy: 0.0798 - val_loss: 3.5996 - learning_rate: 1.0000e-04
# Epoch 214/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8085 - loss: 0.6955 - val_accuracy: 0.0821 - val_loss: 3.5933 - learning_rate: 1.0000e-04
# Epoch 215/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8024 - loss: 0.7026 - val_accuracy: 0.0821 - val_loss: 3.5865 - learning_rate: 1.0000e-04
# Epoch 216/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8098 - loss: 0.6939 - val_accuracy: 0.0845 - val_loss: 3.5793 - learning_rate: 1.0000e-04
# Epoch 217/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8114 - loss: 0.6925 - val_accuracy: 0.0845 - val_loss: 3.5749 - learning_rate: 5.0000e-05
# Epoch 218/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8124 - loss: 0.6824 - val_accuracy: 0.0869 - val_loss: 3.5697 - learning_rate: 5.0000e-05
# Epoch 219/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8111 - loss: 0.6828 - val_accuracy: 0.0869 - val_loss: 3.5643 - learning_rate: 5.0000e-05
# Epoch 220/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8064 - loss: 0.6993 - val_accuracy: 0.0869 - val_loss: 3.5611 - learning_rate: 5.0000e-05
# Epoch 221/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8170 - loss: 0.6728 - val_accuracy: 0.0869 - val_loss: 3.5584 - learning_rate: 5.0000e-05
# Epoch 222/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8103 - loss: 0.6801 - val_accuracy: 0.0869 - val_loss: 3.5560 - learning_rate: 5.0000e-05
# Epoch 223/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8059 - loss: 0.6796 - val_accuracy: 0.0881 - val_loss: 3.5534 - learning_rate: 5.0000e-05
# Epoch 224/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8074 - loss: 0.6849 - val_accuracy: 0.0881 - val_loss: 3.5510 - learning_rate: 5.0000e-05
# Epoch 225/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8136 - loss: 0.6686 - val_accuracy: 0.0881 - val_loss: 3.5487 - learning_rate: 5.0000e-05
# Epoch 226/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8078 - loss: 0.6739 - val_accuracy: 0.0905 - val_loss: 3.5456 - learning_rate: 5.0000e-05
# Epoch 227/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8158 - loss: 0.6699 - val_accuracy: 0.0905 - val_loss: 3.5433 - learning_rate: 5.0000e-05
# Epoch 228/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8099 - loss: 0.6705 - val_accuracy: 0.0905 - val_loss: 3.5399 - learning_rate: 5.0000e-05
# Epoch 229/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8117 - loss: 0.6762 - val_accuracy: 0.0917 - val_loss: 3.5351 - learning_rate: 5.0000e-05
# Epoch 230/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8177 - loss: 0.6598 - val_accuracy: 0.0917 - val_loss: 3.5296 - learning_rate: 5.0000e-05
# Epoch 231/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8154 - loss: 0.6653 - val_accuracy: 0.0929 - val_loss: 3.5233 - learning_rate: 5.0000e-05
# Epoch 232/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8162 - loss: 0.6657 - val_accuracy: 0.0940 - val_loss: 3.5173 - learning_rate: 5.0000e-05
# Epoch 233/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8195 - loss: 0.6634 - val_accuracy: 0.0940 - val_loss: 3.5107 - learning_rate: 5.0000e-05
# Epoch 234/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8166 - loss: 0.6674 - val_accuracy: 0.0976 - val_loss: 3.5045 - learning_rate: 5.0000e-05
# Epoch 235/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8163 - loss: 0.6590 - val_accuracy: 0.1012 - val_loss: 3.4994 - learning_rate: 5.0000e-05
# Epoch 236/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8176 - loss: 0.6580 - val_accuracy: 0.1048 - val_loss: 3.4941 - learning_rate: 5.0000e-05
# Epoch 237/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8272 - loss: 0.6438 - val_accuracy: 0.1048 - val_loss: 3.4889 - learning_rate: 5.0000e-05
# Epoch 238/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8210 - loss: 0.6564 - val_accuracy: 0.1071 - val_loss: 3.4833 - learning_rate: 5.0000e-05
# Epoch 239/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8233 - loss: 0.6429 - val_accuracy: 0.1083 - val_loss: 3.4775 - learning_rate: 5.0000e-05
# Epoch 240/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8203 - loss: 0.6491 - val_accuracy: 0.1107 - val_loss: 3.4718 - learning_rate: 5.0000e-05
# Epoch 241/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8196 - loss: 0.6469 - val_accuracy: 0.1107 - val_loss: 3.4654 - learning_rate: 5.0000e-05
# Epoch 242/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8226 - loss: 0.6497 - val_accuracy: 0.1107 - val_loss: 3.4576 - learning_rate: 5.0000e-05
# Epoch 243/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8209 - loss: 0.6483 - val_accuracy: 0.1119 - val_loss: 3.4484 - learning_rate: 5.0000e-05
# Epoch 244/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8258 - loss: 0.6399 - val_accuracy: 0.1119 - val_loss: 3.4398 - learning_rate: 5.0000e-05
# Epoch 245/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8245 - loss: 0.6389 - val_accuracy: 0.1119 - val_loss: 3.4325 - learning_rate: 5.0000e-05
# Epoch 246/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8227 - loss: 0.6454 - val_accuracy: 0.1143 - val_loss: 3.4254 - learning_rate: 5.0000e-05
# Epoch 247/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8221 - loss: 0.6419 - val_accuracy: 0.1155 - val_loss: 3.4180 - learning_rate: 5.0000e-05
# Epoch 248/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8297 - loss: 0.6266 - val_accuracy: 0.1167 - val_loss: 3.4114 - learning_rate: 5.0000e-05
# Epoch 249/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8231 - loss: 0.6306 - val_accuracy: 0.1190 - val_loss: 3.4044 - learning_rate: 5.0000e-05
# Epoch 250/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8270 - loss: 0.6293 - val_accuracy: 0.1214 - val_loss: 3.3960 - learning_rate: 5.0000e-05
# Epoch 251/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8343 - loss: 0.6270 - val_accuracy: 0.1226 - val_loss: 3.3877 - learning_rate: 5.0000e-05
# Epoch 252/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8314 - loss: 0.6218 - val_accuracy: 0.1238 - val_loss: 3.3788 - learning_rate: 5.0000e-05
# Epoch 253/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8314 - loss: 0.6282 - val_accuracy: 0.1250 - val_loss: 3.3682 - learning_rate: 5.0000e-05
# Epoch 254/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8364 - loss: 0.6181 - val_accuracy: 0.1250 - val_loss: 3.3576 - learning_rate: 5.0000e-05
# Epoch 255/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8268 - loss: 0.6251 - val_accuracy: 0.1274 - val_loss: 3.3466 - learning_rate: 5.0000e-05
# Epoch 256/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8263 - loss: 0.6302 - val_accuracy: 0.1298 - val_loss: 3.3359 - learning_rate: 5.0000e-05
# Epoch 257/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8260 - loss: 0.6251 - val_accuracy: 0.1298 - val_loss: 3.3266 - learning_rate: 5.0000e-05
# Epoch 258/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8360 - loss: 0.6186 - val_accuracy: 0.1310 - val_loss: 3.3186 - learning_rate: 5.0000e-05
# Epoch 259/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8315 - loss: 0.6239 - val_accuracy: 0.1310 - val_loss: 3.3100 - learning_rate: 5.0000e-05
# Epoch 260/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8302 - loss: 0.6139 - val_accuracy: 0.1310 - val_loss: 3.3030 - learning_rate: 2.5000e-05
# Epoch 261/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8269 - loss: 0.6242 - val_accuracy: 0.1310 - val_loss: 3.2965 - learning_rate: 2.5000e-05
# Epoch 262/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8366 - loss: 0.6018 - val_accuracy: 0.1321 - val_loss: 3.2904 - learning_rate: 2.5000e-05
# Epoch 263/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8334 - loss: 0.6226 - val_accuracy: 0.1321 - val_loss: 3.2842 - learning_rate: 2.5000e-05
# Epoch 264/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8305 - loss: 0.6097 - val_accuracy: 0.1333 - val_loss: 3.2782 - learning_rate: 2.5000e-05
# Epoch 265/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8376 - loss: 0.6047 - val_accuracy: 0.1357 - val_loss: 3.2717 - learning_rate: 2.5000e-05
# Epoch 266/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8361 - loss: 0.6115 - val_accuracy: 0.1357 - val_loss: 3.2650 - learning_rate: 2.5000e-05
# Epoch 267/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8323 - loss: 0.6116 - val_accuracy: 0.1357 - val_loss: 3.2582 - learning_rate: 2.5000e-05
# Epoch 268/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8323 - loss: 0.6189 - val_accuracy: 0.1369 - val_loss: 3.2509 - learning_rate: 2.5000e-05
# Epoch 269/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8356 - loss: 0.6069 - val_accuracy: 0.1381 - val_loss: 3.2434 - learning_rate: 1.2500e-05
# Epoch 270/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8341 - loss: 0.6138 - val_accuracy: 0.1381 - val_loss: 3.2356 - learning_rate: 1.2500e-05
# Epoch 271/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8346 - loss: 0.6128 - val_accuracy: 0.1381 - val_loss: 3.2276 - learning_rate: 1.2500e-05
# Epoch 272/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8398 - loss: 0.6020 - val_accuracy: 0.1381 - val_loss: 3.2197 - learning_rate: 1.2500e-05
# Epoch 273/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8328 - loss: 0.6167 - val_accuracy: 0.1381 - val_loss: 3.2114 - learning_rate: 1.2500e-05
# Epoch 274/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8381 - loss: 0.6050 - val_accuracy: 0.1381 - val_loss: 3.2028 - learning_rate: 1.2500e-05
# Epoch 275/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8390 - loss: 0.5947 - val_accuracy: 0.1417 - val_loss: 3.1940 - learning_rate: 1.2500e-05
# Epoch 276/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8394 - loss: 0.6076 - val_accuracy: 0.1429 - val_loss: 3.1850 - learning_rate: 1.2500e-05
# Epoch 277/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8376 - loss: 0.6011 - val_accuracy: 0.1429 - val_loss: 3.1763 - learning_rate: 1.2500e-05
# Epoch 278/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8376 - loss: 0.6039 - val_accuracy: 0.1440 - val_loss: 3.1673 - learning_rate: 1.2500e-05
# Epoch 279/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8335 - loss: 0.6040 - val_accuracy: 0.1440 - val_loss: 3.1582 - learning_rate: 1.2500e-05
# Epoch 280/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8349 - loss: 0.6015 - val_accuracy: 0.1440 - val_loss: 3.1492 - learning_rate: 1.2500e-05
# Epoch 281/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8383 - loss: 0.6014 - val_accuracy: 0.1440 - val_loss: 3.1401 - learning_rate: 6.2500e-06
# Epoch 282/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8332 - loss: 0.6069 - val_accuracy: 0.1440 - val_loss: 3.1308 - learning_rate: 6.2500e-06
# Epoch 283/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8361 - loss: 0.6077 - val_accuracy: 0.1452 - val_loss: 3.1213 - learning_rate: 6.2500e-06
# Epoch 284/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8355 - loss: 0.6070 - val_accuracy: 0.1476 - val_loss: 3.1118 - learning_rate: 6.2500e-06
# Epoch 285/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8338 - loss: 0.6073 - val_accuracy: 0.1476 - val_loss: 3.1019 - learning_rate: 6.2500e-06
# Epoch 286/400
# ...
# Epoch 398/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9342 - loss: 0.2764 - val_accuracy: 0.9357 - val_loss: 0.2045 - learning_rate: 5.0000e-06
# Epoch 399/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9385 - loss: 0.2669 - val_accuracy: 0.9357 - val_loss: 0.2045 - learning_rate: 5.0000e-06
# Epoch 400/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9398 - loss: 0.2649 - val_accuracy: 0.9357 - val_loss: 0.2043 - learning_rate: 5.0000e-06
# Epoch 401/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9395 - loss: 0.2631 - val_accuracy: 0.9357 - val_loss: 0.2043 - learning_rate: 5.0000e-06
# Epoch 402/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9348 - loss: 0.2732 - val_accuracy: 0.9345 - val_loss: 0.2042 - learning_rate: 5.0000e-06
# Epoch 403/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9376 - loss: 0.2710 - val_accuracy: 0.9345 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 404/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9389 - loss: 0.2671 - val_accuracy: 0.9345 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 405/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9349 - loss: 0.2741 - val_accuracy: 0.9345 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 406/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9402 - loss: 0.2647 - val_accuracy: 0.9345 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 407/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9302 - loss: 0.2814 - val_accuracy: 0.9345 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 408/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9411 - loss: 0.2654 - val_accuracy: 0.9345 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 409/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9402 - loss: 0.2590 - val_accuracy: 0.9345 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 410/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9376 - loss: 0.2679 - val_accuracy: 0.9345 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 411/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9344 - loss: 0.2749 - val_accuracy: 0.9345 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 412/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9389 - loss: 0.2631 - val_accuracy: 0.9345 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 413/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9356 - loss: 0.2705 - val_accuracy: 0.9345 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 414/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9356 - loss: 0.2697 - val_accuracy: 0.9333 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 415/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9394 - loss: 0.2676 - val_accuracy: 0.9321 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 416/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9361 - loss: 0.2633 - val_accuracy: 0.9321 - val_loss: 0.2042 - learning_rate: 5.0000e-06
# Epoch 417/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9351 - loss: 0.2683 - val_accuracy: 0.9321 - val_loss: 0.2043 - learning_rate: 5.0000e-06
# Epoch 418/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9353 - loss: 0.2700 - val_accuracy: 0.9321 - val_loss: 0.2044 - learning_rate: 5.0000e-06
# Epoch 419/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9409 - loss: 0.2643 - val_accuracy: 0.9321 - val_loss: 0.2044 - learning_rate: 5.0000e-06
# Epoch 420/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9343 - loss: 0.2716 - val_accuracy: 0.9310 - val_loss: 0.2045 - learning_rate: 5.0000e-06
# Epoch 421/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9375 - loss: 0.2702 - val_accuracy: 0.9310 - val_loss: 0.2045 - learning_rate: 5.0000e-06
# Epoch 422/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9401 - loss: 0.2584 - val_accuracy: 0.9310 - val_loss: 0.2045 - learning_rate: 5.0000e-06
# Epoch 423/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9376 - loss: 0.2687 - val_accuracy: 0.9310 - val_loss: 0.2046 - learning_rate: 5.0000e-06
# Epoch 424/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9346 - loss: 0.2787 - val_accuracy: 0.9310 - val_loss: 0.2047 - learning_rate: 5.0000e-06
# Epoch 425/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9351 - loss: 0.2719 - val_accuracy: 0.9310 - val_loss: 0.2047 - learning_rate: 5.0000e-06
# Epoch 426/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9423 - loss: 0.2622 - val_accuracy: 0.9310 - val_loss: 0.2048 - learning_rate: 5.0000e-06
# Epoch 427/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9389 - loss: 0.2627 - val_accuracy: 0.9310 - val_loss: 0.2048 - learning_rate: 5.0000e-06
# Epoch 428/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9353 - loss: 0.2711 - val_accuracy: 0.9310 - val_loss: 0.2048 - learning_rate: 5.0000e-06
# Epoch 429/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9357 - loss: 0.2674 - val_accuracy: 0.9310 - val_loss: 0.2048 - learning_rate: 5.0000e-06
# Epoch 430/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9385 - loss: 0.2657 - val_accuracy: 0.9310 - val_loss: 0.2048 - learning_rate: 5.0000e-06
# Epoch 431/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9381 - loss: 0.2675 - val_accuracy: 0.9310 - val_loss: 0.2048 - learning_rate: 5.0000e-06
# Epoch 432/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9362 - loss: 0.2752 - val_accuracy: 0.9310 - val_loss: 0.2048 - learning_rate: 5.0000e-06
# Epoch 433/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9388 - loss: 0.2627 - val_accuracy: 0.9310 - val_loss: 0.2048 - learning_rate: 5.0000e-06
# Epoch 434/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9407 - loss: 0.2587 - val_accuracy: 0.9310 - val_loss: 0.2048 - learning_rate: 5.0000e-06
# Epoch 435/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9398 - loss: 0.2668 - val_accuracy: 0.9310 - val_loss: 0.2048 - learning_rate: 5.0000e-06
# Epoch 436/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9375 - loss: 0.2715 - val_accuracy: 0.9310 - val_loss: 0.2047 - learning_rate: 5.0000e-06
# Epoch 437/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9379 - loss: 0.2667 - val_accuracy: 0.9310 - val_loss: 0.2047 - learning_rate: 5.0000e-06
# Epoch 438/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9430 - loss: 0.2566 - val_accuracy: 0.9310 - val_loss: 0.2047 - learning_rate: 5.0000e-06
# Epoch 439/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9380 - loss: 0.2654 - val_accuracy: 0.9310 - val_loss: 0.2046 - learning_rate: 5.0000e-06
# Epoch 440/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9417 - loss: 0.2584 - val_accuracy: 0.9310 - val_loss: 0.2045 - learning_rate: 5.0000e-06
# Epoch 441/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9372 - loss: 0.2631 - val_accuracy: 0.9321 - val_loss: 0.2045 - learning_rate: 5.0000e-06
# Epoch 442/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9403 - loss: 0.2628 - val_accuracy: 0.9321 - val_loss: 0.2044 - learning_rate: 5.0000e-06
# Epoch 443/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9362 - loss: 0.2714 - val_accuracy: 0.9321 - val_loss: 0.2043 - learning_rate: 5.0000e-06
# Epoch 444/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9374 - loss: 0.2671 - val_accuracy: 0.9321 - val_loss: 0.2043 - learning_rate: 5.0000e-06
# Epoch 445/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9389 - loss: 0.2732 - val_accuracy: 0.9321 - val_loss: 0.2042 - learning_rate: 5.0000e-06
# Epoch 446/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9352 - loss: 0.2679 - val_accuracy: 0.9321 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 447/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9361 - loss: 0.2721 - val_accuracy: 0.9321 - val_loss: 0.2041 - learning_rate: 5.0000e-06
# Epoch 448/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9362 - loss: 0.2707 - val_accuracy: 0.9321 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 449/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9402 - loss: 0.2651 - val_accuracy: 0.9321 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 450/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9417 - loss: 0.2549 - val_accuracy: 0.9321 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 451/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9347 - loss: 0.2660 - val_accuracy: 0.9310 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 452/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9411 - loss: 0.2554 - val_accuracy: 0.9310 - val_loss: 0.2039 - learning_rate: 5.0000e-06
# Epoch 453/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9411 - loss: 0.2620 - val_accuracy: 0.9310 - val_loss: 0.2039 - learning_rate: 5.0000e-06
# Epoch 454/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9378 - loss: 0.2631 - val_accuracy: 0.9310 - val_loss: 0.2039 - learning_rate: 5.0000e-06
# Epoch 455/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9365 - loss: 0.2649 - val_accuracy: 0.9310 - val_loss: 0.2039 - learning_rate: 5.0000e-06
# Epoch 456/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9356 - loss: 0.2698 - val_accuracy: 0.9310 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 457/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9369 - loss: 0.2642 - val_accuracy: 0.9310 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 458/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9404 - loss: 0.2650 - val_accuracy: 0.9310 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 459/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9398 - loss: 0.2626 - val_accuracy: 0.9310 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 460/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9403 - loss: 0.2577 - val_accuracy: 0.9321 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 461/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9441 - loss: 0.2569 - val_accuracy: 0.9321 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 462/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9366 - loss: 0.2646 - val_accuracy: 0.9321 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 463/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9416 - loss: 0.2613 - val_accuracy: 0.9321 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 464/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9397 - loss: 0.2619 - val_accuracy: 0.9321 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 465/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9380 - loss: 0.2667 - val_accuracy: 0.9333 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 466/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9384 - loss: 0.2704 - val_accuracy: 0.9333 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 467/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9426 - loss: 0.2605 - val_accuracy: 0.9333 - val_loss: 0.2039 - learning_rate: 5.0000e-06
# Epoch 468/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9388 - loss: 0.2643 - val_accuracy: 0.9333 - val_loss: 0.2039 - learning_rate: 5.0000e-06
# Epoch 469/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9392 - loss: 0.2682 - val_accuracy: 0.9333 - val_loss: 0.2038 - learning_rate: 5.0000e-06
# Epoch 470/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9362 - loss: 0.2680 - val_accuracy: 0.9333 - val_loss: 0.2038 - learning_rate: 5.0000e-06
# Epoch 471/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9379 - loss: 0.2675 - val_accuracy: 0.9333 - val_loss: 0.2037 - learning_rate: 5.0000e-06
# Epoch 472/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9429 - loss: 0.2563 - val_accuracy: 0.9333 - val_loss: 0.2036 - learning_rate: 5.0000e-06
# Epoch 473/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9385 - loss: 0.2665 - val_accuracy: 0.9333 - val_loss: 0.2036 - learning_rate: 5.0000e-06
# Epoch 474/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9381 - loss: 0.2601 - val_accuracy: 0.9333 - val_loss: 0.2036 - learning_rate: 5.0000e-06
# Epoch 475/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9432 - loss: 0.2601 - val_accuracy: 0.9345 - val_loss: 0.2036 - learning_rate: 5.0000e-06
# Epoch 476/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9348 - loss: 0.2769 - val_accuracy: 0.9345 - val_loss: 0.2036 - learning_rate: 5.0000e-06
# Epoch 477/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9416 - loss: 0.2564 - val_accuracy: 0.9345 - val_loss: 0.2036 - learning_rate: 5.0000e-06
# Epoch 478/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9383 - loss: 0.2635 - val_accuracy: 0.9345 - val_loss: 0.2036 - learning_rate: 5.0000e-06
# Epoch 479/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9403 - loss: 0.2628 - val_accuracy: 0.9345 - val_loss: 0.2036 - learning_rate: 5.0000e-06
# Epoch 480/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9369 - loss: 0.2662 - val_accuracy: 0.9345 - val_loss: 0.2037 - learning_rate: 5.0000e-06
# Epoch 481/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9364 - loss: 0.2628 - val_accuracy: 0.9345 - val_loss: 0.2037 - learning_rate: 5.0000e-06
# Epoch 482/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9385 - loss: 0.2633 - val_accuracy: 0.9345 - val_loss: 0.2037 - learning_rate: 5.0000e-06
# Epoch 483/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9412 - loss: 0.2543 - val_accuracy: 0.9333 - val_loss: 0.2038 - learning_rate: 5.0000e-06
# Epoch 484/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9403 - loss: 0.2592 - val_accuracy: 0.9333 - val_loss: 0.2038 - learning_rate: 5.0000e-06
# Epoch 485/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9376 - loss: 0.2606 - val_accuracy: 0.9345 - val_loss: 0.2038 - learning_rate: 5.0000e-06
# Epoch 486/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9356 - loss: 0.2706 - val_accuracy: 0.9345 - val_loss: 0.2038 - learning_rate: 5.0000e-06
# Epoch 487/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9418 - loss: 0.2571 - val_accuracy: 0.9345 - val_loss: 0.2039 - learning_rate: 5.0000e-06
# Epoch 488/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9398 - loss: 0.2636 - val_accuracy: 0.9345 - val_loss: 0.2039 - learning_rate: 5.0000e-06
# Epoch 489/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9401 - loss: 0.2578 - val_accuracy: 0.9345 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 490/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9427 - loss: 0.2542 - val_accuracy: 0.9345 - val_loss: 0.2040 - learning_rate: 5.0000e-06
# Epoch 491/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9395 - loss: 0.2644 - val_accuracy: 0.9345 - val_loss: 0.2039 - learning_rate: 5.0000e-06
# Epoch 492/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9394 - loss: 0.2602 - val_accuracy: 0.9345 - val_loss: 0.2039 - learning_rate: 5.0000e-06
# Epoch 493/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9407 - loss: 0.2616 - val_accuracy: 0.9345 - val_loss: 0.2038 - learning_rate: 5.0000e-06
# Epoch 494/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9385 - loss: 0.2605 - val_accuracy: 0.9345 - val_loss: 0.2037 - learning_rate: 5.0000e-06
# Epoch 495/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9362 - loss: 0.2628 - val_accuracy: 0.9345 - val_loss: 0.2037 - learning_rate: 5.0000e-06
# Epoch 496/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9384 - loss: 0.2618 - val_accuracy: 0.9345 - val_loss: 0.2036 - learning_rate: 5.0000e-06
# Epoch 497/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9402 - loss: 0.2648 - val_accuracy: 0.9345 - val_loss: 0.2035 - learning_rate: 5.0000e-06
# Epoch 498/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9431 - loss: 0.2568 - val_accuracy: 0.9345 - val_loss: 0.2035 - learning_rate: 5.0000e-06
# Epoch 499/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9372 - loss: 0.2700 - val_accuracy: 0.9345 - val_loss: 0.2034 - learning_rate: 5.0000e-06
# Epoch 500/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9398 - loss: 0.2614 - val_accuracy: 0.9345 - val_loss: 0.2034 - learning_rate: 5.0000e-06

# %%
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Test'])
plt.show()

# %%
Y_pred = DD_Net.predict([X_test_0,X_test_1])
labels = ['Grab', 'Tap', 'Expand', 'Pinch', 'RC', 'RCC', 'SR', 'SL', 'SU', 'SD', 'SX', 'S+', 'SV', 'Shake']

y_true = []
for i in np.argmax(Y_test,axis=1):
    y_true.append(labels[i])
    
y_pred = []
for i in np.argmax(Y_pred,axis=1):
    y_pred.append(labels[i])

cm_analysis(y_true,y_pred, 'SHREC_14.png', labels, ymap=None, figsize=(8,8))
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step
