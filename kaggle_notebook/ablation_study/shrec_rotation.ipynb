# %%
# !git clone https://github.com/NadaAbodeshish/Random-Cropping-augmentation-HGR.git
# Out:
# Cloning into 'Random-Cropping-augmentation-HGR'...
# remote: Enumerating objects: 886, done.
# remote: Counting objects: 100% (249/249), done.
# remote: Compressing objects: 100% (173/173), done.
# remote: Total 886 (delta 139), reused 180 (delta 75), pack-reused 637 (from 1)
# Receiving objects: 100% (886/886), 167.01 MiB | 23.98 MiB/s, done.
# Resolving deltas: 100% (491/491), done.

# %%
# !ls /kaggle/input/shrec-rotation/augmenttttdrrsds-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/images_d_augmented
# Out:
# 'SHREC2017.mVOs-3d.14g-noisy(raw).960px-[allVOs].adaptive-mean'

# %%
# %cd Random-Cropping-augmentation-HGR/e2eET
# Out:
# /kaggle/working/Random-Cropping-augmentation-HGR/e2eET

# %%
# !cp -r /kaggle/input/shrec-rotation/augmenttttdrrsds-e2eET-Skeleton-Based-HGR-Using-Data-Level-Fusion/images_d_augmented/* /kaggle/working/Random-Cropping-augmentation-HGR/e2eET/images_d/

# %%
# %cd experiments.server
# Out:
# /kaggle/working/Random-Cropping-augmentation-HGR/e2eET/experiments.server

# %%
# !pip install pytorchcv
# !pip install matplotlib
# !pip install geffnet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.2/134.2 kB 3.3 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.2/585.2 kB 14.1 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !python mVO.e2eEnsembleTuning.py -IG 0 -nC 14 -mVOs top-down custom front-away -dsN SHREC2017 -IISE 0 -ISIS 0
# Out:
# Debug: Number of items in training split: 1960
# Debug: Number of items in validation split: 840
# Debug: Expected classes: 14, Detected classes: 14
# Debug: Detected class vocab: ['01-Grab', '02-Tap', '03-Expand', '04-Pinch', '05-RotationCW', '06-RotationCCW', '07-SwipeRight', '08-SwipeLeft', '09-SwipeUp', '10-SwipeDown', '11-SwipeX', '12-Swipe+', '13-SwipeV', '14-Shake']
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
# ...
